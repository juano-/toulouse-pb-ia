# %% [markdown]
# ### TLS 24 - Rag CoT

# %%
# 1. load data
import os
import pandas as pd
import src.utils as ut
import prompt_builder as pb

from dotenv import load_dotenv
from src.data_loader import load_and_prepare_projects, load_test_dataset
from prompt_utils import tokens_counter, prompt_cost


path_22 = 'data/tls22_projects.csv'
path_24 = 'data/tls24_projects.csv'

df, df22_shuffled = load_and_prepare_projects(path_22,path_24, city = "Toulouse")
test = load_test_dataset(df, rows = len(df[df['year'] == 2024]), city = 'Toulouse')

load_dotenv()

conn_params = {
    "host": os.environ["PG_HOST"],
    "database": os.environ["PG_DATABASE"],
    "user": os.environ["PG_USER"],
    "password": os.environ['PG_PASSWORD']
}

# %%
#2. build prompt
top_k_voted_22 = pb.get_top_k_projects_from_22_election(df, k=15)
proj_count_avg_by_district= pb.get_project_count_and_avg_votes_by_district(df)
proj_count_avg_by_categories = pb.get_project_count_and_avg_votes_by_categories(df)

test['prompt'] = test.apply(
    lambda x: pb.build_prompt(
        'prompts/prompt_rag_CoT_fr.txt',
        {
            'top_k_voted_22': top_k_voted_22,
            'project_count_and_avg_votes_by_district': proj_count_avg_by_district,
            'project_name': x['project_name'],
            'cost': x['cost'],
            'district': x['district'],
            'description': x['description'],
            'top_k_similar_projects_in_22': pb.get_top_k_similar_projects_in_22(df,x['project_id'],conn_params, k=10),
            'count_of_projects22_in_quartier': pb.get_count_of_projects_in_quartier(df,x['district']),
            'top_k_voted_in_district': pb.get_top_k_voted_in_district(df, x['district'], k=5),
            'count_of_projects24_in_quartier': pb.get_count_of_projects_in_quartier(df,x['district'], year=2024),
            'top_k_similar_projects_in_district': pb.get_top_k_similar_projects_in_22_by_district(df, x['project_id'], conn_params,k=5)
        }
    ),
    axis=1
)

# %%
print(test['prompt'].iloc[0])
# Out:
# Vous êtes un modèle expert dans l’analyse des élections de budgets participatifs, spécifiquement dans le contexte de la ville de Toulouse, en France.
#
# À Toulouse, la municipalité organise des élections de budget participatif pour financer des projets citoyens. Chaque habitant peut voter pour entre 1 et 3 initiatives sur le site web officiel.
# Les votes sont anonymes.
#
# Voici comment les projets sont sélectionnés :
# - Tous les projets sont classés selon le nombre de voix obtenues.
# - Un algorithme « greedy » est utilisé : on finance les projets dans l’ordre décroissant des voix, tant que le budget total n’est pas dépassé.
# - Si un projet est trop coûteux pour le budget restant, on passe au suivant.
#
# ---
#
# Lors de l’élection de 2022 :
# - Il y a eu **4532 votants**, chaque personne pouvant voter pour jusqu'à 3 projets.
# - Au total, environ **11918 voix** ont été exprimées sur **200 projets**.
# - Le nombre de voix par projet variait de *2* à 492, avec une moyenne autour de **58** voix et un écart-type estimé de **68**.
# - La majorité des projets ont reçu entre **18 et 75 voix**.
# - Le budget total disponible était de **8000000 €**.
#
# Dans cette édition, les 15 projets les plus votés étaient les suivants :
#
# - Piste cyclable avenue Saint-Exupéry: (Coût: 200000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 492 Voix, Classement: 1
# - Faire des voies vélos et piétons dédiées et bien délimitées: (Coût: 150000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 467 Voix, Classement: 2
# - Végétalisation de la place du Capitole: (Coût: 200000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 358 Voix, Classement: 3
# - Lutte anti-moustiques: (Coût: 7500.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 258 Voix, Classement: 4
# - Planter des arbres et jardins partagés partout où c'est possible!: (Coût: 20000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 243 Voix, Classement: 5
# - Réaménagement piéton, vélos et végétalisation allées Charles de Fitte: (Coût: 175000.0 €, District: 6 - Saint-Cyprien). 206 Voix, Classement: 6
# - Un complexe sportif en zone urbaine: (Coût: 130000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 205 Voix, Classement: 7
# - Terrain couvert au niveau du boulodrome: (Coût: 200000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 189 Voix, Classement: 8
# - Éclairage nocturne à détecteur de mouvements : (Coût: 200000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 189 Voix, Classement: 9
# - Aménager le Rond-Point des Français Libres et le carrefour Demoiselles - Mistral - Frizac - Duméril - St Joseph: (Coût: 200000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 178 Voix, Classement: 10
# - Pénaliser les motards bruyants: (Coût: 30000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 174 Voix, Classement: 11
# - Réouverture des espaces verts des bords de Garonne aux Toulousains: (Coût: 200000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 164 Voix, Classement: 12
# - Végétalisation massive de la place Roguet/ St Cyprien: (Coût: 110000.0 €, District: 6 - Saint-Cyprien). 161 Voix, Classement: 13
# - Lutter contre les moustiques avec les chauves-souris: (Coût: 1200.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 155 Voix, Classement: 14
# - Faire de la Place Amat Massot ... une place ECO-CITOYENNE conviviale !: (Coût: 200000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 145 Voix, Classement: 15
#
#
# Voici, pour chaque quartier, le nombre de projets proposés et le nombre moyen de voix reçues lors de l’élection de 2022 :
# 1 - Capitole / Arnaud Bernard / Carmes : 10 projets, moyenne de voix 136.9.
# 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux : 10 projets, moyenne de voix 71.4.
# 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée : 10 projets, moyenne de voix 43.6.
# 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère : 10 projets, moyenne de voix 116.9.
# 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville : 10 projets, moyenne de voix 55.7.
# 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur : 10 projets, moyenne de voix 40.4.
# 15 - Croix de Pierre / Route d'Espagne : 10 projets, moyenne de voix 45.1.
# 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette : 10 projets, moyenne de voix 39.2.
# 17 - Mirail-Université / Reynerie / Bellefontaine : 10 projets, moyenne de voix 10.5.
# 18 - Lardenne / Pradettes / Basso-Cambo : 10 projets, moyenne de voix 62.2.
# 19 - Casselardit / Fontaine-Bayonne / Cartoucherie : 10 projets, moyenne de voix 49.8.
# 2 - Amidonniers / Compans-Caffarelli / Brouardel : 10 projets, moyenne de voix 58.2.
# 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan : 10 projets, moyenne de voix 43.8.
# 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy : 10 projets, moyenne de voix 52.4.
# 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne : 10 projets, moyenne de voix 41.0.
# 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir : 10 projets, moyenne de voix 76.8.
# 6 - Saint-Cyprien : 10 projets, moyenne de voix 77.8.
# 7 - Sept Deniers / Ginestous-Sesquières / Lalande : 10 projets, moyenne de voix 30.8.
# 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre : 10 projets, moyenne de voix 75.2.
# 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve : 10 projets, moyenne de voix 32.9.
#
#
# ---
#
# Votre tâche est maintenant d’évaluer un nouveau projet soumis à l’élection suivante, dans laquelle **183 projets ont été proposés** et un plus grand nombre de participants est attendu.
#
# **Projet à analyser :**
# - Nom : Multiplier les places de stationnement pour les vélos en hypercentre
# - Coût : 12000.0 €
# - Quartier : 1 - Capitole / Arnaud Bernard / Carmes
# - Description : Même si des efforts notables ont déjà été effectués, vouloir développer la part modale du vélo dans les déplacements exige d'accroître très sensiblement les possibilités d'accroche des vélos, notamment dans l'hyper centre. Les places de stationnement sont très insuffisantes autour de la place du Capitole, place Wilson, Place St Pierre, Place Arnaud Bernard, autour de St Sernin, Boulevards Carnot, Strasbourg, Arcole, rues Alsace-Lorraine, Mirepoix, Pargaminières, Rémusat, Taur, Gambetta, etc.🔎 CE QUE PRÉVOIENT LES SERVICES : Dans le cadre de ses projets d'aménagement urbain, la Collectivité intègre systématiquement du mobilier de type accroche pour les vélos.Le déploiement de mobilier urbain de type racks à vélos dans l'hyper centre s'effectue selon les besoins signalés par les riverains et usagers (sollicitation auprès du Maire de Quartier ou de la plateforme AlloToulouse 05 61 222 222) sous réserve de l'avis de l'Architecte des Bâtiments de France et de la disponibilité sur l'espace public déjà très contraint.Dans le cadre de ce dispositif, il est proposé d'installer, a minima, une cinquantaine de racks vélos par an sur le quartier 1.
#
# En vous basant sur :
# - Les dynamiques de vote observées en 2022.
# - Le coût, le quartier et la thématique du projet.
# - Votre compréhension du contexte social, écologique et politique de Toulouse.
#
# ---
#
# En complément, voici une sélection de projets similaires dans toute la ville, présentés lors de l’élection de 2022 et présentant une forte similarité sémantique avec le projet à analyser.
# Chaque projet inclut :
# - le nom du projet,
# - le quartier concerné,
# - le coût estimé,
# - le nombre de voix obtenues,
# - et leur position dans le classement final.
#
# - Piste vélos terrifique sur le boulevard Matabiau: (Coût: 200000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 83 Voix, Classement: 44
# - Remplacer des places de stationnement par des arbres: (Coût: 100000.0 €, District: 6 - Saint-Cyprien). 76 Voix, Classement: 48
# - Installer des racks à vélos devant tous les commerces et les zones vertes: (Coût: 6000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 75 Voix, Classement: 50
# - Stations de gonflage pour vélo sur les trajets les plus fréquentés: (Coût: 9000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 74 Voix, Classement: 52
# - Facilliter la traversée des allées Charles de Fitte: (Coût: 80000.0 €, District: 6 - Saint-Cyprien). 52 Voix, Classement: 70
# - Installer des racks à vélos devant tous les commerces et les zones vertes: (Coût: 6000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 42 Voix, Classement: 94
# - Le développement de l'auto partage: (Coût: 4500.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 35 Voix, Classement: 108
# - Sécuriser les piétons: (Coût: 150000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 22 Voix, Classement: 137
# - Arceau pour vélo: (Coût: 35000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 19 Voix, Classement: 149
# - Faire des stationnements matérialisés avenue des coteaux : (Coût: 115000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 11 Voix, Classement: 168
# - Installation arceaux vélo à  Lardenne: (Coût: 15000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 8 Voix, Classement: 179
#
#
# ---
#
# Dans le quartier 1 - Capitole / Arnaud Bernard / Carmes, 10 projets ont été proposés, et les projets les plus votés étaient :
#
# - Faire des voies vélos et piétons dédiées et bien délimitées: (Coût: 150000.0 €). 467 Voix, Classement: 2
# - Végétalisation de la place du Capitole: (Coût: 200000.0 €). 358 Voix, Classement: 3
# - Pénaliser les motards bruyants: (Coût: 30000.0 €). 174 Voix, Classement: 11
# - Végétalisation place saint sernin rue alsace parvis de la gare: (Coût: 200000.0 €). 105 Voix, Classement: 29
# - Stations de gonflage pour vélo sur les trajets les plus fréquentés: (Coût: 9000.0 €). 74 Voix, Classement: 52
#
#
# Cette année, 10 projets ont été proposés dans le quartier.
#
# Voici une sélection de projets similaires issus de l’élection précédente et situés dans le même quartier :
#
# - Faire des voies vélos et piétons dédiées et bien délimitées: (Coût: 150000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 467 Voix, Classement: 2
# - Végétalisation de la place du Capitole: (Coût: 200000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 358 Voix, Classement: 3
# - Végétalisation place saint sernin rue alsace parvis de la gare: (Coût: 200000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 105 Voix, Classement: 29
# - Stations de gonflage pour vélo sur les trajets les plus fréquentés: (Coût: 9000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 74 Voix, Classement: 52
# - Planter des arbres et plantes comestibles: (Coût: 3000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 61 Voix, Classement: 64
# - Uritrottoir en plus: (Coût: 14000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 36 Voix, Classement: 106
#
#
# ---
#
# Veuillez répondre sous la forme d’un dictionnaire JSON avec les clés suivantes :
#
# ```json
# {
#   "voix_estimées": X,                // Nombre estimé de voix (entier)
#   "intervalle_confiance": [a, b],   // Intervalle réaliste (min, max)
#   "position_attendue": Y,           // Rang estimé dans le classement
#   "dans_top_5": 1 ou 0,             // 1 si probable d'être dans le top 5, sinon 0
#   "dans_top_10": 1 ou 0             // 1 si probable d'être dans le top 10, sinon 0
# }
# Avant de donner une réponse, prenez le temps de raisonner en profondeur, mais expliquez seulement le raisonnement essentiel.
#
# **INSTRUCTIONS DE SORTIE**
# 1. Exposez votre raisonnement en 5 à 8 points clés maximum, de façon concise.
# 2. À la fin, fournissez uniquement un dictionnaire JSON valide, sans autre texte.

# %%
test['n_tokens'] = test['prompt'].apply(lambda p: tokens_counter(p))
test['cost_usd'] = test['n_tokens'].apply(lambda n_tokens: prompt_cost(n_tokens, 'gpt-4-turbo'))

print('mean tokens by prompt: {:.2f}'.format(test.n_tokens.mean()))
print('avg.cost of each prediction: ${:.2f}'.format(test.cost_usd.mean()))
print('experiment total cost: {:.2f}'.format(test.cost_usd.sum()))
# Out:
# mean tokens by prompt: 4102.49
# avg.cost of each prediction: $0.04
# experiment total cost: 7.51

# %%
#3. run experiment! :)
api_key=os.getenv('OPENAI_API_KEY')
from llm_client import call_openai_model 

test['out'] = test['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))
# Out:
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!

# %%
import json
import re

def get_json_from_llm_response(out):
    
    if isinstance(out, str):
        try:
            data = json.loads(out)
            if isinstance(data, dict):
                return data
        except json.JSONDecodeError:
            pass

    match = re.search(r"```json\s*({.*?})\s*```", out, re.DOTALL)
    if match:
        json_str = match.group(1)
        try:
            return json.loads(json_str)
        except json.JSONDecodeError:
            return None

    return None

def get_predicted_votes(df, out_json, city = 'Toulouse'):
    
    if city != 'Toulouse':
        raise ValueError(f"City '{city}' not supported")

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
    
    votes_2022 = df[df['year'] == 2022].votes.sum()
    votes_2024 = df[df['year'] == 2024].votes.sum()

    relative_estimation = out_json['voix_estimées'] / votes_2022
    adjusted_prediction = relative_estimation * votes_2024

    return adjusted_prediction

def get_predicted_rank(out_json):
    
    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['position_attendue']


def get_if_is_top5(out_json):

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['dans_top_5']

def get_if_is_top10(out_json):

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['dans_top_10']

# %%
test['out_json'] = test['out'].apply(
    lambda o: get_json_from_llm_response(o))

# %%
test['out_json'].iloc[0]
# Out:
# {'voix_estimées': 150,
#  'intervalle_confiance': [100, 200],
#  'position_attendue': 8,
#  'dans_top_5': 0,
#  'dans_top_10': 1}

# %%
test['predicted_votes'] = test['out_json'].apply(lambda x: get_predicted_votes(df, x))
test['predicted_rank'] = test['out_json'].apply(lambda x: get_predicted_rank(x))
test['is_top5'] = test['out_json'].apply(lambda x: get_if_is_top5(x))
test['is_top10'] = test['out_json'].apply(lambda x: get_if_is_top10(x))

# %%
#4. save results.
results = test.filter(['project_id', 
             'real_votes', 
             'real_rank',
             'prompt',
             'out',
             'out_json', 
             'predicted_votes', 
             'predicted_rank', 
             'is_top5', 
             'is_top10']
             )
results
# Out:
#      project_id  real_votes  real_rank  \
# 0           263         590          1
# 1           320         559          2
# 2           394         436          3
# 3           333         366          4
# 4           265         334          5
# ..          ...         ...        ...
# 178         372          20        179
# 179         356          19        180
# 180         230          19        181
# 181         370          18        182
# 182         374          17        183
#
#                                                 prompt  \
# 0    Vous êtes un modèle expert dans l’analyse des ...
# 1    Vous êtes un modèle expert dans l’analyse des ...
# 2    Vous êtes un modèle expert dans l’analyse des ...
# 3    Vous êtes un modèle expert dans l’analyse des ...
# 4    Vous êtes un modèle expert dans l’analyse des ...
# ..                                                 ...
# 178  Vous êtes un modèle expert dans l’analyse des ...
# 179  Vous êtes un modèle expert dans l’analyse des ...
# 180  Vous êtes un modèle expert dans l’analyse des ...
# 181  Vous êtes un modèle expert dans l’analyse des ...
# 182  Vous êtes un modèle expert dans l’analyse des ...
#
#                                                    out  \
# 0    1. Le quartier 1 - Capitole / Arnaud Bernard /...
# 1    1. **Analyse des projets similaires**: Le proj...
# 2    1. **Analyse des projets similaires**: Les pro...
# 3    1. Le projet "Rénovation skatepark Rangueil" e...
# 4    1. Le quartier Capitole / Arnaud Bernard / Car...
# ..                                                 ...
# 178  1. Le quartier 17 - Mirail-Université / Reyner...
# 179  1. Le projet "Débitumiser les places de statio...
# 180  1. Le projet "Installation de poubelles à déje...
# 181  1. Le quartier 17 - Mirail-Université / Reyner...
# 182  1. Le quartier 17 - Mirail-Université / Reyner...
#
#                                               out_json  predicted_votes  \
# 0    {'voix_estimées': 150, 'intervalle_confiance':...       281.492332
# 1    {'voix_estimées': 480, 'intervalle_confiance':...       900.775461
# 2    {'voix_estimées': 125, 'intervalle_confiance':...       234.576943
# 3    {'voix_estimées': 100, 'intervalle_confiance':...       187.661554
# 4    {'voix_estimées': 180, 'intervalle_confiance':...       337.790798
# ..                                                 ...              ...
# 178  {'voix_estimées': 20, 'intervalle_confiance': ...        37.532311
# 179  {'voix_estimées': 75, 'intervalle_confiance': ...       140.746166
# 180  {'voix_estimées': 35, 'intervalle_confiance': ...        65.681544
# 181  {'voix_estimées': 25, 'intervalle_confiance': ...        46.915389
# 182  {'voix_estimées': 20, 'intervalle_confiance': ...        37.532311
#
#      predicted_rank  is_top5  is_top10
# 0                 8        0         1
# 1                 2        1         1
# 2                10        0         1
# 3                30        0         0
# 4                 8        0         1
# ..              ...      ...       ...
# 178             150        0         0
# 179              45        0         0
# 180             100        0         0
# 181             130        0         0
# 182             150        0         0
#
# [183 rows x 10 columns]

# %%
results.to_csv('output/predictions/tls_rag_cot_full_1.csv', sep=";", index=False)
print('results ready!')
# Out:
# results ready!

# %% [markdown]
# ### WRC 17 CoT

# %%
# 1. load data
import os
import pandas as pd
import src.utils as ut
import prompt_builder as pb

from dotenv import load_dotenv
from src.data_loader import load_and_prepare_projects, load_test_dataset
from prompt_utils import tokens_counter, prompt_cost


path_16 = 'data/wrc16_projects.csv'
path_17 = 'data/wrc17_projects.csv'

df, df16_shuffled = load_and_prepare_projects(path_16,path_17, city = 'Wroclaw')
test = load_test_dataset(df, rows = 50, city='Wroclaw')

load_dotenv()

conn_params = {
    "host": os.environ["PG_HOST"],
    "database": os.environ["PG_DATABASE"],
    "user": os.environ["PG_USER"],
    "password": os.environ['PG_PASSWORD']
}

test
# Out:
#     project_id                                       project_name  \
# 0           10  Toalety we Wrocławskich parkach i na terenach ...
# 1           50  Zielona rowerowo-piesza obwodnica Wrocławia; E...
# 2           18                              Rowerowy Wrocław 2017
# 3          675  Zieleń dla Wrocławia – parki kieszonkowe, nasa...
# 4          260                     Budki dla kotów wolno żyjących
# 5          550  Pieszo z Brochowa - uzupełnienie brakującego c...
# 6           12  Bulwar Fizyków - naukowy plac zabaw w przestrz...
# 7          159  Baza małych astronautów czyli kosmiczny plac z...
# 8          656     Toalety miejskie w parkach na miarę Wrocławia.
# 9          499  "Konikowo" - Budowa autorskiego placu zabaw na...
# 10         751                   Modernizacja ulicy DRZEWIECKIEGO
# 11         451                 Wrocławska Arena Sportu - strefa A
# 12         284  Zielona Obwodnica Wrocławia - drzewa i pnącza ...
# 13         345                                     Park Rędziński
# 14          41                Fontanna Neptuna na Placu Nowy Targ
# 15          16                Remont zabytkowego autobusu Fredruś
# 16         716  Park Grabiszyński - bezpieczne dojście! Remont...
# 17         590  Zagospodarowanie terenu kąpieliska na Oporowie...
# 18          43              Zielona Promenada przez Krzyki Etap I
# 19          46  Rondo Reagana na poziomie! Budowa peronów na R...
# 20         514  Pszczoły w mieście – hotele dla zapylaczy z pl...
# 21         553  Sieć parków we Wrocławiu - Psie Pole - Zawidaw...
# 22          68  Zielona trasa biegowo-pieszo-rowerowa z Ołtasz...
# 23         608                                 Sportowa Jantarowa
# 24         258                          Rewitalizacja ul. Ruskiej
# 25         555  Sieć parków we Wrocławiu – Psie Pole - Zawidaw...
# 26          83  Bezpieczne i przyjazne drogi we Wrocławiu - św...
# 27         680     Ścieżki pieszo-rowerowe przy ul. Opatowickiej.
# 28         372  Połączmy Psie Pole i Zakrzów – łącznik pieszo-...
# 29         688                          Miodowe łąki we Wrocławiu
# 30         668  "Park & ride" przy pętli Pilczyce/Stadion Wrocław
# 31         685                             Miejskie wyspy zieleni
# 32         694                Zielone przystanki w centrum miasta
# 33         371  Bezpieczniej na skrzyżowaniu al. Sobieskiego i...
# 34         508  Kępa Mieszczańska –park kieszonkowy z stacją s...
# 35         346          Odnowienie szpetnych wiaduktów kolejowych
# 36         358  Toskania we Wrocławiu: donice z kwiatami wokół...
# 37         594                Las sekwoi, drzewa i krzewy owocowe
# 38         332       Infrastruktura przystankowa na ul. Dworcowej
# 39         334          infrastruktura przystankowa na ul. Dawida
# 40          35  Wsiadanie na poziomie-budowa przystanków wiede...
# 41         620         Wrocławskie parki dostępne dla wszystkich.
# 42         203  Oczyszczenie z wojennego osmolenia i sadzy pia...
# 43         735  Rampa dla rowerów i wózków przy wyjściu z ulic...
# 44         464  Szachy plenerowe dużego gabarytu w centrum mia...
# 45         422          Akcja Plac - Gry uliczne "Oswajamy beton"
# 46         406  Budowa wrocławskiej wypożyczalni rowerów integ...
# 47         629  Wrocław na dotknięcie ręki – tylfograficzne ma...
# 48         720                                               1997
# 49         677  Polegiwacz - wędrujący mebel do odpoczynku i z...
#
#                                           description     cost      district  \
# 0   Uzasadnienie\nW parkach i na terenach zielonyc...   900000   Śródmieście
# 1   Uzasadnienie\nWalczymy o II ETAP. Ideą jest po...  1000000  Stare Miasto
# 2   Uzasadnienie\nProjekt przewiduje poprawę bezpi...  1000000  Stare Miasto
# 3   Uzasadnienie\nWe Wrocławiu nastąpiła deklaraty...  1000000     Psie Pole
# 4                                        Uzasadnienie    70000     Psie Pole
# 5   Uzasadnienie\nZ Brochowa nie sposób wydostać s...  1000000        Krzyki
# 6   Uzasadnienie\nProponujemy stworzenie instalacj...  1000000     Psie Pole
# 7   Uzasadnienie\nW ramach Budżetu Obywatelskiego ...  1000000        Krzyki
# 8   Uzasadnienie\nInicjatywa jest odpowiedzią na p...  1000000   Śródmieście
# 9   Uzasadnienie\nDrodzy Wrocławianie, Drodzy Sąsi...  1000000  Stare Miasto
# 10  Uzasadnienie\nPrzejścia dla pieszych oraz miej...  1000000        Krzyki
# 11  Uzasadnienie\nProjekt zakłada powstanie strefy...  1000000        Krzyki
# 12  Uzasadnienie\nProjekt zakłada nasadzenia drzew...   100000        Krzyki
# 13  Uzasadnienie\nKoncepcję Parku na Maślicach zap...  1000000        Krzyki
# 14  Uzasadnienie\nOdtworzenie historycznej rzeźby ...  1000000   Śródmieście
# 15  Uzasadnienie\nAutobus kabriolet Jelcz MEX - Fr...   430000        Krzyki
# 16  Uzasadnienie\nNiezbędny jest remont ogromnej w...  1000000  Stare Miasto
# 17  Uzasadnienie\nBudowa: boiska do siatkówki plaż...  1000000     Fabryczna
# 18  Uzasadnienie\nProjekt ma za zadanie przywrócen...  1000000        Krzyki
# 19  Uzasadnienie\nRondo Reagana to jeden z ważniej...  1000000     Psie Pole
# 20  Uzasadnienie\nObecnie wskazany zieleniec pomim...   250000        Krzyki
# 21  Uzasadnienie\nCelem projektu jest stworzenie d...  1000000     Fabryczna
# 22  Uzasadnienie\nProponuję kilka modyfikacji (głó...   750000        Krzyki
# 23  Uzasadnienie\nRealizując projekt budowy boiska...  1000000        Krzyki
# 24  Uzasadnienie\nCelem projektu jest remont ul. R...   750000     Psie Pole
# 25  Uzasadnienie\nCelem projektu jest stworzenie d...  1000000  Stare Miasto
# 26  Uzasadnienie\nProjekt zakłada zmianę trybu pra...   650000     Psie Pole
# 27  Uzasadnienie\nWzdłuż ul. Opatowickiej biegnie ...   500000        Krzyki
# 28  Uzasadnienie\nProjekt przewiduje budowę ciągu ...   350000  Stare Miasto
# 29  Uzasadnienie\nCelem projektu jest stworzenie a...   100000     Psie Pole
# 30  Uzasadnienie\n"Park & ride" to parkingi dla  p...   750000     Fabryczna
# 31  Uzasadnienie\nW tym roku smog dał się we znaki...   250000  Stare Miasto
# 32  Uzasadnienie\nProjekt zakłada utworzenie zielo...   320000     Fabryczna
# 33  Uzasadnienie\nProjekt ma na celu poprawę bezpi...  1000000        Krzyki
# 34  Uzasadnienie\nUporządkowanie i zagospodarowani...   750000     Psie Pole
# 35  Uzasadnienie\nCelem projektu jest ocieplenie z...   250000        Krzyki
# 36  Uzasadnienie\nCelem projektu jest upiększenie ...   350000        Krzyki
# 37  Uzasadnienie\n1. Mało kto wie, że kiedyś, potę...   150000  Stare Miasto
# 38  Uzasadnienie\nPętla przystankowa przy ul. Dwor...   420000  Stare Miasto
# 39  Uzasadnienie\nNa ul. Dawida (między ul. Dawida...   250000   Śródmieście
# 40  Uzasadnienie\nPrzystanki wiedeńskie ułatwiają ...   500000   Śródmieście
# 41  Uzasadnienie\nNieodłączną częścią tkanki miejs...   200000     Fabryczna
# 42  Uzasadnienie\nMedaliony z herbem Wrocławia są ...   150000        Krzyki
# 43  Uzasadnienie\nWały nad Odrą, a w szczególności...    50000     Fabryczna
# 44  Uzasadnienie\nBudowa szachów dużego gabarytu w...   250000  Stare Miasto
# 45  Uzasadnienie\nProjekt zakłada lokowanie w prze...   150000   Śródmieście
# 46  Uzasadnienie\nProjekt przeznaczony jest zarówn...   600000        Krzyki
# 47  Uzasadnienie\nRynek i wszystkie miejsca, takie...   130000  Stare Miasto
# 48  Uzasadnienie\nIdeą projektu "1997" było upamię...    50000        Krzyki
# 49  Uzasadnienie\nPolegiwacz jest przenośnym meble...   150000   Śródmieście
#
#     district_number  real_votes  real_rank  year
# 0               4.0       10857          1  2017
# 1               5.0       10796          2  2017
# 2               5.0        8640          3  2017
# 3               3.0        5398          4  2017
# 4               3.0        4998          5  2017
# 5               2.0        4468          6  2017
# 6               3.0        4149          7  2017
# 7               2.0        4098          8  2017
# 8               4.0        4008          9  2017
# 9               5.0        3949         10  2017
# 10              2.0        3788         11  2017
# 11              2.0        3368         12  2017
# 12              2.0        3362         13  2017
# 13              2.0        2484         14  2017
# 14              4.0        2123         15  2017
# 15              2.0        2113         16  2017
# 16              5.0        2098         17  2017
# 17              1.0        2001         18  2017
# 18              2.0        1973         19  2017
# 19              3.0        1839         20  2017
# 20              2.0        1737         21  2017
# 21              1.0        1724         22  2017
# 22              2.0        1705         23  2017
# 23              2.0        1613         24  2017
# 24              3.0        1566         25  2017
# 25              5.0        1512         26  2017
# 26              3.0        1455         27  2017
# 27              2.0        1358         28  2017
# 28              5.0        1331         29  2017
# 29              3.0        1092         30  2017
# 30              1.0        1060         31  2017
# 31              5.0         990         32  2017
# 32              1.0         943         33  2017
# 33              2.0         922         34  2017
# 34              3.0         882         35  2017
# 35              2.0         765         36  2017
# 36              2.0         619         37  2017
# 37              5.0         587         38  2017
# 38              5.0         544         39  2017
# 39              4.0         480         40  2017
# 40              4.0         433         41  2017
# 41              1.0         418         42  2017
# 42              2.0         415         43  2017
# 43              1.0         266         44  2017
# 44              5.0         263         45  2017
# 45              4.0         236         46  2017
# 46              2.0         178         47  2017
# 47              5.0         156         48  2017
# 48              2.0         118         49  2017
# 49              4.0          83         50  2017

# %%
conn_params = {
    "host": os.environ["PG_HOST"],
    "database": os.environ["PG_DATABASE"],
    "user": os.environ["PG_USER"],
    "password": os.environ['PG_PASSWORD']
}

#2. build prompt
top_k_voted_16 = pb.get_top_k_projects_from_16_election(df, k=15)
proj_count_avg_by_district= pb.get_project_count_and_avg_votes_by_district(df, city = 'Wroclaw')
proj_count_avg_by_categories = pb.get_project_count_and_avg_votes_by_categories(df, city = 'Wroclaw')

# %%
test['prompt'] = test.apply(
    lambda x: pb.build_prompt(
        'prompts/prompt_rag2_CoT_pl.txt',
        {
            'top_k_voted_16': top_k_voted_16,
            'project_count_and_avg_votes_by_district': proj_count_avg_by_district,
            'project_name': x['project_name'],
            'cost': x['cost'],
            'district': x['district'],
            'description': x['description'],
            'top_k_similar_projects_in_16': pb.get_top_k_similar_projects_in_16(df, x['project_id'], x['year'], conn_params,k=5),
            'count_of_projects16_in_quartier': pb.get_count_of_projects_in_quartier(df,x['district'], year=2016),
            'top_k_voted_in_district': pb.get_top_k_voted_in_district_eng(df, x['district'], k=5, year=2016),
            'count_of_projects17_in_quartier': pb.get_count_of_projects_in_quartier(df,x['district'], year=2017),
            'top_k_similar_projects_in_district': pb.get_top_k_similar_projects_in_16_by_district(df, x['project_id'], x['year'], conn_params,k=5)
        }
    ),
    axis=1
)

# %%
print(test['prompt'].iloc[0])
# Out:
# You are an expert model in the analysis of participatory budgeting elections, specifically in the context of the city of Wroclaw, Poland.
#
# In Wroclaw, the municipality organizes participatory budgeting elections to fund citizen-led projects. Each resident can vote for between 1 and 3 initiatives on the official website.
# Votes are anonymous.
#
# Here is how the projects are selected:
# - All projects are ranked by the number of votes received.
# - A "greedy" algorithm is used: projects are funded in descending order of votes, as long as the total budget is not exceeded.
# - If a project is too expensive for the remaining budget, it is skipped and the next one is considered.
#
# ---
# In the 2016 election:
# - There were **67103 voters**, each allowed to vote for up to 3 projects.
# - In total, approximately **119194 votes** were cast across **52 projets**.
# - The number of votes per project ranged from **120** to **13938**, with an average of **2292.19** votes and an estimated standard deviation of **2784.06**.
# - Most projects received between **597** and **2923** votes.
# - The total available budget was **4500000 €**.
#
# In this edition, the 15 most-voted projects were:
#
# - Drzewa dla Wrocławia - nasadzenia w całym mieście!: (Cost: 1000000 €, District: Fabryczna). 13938 Votes, Ranking: 1
# - Zielona rowerowo-piesza obwodnica Wrocławia; Etap I - fragment łącznika Gaj, Wojszyce, Ołtaszyn, Partynice, Jagodno, Tarnogaj Krzyki, Borek.: (Cost: 1000000 €, District: Krzyki). 12348 Votes, Ranking: 2
# - Oświetlenie Parku Grabiszyńskiego (Alei Romera oraz ścieżek do Cmentarza Grabiszyńskiego i ul. Racławickiej wzdłuż polan): (Cost: 1000000 €, District: Krzyki). 7291 Votes, Ranking: 3
# - Plac Zabaw dla Starszaków w parku Grabiszyńskim i coś ekstra dla maluchów: (Cost: 560000 €, District: Krzyki). 6663 Votes, Ranking: 4
# - Parking przy "Dobrzyńskiej" - ułatwienie dojazdu wrocławian do największego w mieście centrum medycznego.: (Cost: 750000 €, District: Krzyki). 6383 Votes, Ranking: 5
# - Posadzenie na terenie Wrocławia młodych drzew: (Cost: 100000 €, District: Fabryczna). 5287 Votes, Ranking: 6
# - Rowerowy Wrocław 2016 – ulice przyjazne rowerzystom: (Cost: 1000000 €, District: Śródmieście). 4799 Votes, Ranking: 7
# - Stoły do ping – ponga i boiska do siatkówki w całym Wrocławiu.: (Cost: 1000000 €, District: Fabryczna). 3974 Votes, Ranking: 8
# - Fontanna Neptuna na Placu Nowy Targ: (Cost: 750000 €, District: Stare Miasto). 3632 Votes, Ranking: 9
# - Budowa nadbrzeża ze slipem dla przyszłej miejskiej przystani łodziowej: (Cost: 1000000 €, District: Krzyki). 3243 Votes, Ranking: 10
# - Rowerowe połączenie Dworca Głównego z pl. Społecznym: (Cost: 1000000 €, District: Psie Pole). 3099 Votes, Ranking: 11
# - Park Jedności– miejska rekreacja: (Cost: 1000000 €, District: Fabryczna). 3026 Votes, Ranking: 12
# - Rozbudowa bazy sportowej na wrocławskich Osobowicach - strefa sportu przy Szkole Podstawowej nr 21: (Cost: 1000000 €, District: Psie Pole). 3008 Votes, Ranking: 13
# - Wydłużenie pasa lewoskrętu w kierunku ulicy Lotniczej na skrzyżowaniu ulic Na Ostatnim Groszu i Legnickiej: (Cost: 750000 €, District: Krzyki). 2901 Votes, Ranking: 14
# - Dokończenie trasy pieszo-rowerowej wokół Wielkiej Wyspy: (Cost: 1000000 €, District: Krzyki). 2260 Votes, Ranking: 15
#
#
# Here is, for each district, the number of projects proposed and the average number of votes received during the 2016 election:
# Fabryczna : 12 Projects, Votes Average: 2775.5833333333335.
# Krzyki : 17 Projects, Votes Average: 3055.823529411765.
# Psie Pole : 10 Projects, Votes Average: 1533.3.
# Stare Miasto : 7 Projects, Votes Average: 1485.2857142857142.
# Śródmieście : 5 Projects, Votes Average: 1554.4.
#
#
# ---
#
# Your task now is to evaluate a new project submitted to the upcoming election, in which **50 projects** have been proposed.
#
# **Project to analyze::**
# - Name: Toalety we Wrocławskich parkach i na terenach rekreacyjnych.
# - Cost: 900000 €
# - District: Śródmieście
# - Description: Uzasadnienie
# W parkach i na terenach zielonych we Wrocławiu brakuje toalet, co utrudnia korzystanie z nich w celach rekreacyjnych przez dłuższy czas.
# Proponujemy instalację toalet (technologia dowolna, prawdopodobnie najlepsze byłyby samoczyszczące i/lub odporne na wandalizm).
# Proponujemy następujące miejsca:
# 1) Park Szczytnicki
# 2) Park Wschodni
# 3) Park Południowy
# 4) Park Tysiąclecia
# 5) Park Zachodni
# 6) Karłowice (Park Kasprowicza lub Polana Karłowicka lub Brodzik)
# Szczegóły umiejscowienia zostaną ustalone z liderem projektu. W przypadku gdyby któryś z ww parków posiadał już toaletę w momencie wygranej projektu, wspólnie z UMW wybierzemy inną lokalizację.
#
# Based on:
# - The voting dynamics observed in 2016.
# - The cost, district, and theme of the project.
# - Your understanding of the social, ecological, and political context of Wroclaw.
#
# ---
#
# Additionally, here is a selection of similar projects across the city, presented during the 2016 election and showing strong semantic similarity with the project under review.
# Each project includes:
#
# - the project name,
# - the district concerned,
# - the estimated cost,
# - the number of votes received,
# - and their position in the final ranking.
#
# - Plac Zabaw dla Starszaków w parku Grabiszyńskim i coś ekstra dla maluchów: (Cost: 560000 €, District: Krzyki). 6663 Votes, Ranking: 4
# - Stoły do ping – ponga i boiska do siatkówki w całym Wrocławiu.: (Cost: 1000000 €, District: Fabryczna). 3974 Votes, Ranking: 8
# - Park Jedności– miejska rekreacja: (Cost: 1000000 €, District: Fabryczna). 3026 Votes, Ranking: 12
# - Niewykorzystany potencjał Parku Skowroniego - rewitalizacja: (Cost: 1000000 €, District: Śródmieście). 1644 Votes, Ranking: 24
# - Toaleta publiczna w Parku Wschodnim: (Cost: 250000 €, District: Psie Pole). 1441 Votes, Ranking: 28
# - Frisbee Golf: (Cost: 85000 €, District: Krzyki). 477 Votes, Ranking: 44
# - Miejskie wyspy zieleni: (Cost: 250000 €, District: Stare Miasto). 990 Votes, Ranking: 32
#
#
# ---
#
# In the district Śródmieście, 5 projects were proposed, and the most-voted ones were:
#
# - Rowerowy Wrocław 2016 – ulice przyjazne rowerzystom: (Cost: 1000000 €). 4799 Votes, Ranking: 7
# - Niewykorzystany potencjał Parku Skowroniego - rewitalizacja: (Cost: 1000000 €). 1644 Votes, Ranking: 24
# - Podwórze pomiędzy ulicami Prusa, Wyszyńskiego, Sępa Sarzyńskiego i Sienkiewicza: (Cost: 750000 €). 526 Votes, Ranking: 41
# - Remont ulicy Glinianej - odcinek Ślężna - Borowska: (Cost: 510000 €). 522 Votes, Ranking: 42
# - Cywilizacja na Wojszycach - Światło dla wszystkich - Zamontowanie miejskich latarni na ulicy Smardzowskiej w Europejskiej Stolicy Kultury: (Cost: 40000 €). 281 Votes, Ranking: 49
#
#
# This year, 7 projects have been proposed in the district.
#
# Here is a selection of similar projects from the previous election located in the same district:
#
# - Rowerowy Wrocław 2016 – ulice przyjazne rowerzystom: (Cost: 1000000 €, District: Śródmieście). 4799 Votes, Ranking: 7
# - Niewykorzystany potencjał Parku Skowroniego - rewitalizacja: (Cost: 1000000 €, District: Śródmieście). 1644 Votes, Ranking: 24
# - Podwórze pomiędzy ulicami Prusa, Wyszyńskiego, Sępa Sarzyńskiego i Sienkiewicza: (Cost: 750000 €, District: Śródmieście). 526 Votes, Ranking: 41
# - Remont ulicy Glinianej - odcinek Ślężna - Borowska: (Cost: 510000 €, District: Śródmieście). 522 Votes, Ranking: 42
# - Cywilizacja na Wojszycach - Światło dla wszystkich - Zamontowanie miejskich latarni na ulicy Smardzowskiej w Europejskiej Stolicy Kultury: (Cost: 40000 €, District: Śródmieście). 281 Votes, Ranking: 49
#
# ---
#
# Please respond in the form of a JSON dictionary with the following keys:
#
# ```json
# {
#     "estimated_votes": X,               // Estimated number of votes (integer)
#     "confidence_interval": [a, b],     // Realistic interval (min, max)
#     "expected_rank": Y,                // Expected rank in the final list
#     "in_top_5": 1 or 0,                // 1 if likely to be in the top 5, else 0
#     "in_top_10": 1 or 0                // 1 if likely to be in the top 10, else 0
# }
# Before giving your answer, take time to reason thoroughly, but only explain the essential reasoning.
#
# **OUTPUT INSTRUCTIONS**
# 1. Present your reasoning in 5 to 8 key points, concisely.
# 2. At the end, provide only a valid JSON dictionary, with no additional text.

# %%
test['n_tokens'] = test['prompt'].apply(lambda p: tokens_counter(p))
test['cost_usd'] = test['n_tokens'].apply(lambda n_tokens: prompt_cost(n_tokens, 'gpt-4-turbo'))

print('mean tokens by prompt: {:.2f}'.format(test.n_tokens.mean()))
print('avg.cost of each prediction: ${:.2f}'.format(test.cost_usd.mean()))
print('experiment total cost: {:.2f}'.format(test.cost_usd.sum()))
# Out:
# mean tokens by prompt: 2936.76
# avg.cost of each prediction: $0.03
# experiment total cost: 1.47

# %%
#3. run experiment! :)
api_key=os.getenv('OPENAI_API_KEY')
from llm_client import call_openai_model 

test['out'] = test['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))
# Out:
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!

# %%
import json
import re

def get_json_from_llm_response(out):
    # 1. Primer intento: el string completo es un JSON válido
    if isinstance(out, str):
        try:
            data = json.loads(out)
            if isinstance(data, dict):
                return data
        except json.JSONDecodeError:
            pass  # No es un JSON plano válido, continuamos

    # 2. Segundo intento: buscar bloque ```json {...} ```
    match = re.search(r"```json\s*({.*?})\s*```", out, re.DOTALL)
    if match:
        json_str = match.group(1)
        try:
            return json.loads(json_str)
        except json.JSONDecodeError:
            return None

    # 3. No se pudo encontrar JSON válido
    return None

def get_predicted_votes(df, out_json, city = 'Wroclaw'):
    
    if city != 'Wroclaw':
        raise ValueError(f"City '{city}' not supported")

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
    
    votes_2016 = df[df['year'] == 2016].votes.sum()
    votes_2017 = df[df['year'] == 2017].votes.sum()

    relative_estimation = out_json['estimated_votes'] / votes_2016
    adjusted_prediction = relative_estimation * votes_2017

    return adjusted_prediction

def get_predicted_rank(out_json):
    
    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['expected_rank']

def get_if_is_top5(out_json):
    return out_json['in_top_5']

def get_if_is_top10(out_json):
    return out_json['in_top_10']

# %%
test['out_json'] = test['out'].apply(
    lambda o: get_json_from_llm_response(o))

# %%
test['out_json'].iloc[0]
# Out:
# {'estimated_votes': 4000,
#  'confidence_interval': [3000, 5000],
#  'expected_rank': 10,
#  'in_top_5': 0,
#  'in_top_10': 1}

# %%
test['predicted_votes'] = test['out_json'].apply(lambda x: get_predicted_votes(df, x))
test['predicted_rank'] = test['out_json'].apply(lambda x: get_predicted_rank(x))
test['is_top5'] = test['out_json'].apply(lambda x: get_if_is_top5(x))
test['is_top10'] = test['out_json'].apply(lambda x: get_if_is_top10(x))

# %%
#4. save results.
results = test.filter(['project_id', 
             'real_votes', 
             'real_rank',
             'prompt',
             'out',
             'out_json', 
             'predicted_votes', 
             'predicted_rank', 
             'is_top5', 
             'is_top10']
             )
results
# Out:
#     project_id  real_votes  real_rank  \
# 0           10       10857          1
# 1           50       10796          2
# 2           18        8640          3
# 3          675        5398          4
# 4          260        4998          5
# 5          550        4468          6
# 6           12        4149          7
# 7          159        4098          8
# 8          656        4008          9
# 9          499        3949         10
# 10         751        3788         11
# 11         451        3368         12
# 12         284        3362         13
# 13         345        2484         14
# 14          41        2123         15
# 15          16        2113         16
# 16         716        2098         17
# 17         590        2001         18
# 18          43        1973         19
# 19          46        1839         20
# 20         514        1737         21
# 21         553        1724         22
# 22          68        1705         23
# 23         608        1613         24
# 24         258        1566         25
# 25         555        1512         26
# 26          83        1455         27
# 27         680        1358         28
# 28         372        1331         29
# 29         688        1092         30
# 30         668        1060         31
# 31         685         990         32
# 32         694         943         33
# 33         371         922         34
# 34         508         882         35
# 35         346         765         36
# 36         358         619         37
# 37         594         587         38
# 38         332         544         39
# 39         334         480         40
# 40          35         433         41
# 41         620         418         42
# 42         203         415         43
# 43         735         266         44
# 44         464         263         45
# 45         422         236         46
# 46         406         178         47
# 47         629         156         48
# 48         720         118         49
# 49         677          83         50
#
#                                                prompt  \
# 0   You are an expert model in the analysis of par...
# 1   You are an expert model in the analysis of par...
# 2   You are an expert model in the analysis of par...
# 3   You are an expert model in the analysis of par...
# 4   You are an expert model in the analysis of par...
# 5   You are an expert model in the analysis of par...
# 6   You are an expert model in the analysis of par...
# 7   You are an expert model in the analysis of par...
# 8   You are an expert model in the analysis of par...
# 9   You are an expert model in the analysis of par...
# 10  You are an expert model in the analysis of par...
# 11  You are an expert model in the analysis of par...
# 12  You are an expert model in the analysis of par...
# 13  You are an expert model in the analysis of par...
# 14  You are an expert model in the analysis of par...
# 15  You are an expert model in the analysis of par...
# 16  You are an expert model in the analysis of par...
# 17  You are an expert model in the analysis of par...
# 18  You are an expert model in the analysis of par...
# 19  You are an expert model in the analysis of par...
# 20  You are an expert model in the analysis of par...
# 21  You are an expert model in the analysis of par...
# 22  You are an expert model in the analysis of par...
# 23  You are an expert model in the analysis of par...
# 24  You are an expert model in the analysis of par...
# 25  You are an expert model in the analysis of par...
# 26  You are an expert model in the analysis of par...
# 27  You are an expert model in the analysis of par...
# 28  You are an expert model in the analysis of par...
# 29  You are an expert model in the analysis of par...
# 30  You are an expert model in the analysis of par...
# 31  You are an expert model in the analysis of par...
# 32  You are an expert model in the analysis of par...
# 33  You are an expert model in the analysis of par...
# 34  You are an expert model in the analysis of par...
# 35  You are an expert model in the analysis of par...
# 36  You are an expert model in the analysis of par...
# 37  You are an expert model in the analysis of par...
# 38  You are an expert model in the analysis of par...
# 39  You are an expert model in the analysis of par...
# 40  You are an expert model in the analysis of par...
# 41  You are an expert model in the analysis of par...
# 42  You are an expert model in the analysis of par...
# 43  You are an expert model in the analysis of par...
# 44  You are an expert model in the analysis of par...
# 45  You are an expert model in the analysis of par...
# 46  You are an expert model in the analysis of par...
# 47  You are an expert model in the analysis of par...
# 48  You are an expert model in the analysis of par...
# 49  You are an expert model in the analysis of par...
#
#                                                   out  \
# 0   1. **Project Theme and Demand**: The proposed ...
# 1   1. **Project Theme and Historical Success**: T...
# 2   1. **Project Theme and Popularity**: The proje...
# 3   1. **Project Theme and Popularity**: The proje...
# 4   1. **District Voting Patterns**: Psie Pole has...
# 5   1. **District Voting Trends**: Krzyki district...
# 6   1. **District Voting Patterns**: Psie Pole has...
# 7   1. **District Voting Trends**: The district of...
# 8   1. **Project Cost and District Analysis**: The...
# 9   1. **District Voting Trends**: Stare Miasto ha...
# 10  1. **District Analysis**: The project is locat...
# 11  1. **District Voting Trends**: The district of...
# 12  1. **Project Theme and Cost**: The project "Zi...
# 13  1. **District Voting Trends**: Krzyki district...
# 14  1. **Historical Context and Voter Interest**: ...
# 15  1. **Historical Voting Patterns**: In 2016, pr...
# 16  1. **Project Theme and District Analysis**: Th...
# 17  1. **Project Theme and Cost**: The proposed pr...
# 18  1. **District Voting Trends**: Krzyki district...
# 19  1. **District Voting Patterns**: Psie Pole has...
# 20  1. **District Voting Trends**: The district of...
# 21  1. **Project Theme and Cost**: The project "Si...
# 22  1. **Project Theme and Popularity**: The propo...
# 23  1. **District Voting Trends**: Krzyki district...
# 24  1. **District Voting Patterns**: Projects in P...
# 25  1. **Project Cost and District**: The project ...
# 26  1. **District Voting Patterns**: Psie Pole has...
# 27  1. **District Voting Trends**: The district of...
# 28  1. **Project Cost and Appeal**: The project "P...
# 29  1. **Project Cost and Appeal**: The project "M...
# 30  1. **District Voting Trends**: The district of...
# 31  1. **Project Theme and Cost**: The project "Mi...
# 32  1. **Project Theme and Popularity**: The proje...
# 33  1. **District Voting Trends**: The district of...
# 34  1. **District Voting Patterns**: Psie Pole had...
# 35  1. **Project Theme and Cost**: The project "Od...
# 36  1. **District Voting Trends**: Krzyki district...
# 37  1. **Project Theme and Cost**: The project "La...
# 38  1. **Project Cost and Appeal**: The project "I...
# 39  1. **Project Cost and Appeal**: The project "i...
# 40  1. **Project Cost and Appeal**: The project "W...
# 41  1. **Project Theme and Cost**: The project "Wr...
# 42  1. **Project Cost and Appeal**: The proposed p...
# 43  1. **Project Cost and Appeal**: The project "R...
# 44  1. **Project Context and Cost**: The project "...
# 45  1. **Project Cost and Appeal**: The project "A...
# 46  1. **District Voting Trends**: The district of...
# 47  1. **Project Cost and Appeal**: The project "W...
# 48  1. **Project Cost and Appeal**: The project "1...
# 49  1. **Project Cost and Appeal**: The project "P...
#
#                                              out_json  predicted_votes  \
# 0   {'estimated_votes': 4000, 'confidence_interval...      3757.269661
# 1   {'estimated_votes': 4000, 'confidence_interval...      3757.269661
# 2   {'estimated_votes': 4000, 'confidence_interval...      3757.269661
# 3   {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 4   {'estimated_votes': 1600, 'confidence_interval...      1502.907864
# 5   {'estimated_votes': 6000, 'confidence_interval...      5635.904492
# 6   {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 7   {'estimated_votes': 6500, 'confidence_interval...      6105.563199
# 8   {'estimated_votes': 5000, 'confidence_interval...      4696.587077
# 9   {'estimated_votes': 4000, 'confidence_interval...      3757.269661
# 10  {'estimated_votes': 6500, 'confidence_interval...      6105.563199
# 11  {'estimated_votes': 6500, 'confidence_interval...      6105.563199
# 12  {'estimated_votes': 6000, 'confidence_interval...      5635.904492
# 13  {'estimated_votes': 7000, 'confidence_interval...      6575.221907
# 14  {'estimated_votes': 4000, 'confidence_interval...      3757.269661
# 15  {'estimated_votes': 2250, 'confidence_interval...      2113.464184
# 16  {'estimated_votes': 4000, 'confidence_interval...      3757.269661
# 17  {'estimated_votes': 4000, 'confidence_interval...      3757.269661
# 18  {'estimated_votes': 11000, 'confidence_interva...     10332.491568
# 19  {'estimated_votes': 1500, 'confidence_interval...      1408.976123
# 20  {'estimated_votes': 3000, 'confidence_interval...      2817.952246
# 21  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 22  {'estimated_votes': 6500, 'confidence_interval...      6105.563199
# 23  {'estimated_votes': 7000, 'confidence_interval...      6575.221907
# 24  {'estimated_votes': 2500, 'confidence_interval...      2348.293538
# 25  {'estimated_votes': 2750, 'confidence_interval...      2583.122892
# 26  {'estimated_votes': 2100, 'confidence_interval...      1972.566572
# 27  {'estimated_votes': 6500, 'confidence_interval...      6105.563199
# 28  {'estimated_votes': 2500, 'confidence_interval...      2348.293538
# 29  {'estimated_votes': 2500, 'confidence_interval...      2348.293538
# 30  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 31  {'estimated_votes': 3500, 'confidence_interval...      3287.610954
# 32  {'estimated_votes': 5000, 'confidence_interval...      4696.587077
# 33  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 34  {'estimated_votes': 2500, 'confidence_interval...      2348.293538
# 35  {'estimated_votes': 3500, 'confidence_interval...      3287.610954
# 36  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 37  {'estimated_votes': 4000, 'confidence_interval...      3757.269661
# 38  {'estimated_votes': 1800, 'confidence_interval...      1690.771348
# 39  {'estimated_votes': 3000, 'confidence_interval...      2817.952246
# 40  {'estimated_votes': 2000, 'confidence_interval...      1878.634831
# 41  {'estimated_votes': 5500, 'confidence_interval...      5166.245784
# 42  {'estimated_votes': 700, 'confidence_interval'...       657.522191
# 43  {'estimated_votes': 4000, 'confidence_interval...      3757.269661
# 44  {'estimated_votes': 900, 'confidence_interval'...       845.385674
# 45  {'estimated_votes': 3500, 'confidence_interval...      3287.610954
# 46  {'estimated_votes': 6500, 'confidence_interval...      6105.563199
# 47  {'estimated_votes': 1800, 'confidence_interval...      1690.771348
# 48  {'estimated_votes': 2000, 'confidence_interval...      1878.634831
# 49  {'estimated_votes': 3000, 'confidence_interval...      2817.952246
#
#     predicted_rank  is_top5  is_top10
# 0               10        0         1
# 1                8        0         1
# 2                8        0         1
# 3               12        0         0
# 4               20        0         0
# 5                5        1         1
# 6               12        0         1
# 7                8        0         1
# 8                8        0         1
# 9                8        0         1
# 10               6        0         1
# 11               6        0         1
# 12               6        0         1
# 13               4        1         1
# 14              10        0         1
# 15              10        0         1
# 16               8        0         1
# 17               8        0         1
# 18               3        1         1
# 19              15        0         0
# 20              10        0         1
# 21               8        0         1
# 22               8        0         1
# 23               5        1         1
# 24              15        0         0
# 25              15        0         0
# 26              12        0         1
# 27               6        0         1
# 28              15        0         0
# 29              10        0         1
# 30               8        0         1
# 31              12        0         1
# 32               8        0         1
# 33               8        0         1
# 34              10        0         1
# 35              10        0         1
# 36               8        0         1
# 37               8        0         1
# 38              12        0         1
# 39               8        0         1
# 40              10        0         1
# 41               6        0         1
# 42              35        0         0
# 43               8        0         1
# 44              30        0         0
# 45               8        0         1
# 46               6        0         1
# 47              12        0         1
# 48              12        0         0
# 49              10        0         1

# %%
results.to_csv('output/predictions/wrc_rag_cot_full_1.csv', sep=";", index=False)
print('results ready!')
# Out:
# results ready!

# %% [markdown]
# ### SB

# %%
# 1. load data
import os
import pandas as pd
import src.utils as ut
import prompt_builder as pb

from dotenv import load_dotenv
from src.data_loader import load_and_prepare_projects, load_prediction_set
from prompt_utils import tokens_counter, prompt_cost

load_dotenv()

path_16 = 'data/wrc16_projects.csv'
path_17 = 'data/wrc17_projects.csv'

df, df16_shuffled = load_and_prepare_projects(path_16,path_17, city="Wroclaw")

ids_to_predict_path = 'data/wrc17_projects_to_predict.csv'
test = load_prediction_set(df, ids_to_predict_path, city='Wroclaw')
df
# Out:
#      project_id                                       project_name  \
# 0           710  Drzewa dla Wrocławia - nasadzenia w całym mieś...
# 1            15  Zielona rowerowo-piesza obwodnica Wrocławia; E...
# 2           764  Oświetlenie Parku Grabiszyńskiego (Alei Romera...
# 3           685  Plac Zabaw dla Starszaków w parku Grabiszyński...
# 4           379  Parking przy "Dobrzyńskiej" - ułatwienie dojaz...
# ..          ...                                                ...
# 97          422          Akcja Plac - Gry uliczne "Oswajamy beton"
# 98          406  Budowa wrocławskiej wypożyczalni rowerów integ...
# 99          629  Wrocław na dotknięcie ręki – tylfograficzne ma...
# 100         720                                               1997
# 101         677  Polegiwacz - wędrujący mebel do odpoczynku i z...
#
#                                            description  \
# 0    Uzasadnienie\nZnikające drzewa z krajobrazu mi...
# 1                                         Uzasadnienie
# 2    Uzasadnienie\nTaki mamy klimat... że przez pół...
# 3    Uzasadnienie\nPlac Zabaw dla Starszaków w park...
# 4    Uzasadnienie\nProjekt polega na utworzeniu w c...
# ..                                                 ...
# 97   Uzasadnienie\nProjekt zakłada lokowanie w prze...
# 98   Uzasadnienie\nProjekt przeznaczony jest zarówn...
# 99   Uzasadnienie\nRynek i wszystkie miejsca, takie...
# 100  Uzasadnienie\nIdeą projektu "1997" było upamię...
# 101  Uzasadnienie\nPolegiwacz jest przenośnym meble...
#
#                            category     cost      district  votes  \
# 0               greenery/recreation  1000000     Fabryczna  13938
# 1    walking/cycling infrastructure  1000000        Krzyki  12348
# 2                             other  1000000        Krzyki   7291
# 3                       playgrounds   560000        Krzyki   6663
# 4                             roads   750000        Krzyki   6383
# ..                              ...      ...           ...    ...
# 97              greenery/recreation   150000   Śródmieście    236
# 98   walking/cycling infrastructure   600000        Krzyki    178
# 99                            other   130000  Stare Miasto    156
# 100                           other    50000        Krzyki    118
# 101             greenery/recreation   150000   Śródmieście     83
#
#      district_number  rank  year
# 0                1.0     1  2016
# 1                2.0     2  2016
# 2                2.0     3  2016
# 3                2.0     4  2016
# 4                2.0     5  2016
# ..               ...   ...   ...
# 97               4.0    46  2017
# 98               2.0    47  2017
# 99               5.0    48  2017
# 100              2.0    49  2017
# 101              4.0    50  2017
#
# [102 rows x 10 columns]

# %%
conn_params = {
    "host": os.environ["PG_HOST"],
    "database": os.environ["PG_DATABASE"],
    "user": os.environ["PG_USER"],
    "password": os.environ['PG_PASSWORD']
}

#2. build prompt
top_k_voted_16 = pb.get_top_k_projects_from_16_election(df, k=15)
proj_count_avg_by_district= pb.get_project_count_and_avg_votes_by_district(df, city = 'Wroclaw')
proj_count_avg_by_categories = pb.get_project_count_and_avg_votes_by_categories(df, city = 'Wroclaw')

# %%
test['prompt'] = test.apply(
    lambda x: pb.build_prompt(
        'prompts/prompt_rag2_SB_pl.txt',
        {
            'top_k_voted_16': top_k_voted_16,
            'project_count_and_avg_votes_by_district': proj_count_avg_by_district,
            'project_name': x['project_name'],
            'cost': x['cost'],
            'district': x['district'],
            'description': x['description'],
            'top_k_similar_projects_in_16': pb.get_top_k_similar_projects_in_16(df, x['project_id'], x['year'], conn_params,k=5),
            'count_of_projects16_in_quartier': pb.get_count_of_projects_in_quartier(df,x['district'], year=2016),
            'top_k_voted_in_district': pb.get_top_k_voted_in_district_eng(df, x['district'], k=5, year=2016),
            'count_of_projects17_in_quartier': pb.get_count_of_projects_in_quartier(df,x['district'], year=2017),
            'top_k_similar_projects_in_district': pb.get_top_k_similar_projects_in_16_by_district(df, x['project_id'], x['year'], conn_params,k=5)
        }
    ),
    axis=1
)

# %%
print(test['prompt'].iloc[0])
# Out:
# You are an expert model in the analysis of participatory budgeting elections, specifically in the context of the city of Wroclaw, Poland.
#
# In Wroclaw, the municipality organizes participatory budgeting elections to fund citizen-led projects. Each resident can vote for between 1 and 3 initiatives on the official website.
# Votes are anonymous.
#
# Here is how the projects are selected:
# - All projects are ranked by the number of votes received.
# - A "greedy" algorithm is used: projects are funded in descending order of votes, as long as the total budget is not exceeded.
# - If a project is too expensive for the remaining budget, it is skipped and the next one is considered.
#
# ---
# In the 2016 election:
# - There were **67103 voters**, each allowed to vote for up to 3 projects.
# - In total, approximately **119194 votes** were cast across **52 projets**.
# - The number of votes per project ranged from **120** to **13938**, with an average of **2292.19** votes and an estimated standard deviation of **2784.06**.
# - Most projects received between **597** and **2923** votes.
# - The total available budget was **4500000 €**.
#
# In this edition, the 15 most-voted projects were:
#
# - Drzewa dla Wrocławia - nasadzenia w całym mieście!: (Cost: 1000000 €, District: Fabryczna). 13938 Votes, Ranking: 1
# - Zielona rowerowo-piesza obwodnica Wrocławia; Etap I - fragment łącznika Gaj, Wojszyce, Ołtaszyn, Partynice, Jagodno, Tarnogaj Krzyki, Borek.: (Cost: 1000000 €, District: Krzyki). 12348 Votes, Ranking: 2
# - Oświetlenie Parku Grabiszyńskiego (Alei Romera oraz ścieżek do Cmentarza Grabiszyńskiego i ul. Racławickiej wzdłuż polan): (Cost: 1000000 €, District: Krzyki). 7291 Votes, Ranking: 3
# - Plac Zabaw dla Starszaków w parku Grabiszyńskim i coś ekstra dla maluchów: (Cost: 560000 €, District: Krzyki). 6663 Votes, Ranking: 4
# - Parking przy "Dobrzyńskiej" - ułatwienie dojazdu wrocławian do największego w mieście centrum medycznego.: (Cost: 750000 €, District: Krzyki). 6383 Votes, Ranking: 5
# - Posadzenie na terenie Wrocławia młodych drzew: (Cost: 100000 €, District: Fabryczna). 5287 Votes, Ranking: 6
# - Rowerowy Wrocław 2016 – ulice przyjazne rowerzystom: (Cost: 1000000 €, District: Śródmieście). 4799 Votes, Ranking: 7
# - Stoły do ping – ponga i boiska do siatkówki w całym Wrocławiu.: (Cost: 1000000 €, District: Fabryczna). 3974 Votes, Ranking: 8
# - Fontanna Neptuna na Placu Nowy Targ: (Cost: 750000 €, District: Stare Miasto). 3632 Votes, Ranking: 9
# - Budowa nadbrzeża ze slipem dla przyszłej miejskiej przystani łodziowej: (Cost: 1000000 €, District: Krzyki). 3243 Votes, Ranking: 10
# - Rowerowe połączenie Dworca Głównego z pl. Społecznym: (Cost: 1000000 €, District: Psie Pole). 3099 Votes, Ranking: 11
# - Park Jedności– miejska rekreacja: (Cost: 1000000 €, District: Fabryczna). 3026 Votes, Ranking: 12
# - Rozbudowa bazy sportowej na wrocławskich Osobowicach - strefa sportu przy Szkole Podstawowej nr 21: (Cost: 1000000 €, District: Psie Pole). 3008 Votes, Ranking: 13
# - Wydłużenie pasa lewoskrętu w kierunku ulicy Lotniczej na skrzyżowaniu ulic Na Ostatnim Groszu i Legnickiej: (Cost: 750000 €, District: Krzyki). 2901 Votes, Ranking: 14
# - Dokończenie trasy pieszo-rowerowej wokół Wielkiej Wyspy: (Cost: 1000000 €, District: Krzyki). 2260 Votes, Ranking: 15
#
#
# Here is, for each district, the number of projects proposed and the average number of votes received during the 2016 election:
# Fabryczna : 12 Projects, Votes Average: 2775.5833333333335.
# Krzyki : 17 Projects, Votes Average: 3055.823529411765.
# Psie Pole : 10 Projects, Votes Average: 1533.3.
# Stare Miasto : 7 Projects, Votes Average: 1485.2857142857142.
# Śródmieście : 5 Projects, Votes Average: 1554.4.
#
#
# ---
#
# Your task now is to evaluate a new project submitted to the upcoming election, in which **50 projects** have been proposed.
#
# **Project to analyze::**
# - Name: Toalety we Wrocławskich parkach i na terenach rekreacyjnych.
# - Cost: 900000 €
# - District: Śródmieście
# - Description: Uzasadnienie
# W parkach i na terenach zielonych we Wrocławiu brakuje toalet, co utrudnia korzystanie z nich w celach rekreacyjnych przez dłuższy czas.
# Proponujemy instalację toalet (technologia dowolna, prawdopodobnie najlepsze byłyby samoczyszczące i/lub odporne na wandalizm).
# Proponujemy następujące miejsca:
# 1) Park Szczytnicki
# 2) Park Wschodni
# 3) Park Południowy
# 4) Park Tysiąclecia
# 5) Park Zachodni
# 6) Karłowice (Park Kasprowicza lub Polana Karłowicka lub Brodzik)
# Szczegóły umiejscowienia zostaną ustalone z liderem projektu. W przypadku gdyby któryś z ww parków posiadał już toaletę w momencie wygranej projektu, wspólnie z UMW wybierzemy inną lokalizację.
#
# Based on:
# - The voting dynamics observed in 2016.
# - The cost, district, and theme of the project.
# - Your understanding of the social, ecological, and political context of Wroclaw.
#
# ---
#
# Additionally, here is a selection of similar projects across the city, presented during the 2016 election and showing strong semantic similarity with the project under review.
# Each project includes:
#
# - the project name,
# - the district concerned,
# - the estimated cost,
# - the number of votes received,
# - and their position in the final ranking.
#
# - Plac Zabaw dla Starszaków w parku Grabiszyńskim i coś ekstra dla maluchów: (Cost: 560000 €, District: Krzyki). 6663 Votes, Ranking: 4
# - Stoły do ping – ponga i boiska do siatkówki w całym Wrocławiu.: (Cost: 1000000 €, District: Fabryczna). 3974 Votes, Ranking: 8
# - Park Jedności– miejska rekreacja: (Cost: 1000000 €, District: Fabryczna). 3026 Votes, Ranking: 12
# - Niewykorzystany potencjał Parku Skowroniego - rewitalizacja: (Cost: 1000000 €, District: Śródmieście). 1644 Votes, Ranking: 24
# - Toaleta publiczna w Parku Wschodnim: (Cost: 250000 €, District: Psie Pole). 1441 Votes, Ranking: 28
# - Frisbee Golf: (Cost: 85000 €, District: Krzyki). 477 Votes, Ranking: 44
# - Miejskie wyspy zieleni: (Cost: 250000 €, District: Stare Miasto). 990 Votes, Ranking: 32
#
#
# ---
#
# In the district Śródmieście, 5 projects were proposed, and the most-voted ones were:
#
# - Rowerowy Wrocław 2016 – ulice przyjazne rowerzystom: (Cost: 1000000 €). 4799 Votes, Ranking: 7
# - Niewykorzystany potencjał Parku Skowroniego - rewitalizacja: (Cost: 1000000 €). 1644 Votes, Ranking: 24
# - Podwórze pomiędzy ulicami Prusa, Wyszyńskiego, Sępa Sarzyńskiego i Sienkiewicza: (Cost: 750000 €). 526 Votes, Ranking: 41
# - Remont ulicy Glinianej - odcinek Ślężna - Borowska: (Cost: 510000 €). 522 Votes, Ranking: 42
# - Cywilizacja na Wojszycach - Światło dla wszystkich - Zamontowanie miejskich latarni na ulicy Smardzowskiej w Europejskiej Stolicy Kultury: (Cost: 40000 €). 281 Votes, Ranking: 49
#
#
# This year, 7 projects have been proposed in the district.
#
# Here is a selection of similar projects from the previous election located in the same district:
#
# - Rowerowy Wrocław 2016 – ulice przyjazne rowerzystom: (Cost: 1000000 €, District: Śródmieście). 4799 Votes, Ranking: 7
# - Niewykorzystany potencjał Parku Skowroniego - rewitalizacja: (Cost: 1000000 €, District: Śródmieście). 1644 Votes, Ranking: 24
# - Podwórze pomiędzy ulicami Prusa, Wyszyńskiego, Sępa Sarzyńskiego i Sienkiewicza: (Cost: 750000 €, District: Śródmieście). 526 Votes, Ranking: 41
# - Remont ulicy Glinianej - odcinek Ślężna - Borowska: (Cost: 510000 €, District: Śródmieście). 522 Votes, Ranking: 42
# - Cywilizacja na Wojszycach - Światło dla wszystkich - Zamontowanie miejskich latarni na ulicy Smardzowskiej w Europejskiej Stolicy Kultury: (Cost: 40000 €, District: Śródmieście). 281 Votes, Ranking: 49
#
# ---
#
# Please respond in the form of a JSON dictionary with the following keys:
#
# ```json
# {
#     "estimated_votes": X,               // Estimated number of votes (integer)
#     "confidence_interval": [a, b],     // Realistic interval (min, max)
#     "expected_rank": Y,                // Expected rank in the final list
#     "in_top_5": 1 or 0,                // 1 if likely to be in the top 5, else 0
#     "in_top_10": 1 or 0                // 1 if likely to be in the top 10, else 0
# }
# Before giving an answer, take the time to reason deeply, but explain only the essential reasoning.
#
# **OUTPUT INSTRUCTIONS**
# 1. First, take a “step back”:
# 2. In 2 to 3 sentences, summarize the general rules that explain the outcomes of projects in participatory budgeting elections in Wroclaw, Poland (main factors, voting dynamics, etc.).
#
# Then, apply this general framework to the analysis of the project Toalety we Wrocławskich parkach i na terenach rekreacyjnych., listing 5 to 8 key points that justify your estimations.
# At the end, provide only a valid JSON dictionary — no additional text.
