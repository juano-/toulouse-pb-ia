# %% [markdown]
# ### TLS 24

# %%
# 1. load data
import os
import pandas as pd
import src.utils as ut
import prompt_builder as pb

from dotenv import load_dotenv
from src.data_loader import load_and_prepare_projects, load_test_dataset
from prompt_utils import tokens_counter, prompt_cost


path_22 = 'data/tls22_projects.csv'
path_24 = 'data/tls24_projects.csv'

df, df22_shuffled = load_and_prepare_projects(path_22,path_24, city = "Toulouse")
test = load_test_dataset(df, rows = len(df[df['year'] == 2024]), city = 'Toulouse')

load_dotenv()

conn_params = {
    "host": os.environ["PG_HOST"],
    "database": os.environ["PG_DATABASE"],
    "user": os.environ["PG_USER"],
    "password": os.environ['PG_PASSWORD']
}

# %%
#2. build prompt
last_projects_results = pb.get_all_projects_from_22_election(df22_shuffled)

test['prompt'] = test.apply(
    lambda x: pb.build_prompt(
        'prompts/tls_prompt_incontext_fr.txt',
        {
            'last_projects_results': last_projects_results,
            'project_name': x['project_name'],
            'cost': x['cost'],
            'district': x['district'],
            'description': x['description']
        }
    ),
    axis=1
)

# %%
print(test['prompt'].iloc[0])
# Out:
# Vous êtes un modèle expert dans l’analyse des élections de budgets participatifs, spécifiquement dans le contexte de la ville de Toulouse, en France.
#
# À Toulouse, la municipalité organise des élections de budget participatif pour financer des projets citoyens. Chaque habitant peut voter pour entre 1 et 3 initiatives sur le site web officiel.
# Les votes sont anonymes.
#
# Une fois la période de vote terminée, les projets sont classés selon le nombre de voix obtenues et se voient attribuer un rang. Ensuite, les projets gagnants sont sélectionnés à l’aide d’un algorithme greedy : on commence par le projet ayant obtenu le plus de voix, puis on ajoute successivement les projets suivants les plus votés, tant que le budget disponible le permet.
# Lorsque le budget restant ne permet plus de financer le projet suivant dans la liste, on passe au suivant qui peut l’être, et ainsi de suite, jusqu’à épuisement du budget total de 8000000 euros.
#
# Voici la liste des 200 initiatives proposées lors de l’élection, avec leur nom, leur coût et le quartier auquel elles appartiennent :
# - Vélo-rue aux Minimes: (Coût: 30000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 40 Voix, Classement: 96
# - Des arbres pour la rue de la République (végétaliser la place Olivier): (Coût: 150000.0 €, District: 6 - Saint-Cyprien). 135 Voix, Classement: 16
# - Aménagement du site de l’observatoire de Pech-David: (Coût: 95000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 101 Voix, Classement: 31
# - Esthétique des conteneurs de recyclage: (Coût: 4000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 14 Voix, Classement: 159
# - Equipements sportifs: (Coût: 15000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 26 Voix, Classement: 129
# - Des panneaux solaires sur la Maison de Quartier de Bagatelle: (Coût: 68000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 31 Voix, Classement: 116
# - Facilliter la traversée des allées Charles de Fitte: (Coût: 80000.0 €, District: 6 - Saint-Cyprien). 52 Voix, Classement: 70
# - Végétalisation des murs extérieurs de l'école du Grand Selve: (Coût: 30000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 10 Voix, Classement: 171
# - Aire de jeux pour enfants : (Coût: 100000.0 €, District: 6 - Saint-Cyprien). 9 Voix, Classement: 175
# - Mise en place d'un parcours santé et d'aménagements parc de la Mounède: (Coût: 80000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 80 Voix, Classement: 46
# - Végétaliser le square de la Vierge Rouge: (Coût: 100000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 58 Voix, Classement: 67
# - Végétalisation/ réaménagement  du square Bartoli: (Coût: 115000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 7 Voix, Classement: 183
# - La rue Saint Nicolas,  artistique et ...fleurie?: (Coût: 90000.0 €, District: 6 - Saint-Cyprien). 11 Voix, Classement: 166
# - Limiter l'éclairage des équipements - Cartoucherie-Zenith: (Coût: 100000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 50 Voix, Classement: 79
# - Implanter des panneaux signalétiques Lafourguette: (Coût: 1500.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 6 Voix, Classement: 187
# - Eclairage passage piéton : (Coût: 20000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 8 Voix, Classement: 178
# - Stop aux moustiques ! Passons aux pièges ! : (Coût: 5700.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 67 Voix, Classement: 57
# - Création d'un terrain de cécifoot (foot pour non-voyants à Borderouge): (Coût: 150000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 16 Voix, Classement: 153
# - Une structure de jeux au jardin du Barry: (Coût: 150000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 48 Voix, Classement: 83
# - Piste cyclable à double sens route d'Espagne: (Coût: 60000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 52 Voix, Classement: 69
# - Jardin pédagogique: (Coût: 10000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 29 Voix, Classement: 125
# - Rénovation du Parc des Argoulets 🌳🌱🌺🌻: (Coût: 200000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 134 Voix, Classement: 17
# - Arceau pour vélo: (Coût: 35000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 19 Voix, Classement: 149
# - Installer des racks à vélos devant tous les commerces et les zones vertes: (Coût: 6000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 42 Voix, Classement: 94
# - Zone verte des Ponts-Jumeaux : équipements sportifs: (Coût: 150000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 59 Voix, Classement: 66
# - Sécuriser le passage du pont de la Cépière pour les cyclistes: (Coût: 200000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 64 Voix, Classement: 61
# - Installation de composteurs dans les écoles de la ville: (Coût: 35000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 47 Voix, Classement: 85
# - Coup de pinceau sur le béton du quartier: (Coût: 50000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 56 Voix, Classement: 68
# - De l'art sur les murs aveugles: (Coût: 100000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 27 Voix, Classement: 126
# - Plan du voisinage aux sorties de métro: (Coût: 6000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 24 Voix, Classement: 133
# - Aménager le Rond-Point des Français Libres et le carrefour Demoiselles - Mistral - Frizac - Duméril - St Joseph: (Coût: 200000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 178 Voix, Classement: 10
# - Plantation d'arbres et diversification de la palette végétale: (Coût: 70000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 128 Voix, Classement: 19
# - Végétalisation de la ZA Thibaud: (Coût: 60000.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 67 Voix, Classement: 56
# - Lampadaires à détecteur de mouvement piste cyclable Sud canal: (Coût: 50000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 50 Voix, Classement: 76
# - Mettre des poubelles à tous les arrêts de bus: (Coût: 20000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 17 Voix, Classement: 151
# - Arbres fruitiers : (Coût: 40000.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 36 Voix, Classement: 105
# - Toilettes publiques Bois de Limayrac: (Coût: 60000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 23 Voix, Classement: 136
# - Contrôle limitation de vitesse allée de Brienne: (Coût: 50000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 22 Voix, Classement: 138
# - Rendre glamour les bornes de recyclage: (Coût: 10000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 11 Voix, Classement: 165
# -  Radars de bruit et de vitesse sur l'allée de Barcelone/Ponts Jumeaux : (Coût: 30000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 50 Voix, Classement: 77
# - Terrain Multi Activités à proximité du Touch: (Coût: 150000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 49 Voix, Classement: 80
# - Des ralentisseurs boulevard Déodat de Séverac pour plus de sécurité et de quiétude: (Coût: 15000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 2 Voix, Classement: 198
# - Pièges à moustiques tigres: (Coût: 1200.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 91 Voix, Classement: 39
# - Réduction de la pollution lumineuse: (Coût: 50000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 113 Voix, Classement: 25
# - Libérer les pieds des arbres avenue de Muret et route d'Espagne: (Coût: 192000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 29 Voix, Classement: 123
# - Installation de bornes de recharge électrique dans le parc HLM/ZFU: (Coût: 10500.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 2 Voix, Classement: 196
# - Aménagement berge canal du midi : (Coût: 170000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 103 Voix, Classement: 30
# - Aménagement pour La Plaine: (Coût: 60000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 125 Voix, Classement: 20
# - Mettre en sens unique et zone 30 l'avenue de Rangueil: (Coût: 40000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 20 Voix, Classement: 144
# - Rue Negreneys : Un transport pour tous :  piste cyclable continue, sécurité pour les piétons et réduction de la vitesse : (Coût: 150000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 47 Voix, Classement: 87
# - Circuit sportif autour de la Garonne: (Coût: 35000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 32 Voix, Classement: 115
# - Installer des échiquiers au Jardin Claude Nougaro: (Coût: 3000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 9 Voix, Classement: 174
# - Réaménagement piéton, vélos et végétalisation allées Charles de Fitte: (Coût: 175000.0 €, District: 6 - Saint-Cyprien). 206 Voix, Classement: 6
# - Toilettes publiques au Jardin du Barry: (Coût: 60000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 27 Voix, Classement: 127
# - Aménagement du parc Fontaine Lestang (Les Biscottes): (Coût: 44000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 31 Voix, Classement: 118
# - Corriger les discontinuités entre les pistes cyclables Bd Déodat de Séverac, l'arrêt de tram Croix de Pierre et le pont: (Coût: 70000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 51 Voix, Classement: 74
# - Poser des ralentisseurs avenue Albert Bedouce: (Coût: 30000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 21 Voix, Classement: 141
# - Végétaliser nos quartiers (projet étudié autour de la place Émile Male et sur la route de Saint-Simon): (Coût: 130000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 39 Voix, Classement: 99
# - Clarifier les priorités à la sortie de la rue Réclusane: (Coût: 40000.0 €, District: 6 - Saint-Cyprien). 9 Voix, Classement: 173
# - Aménagement allée Joséphine Baker: (Coût: 200000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 39 Voix, Classement: 97
# - De l'art sur les murs aveugles: (Coût: 100000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 10 Voix, Classement: 170
# - Valorisation du tunnel de Gironis: (Coût: 150000.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 39 Voix, Classement: 98
# - Garder arbres, espaces aérés et terrains de foot/baskets autour du dôme de La Grave (plantations d’arbres fruitiers à proximité du terrain de jeux): (Coût: 192000.0 €, District: 6 - Saint-Cyprien). 100 Voix, Classement: 32
# - Végétalisation massive de la place Roguet/ St Cyprien: (Coût: 110000.0 €, District: 6 - Saint-Cyprien). 161 Voix, Classement: 13
# - Végétalisation et convivialité du quartier Saint-Aubin: (Coût: 30000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 94 Voix, Classement: 36
# - Veille sur les dépôts sauvages : (Coût: 35000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 30 Voix, Classement: 120
# - Déployer des équipements préventifs pour démoustiquer le quartier: (Coût: 5700.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 85 Voix, Classement: 43
# - Aire convivialité espace vert rue de l'Isére / rue de l'Invention: (Coût: 75000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 5 Voix, Classement: 190
# - Nichoirs pour des mésanges: (Coût: 6000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 44 Voix, Classement: 91
# - Sécuriser les piétons: (Coût: 150000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 22 Voix, Classement: 137
# - Stations de gonflage pour vélo sur les trajets les plus fréquentés: (Coût: 9000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 74 Voix, Classement: 52
# - City Stade quartier Guilhermy: (Coût: 40000.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 26 Voix, Classement: 128
# - Végétalisation d'ombrage rue Jean Mermoz: (Coût: 100000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 12 Voix, Classement: 163
# - Installation de ruches urbaines: (Coût: 3000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 87 Voix, Classement: 42
# - Voilage d'ombres sur les jeux public de plein air pour enfants: (Coût: 10000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 31 Voix, Classement: 119
# - Un rucher en ville: (Coût: 3000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 33 Voix, Classement: 114
# - Nichoirs à martinets et chauve souris + pièges à larves ou à adulte de moustique tigre: (Coût: 60000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 111 Voix, Classement: 27
# - Toilettes séches dans la zone verte de la Plaine: (Coût: 60000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 21 Voix, Classement: 140
# - Création d’abris pour la faune: (Coût: 4000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 38 Voix, Classement: 101
# - Aménagement de cours "OASIS" à l'école élémentaire Victor Hugo: (Coût: 200000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 33 Voix, Classement: 112
# - Végétalisation de la place du Capitole: (Coût: 200000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 358 Voix, Classement: 3
# - Améliorations possibles Quartier Belfort / Denfert Rochereau: (Coût: 200000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 50 Voix, Classement: 78
# - Végétaliser Croix de Pierre (végétalisation de l'avenue de Muret): (Coût: 200000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 79 Voix, Classement: 47
# - Un city stade pour les enfants de moins de 11ans: (Coût: 65000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 6 Voix, Classement: 188
# - Paniers de basket pour petits: (Coût: 15000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 4 Voix, Classement: 192
# - Créer une forêt urbaine sur les friches de l’ancien Darty: (Coût: 15000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 47 Voix, Classement: 86
# - Installer une «tour-nichoir à hirondelles» dans une zone verte du cœur de quartier Lafourguette: (Coût: 10000.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 13 Voix, Classement: 162
# - Planter des arbres entre la rocade et la voie verte de l'Hers: (Coût: 199500.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 94 Voix, Classement: 37
# - Guinguette Petit Bois: (Coût: 10000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 4 Voix, Classement: 191
# - Un verger pour les enfants du bitume (plantation d’arbres fruitiers dans le quartier ): (Coût: 100000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 64 Voix, Classement: 62
# - Multiplier les points de source de fraicheur et de captation de CO2 dans le quartier : (Coût: 50000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 115 Voix, Classement: 23
# - Végétaliser le parking du cimetière de Croix Daurade: (Coût: 200000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 21 Voix, Classement: 142
# - Végétalisation rond point avenue de Lombez, boulevard Gabriel Koenings et environs: (Coût: 200000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 37 Voix, Classement: 102
# - Végétaliser pour limiter la surchauffe estivale et confort de quartier...: (Coût: 150000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 96 Voix, Classement: 34
# - Réouverture des espaces verts des bords de Garonne aux Toulousains: (Coût: 200000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 164 Voix, Classement: 12
# - Aménagement voie accès Ecole maternelle Victor Hugo: (Coût: 30000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 2 Voix, Classement: 195
# - Installation de tables de jeux place des Pradettes: (Coût: 12000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 14 Voix, Classement: 160
# - Un complexe sportif en zone urbaine: (Coût: 130000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 205 Voix, Classement: 7
# - Redonnons de la couleur aux espaces verts du chemin de la Fronde: (Coût: 45000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 107 Voix, Classement: 28
# - Piste cyclabe chemin Lapujade partie manquante: (Coût: 40000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 30 Voix, Classement: 121
# - Planter des arbres et jardins partagés partout où c'est possible!: (Coût: 20000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 243 Voix, Classement: 5
# - Aménager la place Henri Russel: (Coût: 200000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 98 Voix, Classement: 33
# - Le WorksParc, un complexe sportif en plein air, au croisement entre plusieurs disciplines ( Street Worksout, Chase Tag, Parkour): (Coût: 200000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 21 Voix, Classement: 143
# - Végétaliser les abords des écoles Marengo-Périole: (Coût: 160000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 20 Voix, Classement: 146
# - Voilage d'ombres sur les jeux public de plein air pour enfants: (Coût: 10000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 34 Voix, Classement: 110
# - Pépinière-jardin du quartier Reynerie-Bellefontaine: (Coût: 75000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 20 Voix, Classement: 145
# - Pénaliser les motards bruyants: (Coût: 30000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 174 Voix, Classement: 11
# - Lutter contre la pollution des mégots: (Coût: 30000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 63 Voix, Classement: 63
# - Réduire la pollution sonore: (Coût: 35000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 33 Voix, Classement: 113
# - Installation des toilettes publiques entre la gare d'Arènes et le Carrefour Lombez: (Coût: 14000.0 €, District: 6 - Saint-Cyprien). 19 Voix, Classement: 147
# - Des cendriers aux arrêts de bus / métro / tram : (Coût: 16000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 11 Voix, Classement: 167
# - Piste cyclable avenue Saint-Exupéry: (Coût: 200000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 492 Voix, Classement: 1
# - Espace de jeux Place Niki de St-Phalle: (Coût: 39000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 2 Voix, Classement: 199
# - Végétalisation de la rue Agathoise : (Coût: 150000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 16 Voix, Classement: 154
# - Création d une piste cyclable avenue de la Marcaissonne: (Coût: 200000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 52 Voix, Classement: 71
# - L'ornemental fruitier: (Coût: 1500.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 29 Voix, Classement: 124
# - Composte partagé 'lalala'lande: (Coût: 7000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 61 Voix, Classement: 65
# - Eisenhower : arbres pour pistes cyclables: (Coût: 80000.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 81 Voix, Classement: 45
# - Aménagement parc rue du Canigou: (Coût: 150000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 11 Voix, Classement: 164
# - Végétalisation place saint sernin rue alsace parvis de la gare: (Coût: 200000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 105 Voix, Classement: 29
# - Amélioration pistes cyclables: (Coût: 100000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 88 Voix, Classement: 41
# - Arbre fruitier dans les parcs: (Coût: 25000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 35 Voix, Classement: 109
# - Fresque murale retraçant l'histoire de Montaudran : (Coût: 60000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 15 Voix, Classement: 156
# - Mettre des poubelles à tous les arrêts de bus: (Coût: 10700.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 15 Voix, Classement: 157
# - Restructuration "verte" de la place Roger Arnaud : (Coût: 200000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 112 Voix, Classement: 26
# - Anti-moustiques - Distribuer des nichoirs à chauves-souris: (Coût: 60000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 115 Voix, Classement: 24
# - Bornes publiques de recharge électrique: (Coût: 10500.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 7 Voix, Classement: 185
# - Ajout d'Arbres quartier des Arènes Romaines: (Coût: 70000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 19 Voix, Classement: 148
# - Végétaliser les pieds d'arbres en ville: (Coût: 50000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 49 Voix, Classement: 82
# - Vive l'énergie solaire sur les toits des bâtiments publics !: (Coût: 180000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 90 Voix, Classement: 40
# - Mettre des poubelles à tous les arrêts de bus: (Coût: 10700.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 11 Voix, Classement: 169
# - Remplacer des places de stationnement par des arbres: (Coût: 100000.0 €, District: 6 - Saint-Cyprien). 76 Voix, Classement: 48
# - Personne en situation de handicap: (Coût: 200000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 40 Voix, Classement: 95
# - Aménagement du terrain vague derrière l'école de Pouvourville: (Coût: 80000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 16 Voix, Classement: 155
# - Piste vélos terrifique sur le boulevard Matabiau: (Coût: 200000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 83 Voix, Classement: 44
# - Augmenter l'Installation de L'arbre Algal dans Toulouse: (Coût: 80000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 21 Voix, Classement: 139
# - Lutte anti-moustiques: (Coût: 7500.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 258 Voix, Classement: 4
# - Uritrottoir en plus: (Coût: 14000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 36 Voix, Classement: 106
# - Végétalisation de quartier: (Coût: 55000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 68 Voix, Classement: 54
# - Installer un filtre à pollution Place Job : (Coût: 80000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 24 Voix, Classement: 134
# - Rond point allée Brunaud quartier Roseraie: (Coût: 8000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 8 Voix, Classement: 181
# - Installation arceaux vélo à  Lardenne: (Coût: 15000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 8 Voix, Classement: 179
# - Zone de Street Workout - Jardin Pierre Larousse: (Coût: 20000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 6 Voix, Classement: 186
# - Installer des racks à vélos devant tous les commerces et les zones vertes: (Coût: 6000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 75 Voix, Classement: 50
# - Installation de pièges à moustiques à Croix Daurade: (Coût: 1200.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 49 Voix, Classement: 81
# - Végétaliser la rue Matabiau: (Coût: 200000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 95 Voix, Classement: 35
# - Terrain couvert au niveau du boulodrome: (Coût: 200000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 189 Voix, Classement: 8
# - Propositions de lieux pour des composts: (Coût: 14000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 34 Voix, Classement: 111
# - Du miel dans mon quartier: produisons de la douceur!: (Coût: 10000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 43 Voix, Classement: 92
# - Insectes et oiseaux dans la ville: (Coût: 5320.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 48 Voix, Classement: 84
# - Connaître et mieux préserver les animaux du quartier des Sept-Deniers: (Coût: 5300.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 9 Voix, Classement: 177
# - Construire et installer un four à pain collectif dans le quartier des 7 Deniers: (Coût: 72000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 7 Voix, Classement: 182
# - Végétalisation Place des Tibaous: (Coût: 200000.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 44 Voix, Classement: 90
# - Éclairage nocturne à détecteur de mouvements : (Coût: 200000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 189 Voix, Classement: 9
# - Lutter contre les moustiques avec les chauves-souris: (Coût: 1200.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 155 Voix, Classement: 14
# - Apaisement du Boulevard Riquet: (Coût: 75000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 64 Voix, Classement: 60
# - Piste cyclable chemin Caillibens : (Coût: 50000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 9 Voix, Classement: 172
# - Aménagement d'une halle place Bertier: (Coût: 170000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 25 Voix, Classement: 132
# - Débitumer l’avenue de Lombez et l’avenue de Grande-Bretagne : (Coût: 115000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 130 Voix, Classement: 18
# - Bataille Militaire aux 7 deniers en 1814 (création d’une statue de soldat): (Coût: 60000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 52 Voix, Classement: 73
# - Remplacer les feux tricolores actuels de la Route de Blagnac par des feux récompenses et ajouter de nouveaux feux à tous les passages piétons: (Coût: 55000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 9 Voix, Classement: 176
# - Réhabiliter l’impasse des Minimes : (Coût: 150000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 23 Voix, Classement: 135
# - Faire des stationnements matérialisés avenue des coteaux : (Coût: 115000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 11 Voix, Classement: 168
# - Des jeux pour les grands (aménagement d’une aire de jeux avec des équipements qui ne soient pas uniquement dédiés aux enfants): (Coût: 100000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 7 Voix, Classement: 184
# - Planter des arbres et plantes comestibles: (Coût: 3000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 61 Voix, Classement: 64
# - Piste cyclable et sens unique rue de Périole : (Coût: 50000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 67 Voix, Classement: 55
# - Le développement de l'auto partage: (Coût: 4500.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 35 Voix, Classement: 108
# - Une fresque au coeur du quartier Bourrassol valorisant la nature sur un lieu de vie important pour les habitants: (Coût: 25000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 75 Voix, Classement: 51
# - Réhabilitation du parcours de maniabilité Vélo et VTT: (Coût: 40000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 2 Voix, Classement: 197
# - Arborer la rue Raymond IV: (Coût: 200000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 65 Voix, Classement: 59
# -  Installation d’un parcours de santé au quartier Montaudran vers la Halle de la Machine: (Coût: 150000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 76 Voix, Classement: 49
# - Végétaliser Avenues Biarritz & Casselardit : (Coût: 150000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 46 Voix, Classement: 89
# - Plantations d’arbres fruitiers sur les quartiers de Rangueil, Sauzelong et Jules Julien: (Coût: 50000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 116 Voix, Classement: 22
# - Une piste cyclable pour une meilleure continuité rue Henri Desbals: (Coût: 45000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 66 Voix, Classement: 58
# - Plus de bancs dans les rues: (Coût: 10000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 13 Voix, Classement: 161
# - Ralentisseurs chemin du Touch: (Coût: 60000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 3 Voix, Classement: 193
# - Aire sportive et ludique intergénérationnelle autour d'un pumptrack: (Coût: 150000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 26 Voix, Classement: 130
# - Voie verte pour aller à Pech David: (Coût: 200000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 93 Voix, Classement: 38
# - Aire de jeux accessible à tous au jardin du Pays d'Oc: (Coût: 30000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 14 Voix, Classement: 158
# - La Gironde conviviale et sportive (aménagement du parc du Couserans): (Coût: 26000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 3 Voix, Classement: 194
# - Faire des voies vélos et piétons dédiées et bien délimitées: (Coût: 150000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 467 Voix, Classement: 2
# - Poursuivre la piste cyclable allée de Brienne jusqu’à l’avenue Paul-Séjourné: (Coût: 200000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 71 Voix, Classement: 53
# - De l'art sur les murs aveugles: (Coût: 100000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 17 Voix, Classement: 150
# - Aménager le Parc des Sept-Deniers avec un parcours sportif écologique: (Coût: 25000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 25 Voix, Classement: 131
# - Amélioration de l'aire de jeux du square Mady de la Giraudière: (Coût: 60000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 17 Voix, Classement: 152
# - Création d'une Venelle  quartier Soupetard Roseraie- accès - entre Rue Louis Plana et  quartier Guillaumet: (Coût: 100000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 36 Voix, Classement: 104
# - Désimperméabiliser et végétaliser le carrefour Ducuing/Salade Ponsan: (Coût: 200000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 38 Voix, Classement: 100
# - Zone de Street Workout - Parc de la boisseraie: (Coût: 20000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 31 Voix, Classement: 117
# - Kiosque au Jardin Michelet: (Coût: 10000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 46 Voix, Classement: 88
# - Un jardin en mouvement le long de la voie ferrée et le rectorat: (Coût: 11000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 50 Voix, Classement: 75
# - Compostage commun/jardin participatif - Croix de PIerre: (Coût: 7000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 30 Voix, Classement: 122
# - Abribus chemin de Lanusse: (Coût: 10000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 0 Voix, Classement: 200
# - Nichoirs à martinets et chauve souris + pièges à larves ou à adulte de moustique tigre: (Coût: 11200.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 125 Voix, Classement: 21
# - Augmenter l'Installation de L'arbre Algal dans Toulouse: (Coût: 80000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 5 Voix, Classement: 189
# - Des arbres dans la cour d'école de Soupetard: (Coût: 30000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 52 Voix, Classement: 72
# - Un Parcours Santé au bord du Touch: (Coût: 35000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 36 Voix, Classement: 107
# - Faire de la Place Amat Massot ... une place ECO-CITOYENNE conviviale !: (Coût: 200000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 145 Voix, Classement: 15
# - Un double sens cyclable entre l'usine Airbus Saint-Eloi et le Canal du midi  (Chemin du Sang de Serp): (Coût: 60000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 43 Voix, Classement: 93
# - Jeux d'Ooo dans la ville: (Coût: 20000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 8 Voix, Classement: 180
# - Prévoir des pistes cyclables sécurisées pour relier le quartier des Sept-Deniers à Ginestous: (Coût: 200000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 36 Voix, Classement: 103
#
#
# Votre tâche consiste à analyser le projet suivant, proposé dans le cadre d'une nouvelle élection de budget participatif.
#
# Projet : Multiplier les places de stationnement pour les vélos en hypercentre
# Coût : 12000.0 €
# Quartier : 1 - Capitole / Arnaud Bernard / Carmes
# Description : Même si des efforts notables ont déjà été effectués, vouloir développer la part modale du vélo dans les déplacements exige d'accroître très sensiblement les possibilités d'accroche des vélos, notamment dans l'hyper centre. Les places de stationnement sont très insuffisantes autour de la place du Capitole, place Wilson, Place St Pierre, Place Arnaud Bernard, autour de St Sernin, Boulevards Carnot, Strasbourg, Arcole, rues Alsace-Lorraine, Mirepoix, Pargaminières, Rémusat, Taur, Gambetta, etc.🔎 CE QUE PRÉVOIENT LES SERVICES : Dans le cadre de ses projets d'aménagement urbain, la Collectivité intègre systématiquement du mobilier de type accroche pour les vélos.Le déploiement de mobilier urbain de type racks à vélos dans l'hyper centre s'effectue selon les besoins signalés par les riverains et usagers (sollicitation auprès du Maire de Quartier ou de la plateforme AlloToulouse 05 61 222 222) sous réserve de l'avis de l'Architecte des Bâtiments de France et de la disponibilité sur l'espace public déjà très contraint.Dans le cadre de ce dispositif, il est proposé d'installer, a minima, une cinquantaine de racks vélos par an sur le quartier 1.
#
# En vous basant sur :
#
# - Votre connaissance de Toulouse, de son contexte urbain, ainsi que de ses problématiques sociales et environnementales
# - Les caractéristiques du projet (thème, coût, quartier, etc.)
# - Les similarités avec des projets antérieurs ayant obtenu des voix
# - Les dynamiques typiques de vote dans les élections participatives
#
# Veuillez répondre aux questions suivantes concernant ce projet :
#
# 1. Quelle estimation raisonnable du nombre de voix ce projet pourrait-il obtenir ?
# 2. Quelle serait sa position attendue dans le classement final ?
#
# Veuillez répondre sous la forme d’un dictionnaire JSON avec les clés suivantes :
#
# ```json
# {
#   "voix_estimées": X,                // Nombre estimé de voix (entier)
#   "intervalle_confiance": [a, b],   // Intervalle réaliste (min, max)
#   "position_attendue": Y,           // Rang estimé dans le classement
#   "dans_top_5": 1 ou 0,             // 1 si probable d'être dans le top 5, sinon 0
#   "dans_top_10": 1 ou 0             // 1 si probable d'être dans le top 10, sinon 0
# }
# ```
# Avant de donner une réponse, prenez le temps de raisonner en profondeur, mais expliquez seulement le raisonnement essentiel.
#
# **INSTRUCTIONS DE SORTIE**
# 1. Exposez votre raisonnement en 5 à 8 points clés maximum, de façon concise.
# 2. À la fin, fournissez uniquement un dictionnaire JSON valide, sans autre texte.

# %%
test['n_tokens'] = test['prompt'].apply(lambda p: tokens_counter(p))
test['cost_usd'] = test['n_tokens'].apply(lambda n_tokens: prompt_cost(n_tokens, 'gpt-4-turbo'))

print('mean tokens by prompt: {:.2f}'.format(test.n_tokens.mean()))
print('avg.cost of each prediction: ${:.2f}'.format(test.cost_usd.mean()))
print('experiment total cost: {:.2f}'.format(test.cost_usd.sum()))
# Out:
# mean tokens by prompt: 13513.34
# avg.cost of each prediction: $0.14
# experiment total cost: 24.73

# %%
#3. run experiment! :)
api_key=os.getenv('OPENAI_API_KEY')
from llm_client import call_openai_model 

test['out'] = test['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))

# %%
import json
import re

def get_json_from_llm_response(out):
    
    if isinstance(out, str):
        try:
            data = json.loads(out)
            if isinstance(data, dict):
                return data
        except json.JSONDecodeError:
            pass

    match = re.search(r"```json\s*({.*?})\s*```", out, re.DOTALL)
    if match:
        json_str = match.group(1)
        try:
            return json.loads(json_str)
        except json.JSONDecodeError:
            return None

    return None

def get_predicted_votes(df, out_json, city = 'Toulouse'):
    
    if city != 'Toulouse':
        raise ValueError(f"City '{city}' not supported")

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
    
    votes_2022 = df[df['year'] == 2022].votes.sum()
    votes_2024 = df[df['year'] == 2024].votes.sum()

    relative_estimation = out_json['voix_estimées'] / votes_2022
    adjusted_prediction = relative_estimation * votes_2024

    return adjusted_prediction

def get_predicted_rank(out_json):
    
    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['position_attendue']


def get_if_is_top5(out_json):

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['dans_top_5']

def get_if_is_top10(out_json):

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['dans_top_10']

test['out_json'].iloc[0]

# %%
test['out_json'] = test['out'].apply(
    lambda o: get_json_from_llm_response(o))

# %%
test['predicted_votes'] = test['out_json'].apply(lambda x: ut.get_predicted_votes(df, x))
test['predicted_rank'] = test['out_json'].apply(lambda x: ut.get_predicted_rank(x))
test['is_top5'] = test['out_json'].apply(lambda x: ut.get_if_is_top5(x))
test['is_top10'] = test['out_json'].apply(lambda x: ut.get_if_is_top10(x))

# %%
results = test.filter(['project_id', 
             'real_votes', 
             'real_rank',
             'prompt',
             'out',
             'out_json', 
             'predicted_votes', 
             'predicted_rank', 
             'is_top5', 
             'is_top10']
             )

results

# %%
results.to_csv('output/predictions/tls_incontext_prompt.csv', sep=";", index=False)
print('results ready!')

# %% [markdown]
# #### TLS 24

# %%
# 1. load data
import os
import pandas as pd
import src.utils as ut
import prompt_builder as pb

from dotenv import load_dotenv
from src.data_loader import load_and_prepare_projects, load_test_dataset
from prompt_utils import tokens_counter, prompt_cost


path_22 = 'data/tls22_projects.csv'
path_24 = 'data/tls24_projects.csv'

df, df22_shuffled = load_and_prepare_projects(path_22,path_24, city = "Toulouse")
test = load_test_dataset(df, rows = len(df[df['year'] == 2024]), city = 'Toulouse')

load_dotenv()

conn_params = {
    "host": os.environ["PG_HOST"],
    "database": os.environ["PG_DATABASE"],
    "user": os.environ["PG_USER"],
    "password": os.environ['PG_PASSWORD']
}

# %%
#2. build prompt

last_projects_results = pb.get_all_projects_from_22_election(df22_shuffled)

test['prompt'] = test.apply(
    lambda x: pb.build_prompt(
        'prompts/prompt_in_context_fr.txt',
        {
            'last_projects_results': last_projects_results,
            'project_name': x['project_name'],
            'cost': x['cost'],
            'district': x['district'],
            'description': x['description']
        }
    ),
    axis=1
)

# %%
print(test['prompt'].iloc[0])

# %%
test['n_tokens'] = test['prompt'].apply(lambda p: tokens_counter(p))
test['cost_usd'] = test['n_tokens'].apply(lambda n_tokens: prompt_cost(n_tokens, 'gpt-4-turbo'))

print('mean tokens by prompt: {:.2f}'.format(test.n_tokens.mean()))
print('avg.cost of each prediction: ${:.2f}'.format(test.cost_usd.mean()))
print('experiment total cost: {:.2f}'.format(test.cost_usd.sum()))

# %%
#3. run experiment! :)
api_key=os.getenv('OPENAI_API_KEY')
from llm_client import call_openai_model 

test['out'] = test['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))

# %%
import json
import re

def get_json_from_llm_response(out):
    
    if isinstance(out, str):
        try:
            data = json.loads(out)
            if isinstance(data, dict):
                return data
        except json.JSONDecodeError:
            pass

    match = re.search(r"```json\s*({.*?})\s*```", out, re.DOTALL)
    if match:
        json_str = match.group(1)
        try:
            return json.loads(json_str)
        except json.JSONDecodeError:
            return None

    return None

def get_predicted_votes(df, out_json, city = 'Toulouse'):
    
    if city != 'Toulouse':
        raise ValueError(f"City '{city}' not supported")

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
    
    votes_2022 = df[df['year'] == 2022].votes.sum()
    votes_2024 = df[df['year'] == 2024].votes.sum()

    relative_estimation = out_json['voix_estimées'] / votes_2022
    adjusted_prediction = relative_estimation * votes_2024

    return adjusted_prediction

def get_predicted_rank(out_json):
    
    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['position_attendue']


def get_if_is_top5(out_json):

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['dans_top_5']

def get_if_is_top10(out_json):

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['dans_top_10']

# %%
test['out_json'] = test['out'].apply(
    lambda o: get_json_from_llm_response(o))

test['out_json'].iloc[0]

# %%
test['predicted_votes'] = test['out_json'].apply(lambda x: get_predicted_votes(df, x))
test['predicted_rank'] = test['out_json'].apply(lambda x: get_predicted_rank(x))
test['is_top5'] = test['out_json'].apply(lambda x: get_if_is_top5(x))
test['is_top10'] = test['out_json'].apply(lambda x: get_if_is_top10(x))

# %%
#4. save results.
results = test.filter(['project_id', 
             'real_votes', 
             'real_rank',
             'prompt',
             'out',
             'out_json', 
             'predicted_votes', 
             'predicted_rank', 
             'is_top5', 
             'is_top10']
             )
results

# %%
results.to_csv('output/predictions/tls_in_context_full_1.csv', sep=";", index=False)
print('results ready!')

# %% [markdown]
# #### Tls 24 - In-Context (English DB)

# %%
# 1. load data
import os
import pandas as pd
import src.utils as ut
import prompt_builder as pb

from dotenv import load_dotenv
from src.data_loader import load_and_prepare_projects, load_test_dataset
from prompt_utils import tokens_counter, prompt_cost

load_dotenv()

conn_params = {
    "host": os.environ["PG_HOST"],
    "database": os.environ["PG_DATABASE"],
    "user": os.environ["PG_USER"],
    "password": os.environ['PG_PASSWORD']
}

path_22 = 'data/tls22_projects.csv'
path_24 = 'data/tls24_projects.csv'

df, df22_shuffled = load_and_prepare_projects(path_22,path_24, city = "Toulouse")
test = load_test_dataset(df, rows = len(df[df['year'] == 2024]), city = 'Toulouse')

english_df  = pd.read_csv("data/tls_projects_translated_to_eng.csv", sep=";")

df = pd.merge(
    left=df,
    right=english_df,
    on=['project_id','year'],
    how='inner'
)

df22_shuffled = pd.merge(
    left=df22_shuffled,
    right=english_df,
    on=['project_id','year'],
    how='inner'
)

test = pd.merge(left=test,
         right=english_df,
         on=['project_id'],
         how='inner')

# %%
#2. build prompt
last_projects_results = pb.get_all_projects_from_22_election_eng(df22_shuffled)

test['prompt'] = test.apply(
    lambda x: pb.build_prompt(
        'prompts/tls_prompt_incontext_eng.txt',
        {
            'last_projects_results': last_projects_results,
            'project_name': x['project_name_eng'],
            'cost': x['cost'],
            'district': x['district'],
            'description': x['description_eng']
        }
    ),
    axis=1
)

# %%
print(test['prompt'].iloc[0])
# Out:
# You are an expert model in analyzing participatory budgeting elections, specifically in the context of the city of Toulouse, France.
#
# In Toulouse, the municipality organizes participatory budgeting elections to fund citizen-led projects. Each resident can vote for between 1 and 3 initiatives via the official website.
# Votes are anonymous.
#
# Once the voting period ends, projects are ranked according to the number of votes received. Each project is assigned a position in the ranking. Then, the winning projects are selected using a greedy algorithm: funding starts with the most voted project and continues down the list, as long as the available budget allows.
# If the next project cannot be funded due to insufficient remaining budget, the algorithm skips it and moves to the next affordable one — continuing this way until the entire €8,000,000 budget is allocated.
#
# Below is the list of the 200 initiatives proposed in the previous election, including their name, cost, and district:
# - Bike street in Les Minimes: (Cost: 30000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 40 Votes, Ranking: 96
# - Trees for Rue de la République (greening Place Olivier): (Cost: 150000.0 €, District: 6 - Saint-Cyprien). 135 Votes, Ranking: 16
# - Development of the Pech-David observatory site: (Cost: 95000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 101 Votes, Ranking: 31
# - Aesthetics of Recycling Bins: (Cost: 4000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 14 Votes, Ranking: 159
# - Sports equipment: (Cost: 15000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 26 Votes, Ranking: 129
# - Solar panels on the Bagatelle Neighborhood House: (Cost: 68000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 31 Votes, Ranking: 116
# - Facilitate the crossing of Charles de Fitte alleys: (Cost: 80000.0 €, District: 6 - Saint-Cyprien). 52 Votes, Ranking: 70
# - Greening of the exterior walls of the Grand Selve school: (Cost: 30000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 10 Votes, Ranking: 171
# - Children's playground: (Cost: 100000.0 €, District: 6 - Saint-Cyprien). 9 Votes, Ranking: 175
# - Implementation of a health trail and facilities at Mounède Park: (Cost: 80000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 80 Votes, Ranking: 46
# - Greening the Square of the Red Virgin: (Cost: 100000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 58 Votes, Ranking: 67
# - Greening/ redevelopment of Bartoli Square: (Cost: 115000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 7 Votes, Ranking: 183
# - Saint Nicolas Street, artistic and ... flowered?: (Cost: 90000.0 €, District: 6 - Saint-Cyprien). 11 Votes, Ranking: 166
# - Limit the lighting of the equipment - Cartoucherie-Zenith: (Cost: 100000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 50 Votes, Ranking: 79
# - Install Lafourguette signage panels: (Cost: 1500.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 6 Votes, Ranking: 187
# - Pedestrian crossing lighting: (Cost: 20000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 8 Votes, Ranking: 178
# - Stop the mosquitoes! Let's switch to traps!: (Cost: 5700.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 67 Votes, Ranking: 57
# - Creation of a blind football field in Borderouge: (Cost: 150000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 16 Votes, Ranking: 153
# - A playground in the Barry garden: (Cost: 150000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 48 Votes, Ranking: 83
# - Two-way cycle path on Route d'Espagne: (Cost: 60000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 52 Votes, Ranking: 69
# - Educational garden: (Cost: 10000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 29 Votes, Ranking: 125
# - Renovation of the Parc des Argoulets 🌳🌱🌺🌻: (Cost: 200000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 134 Votes, Ranking: 17
# - Bike rack: (Cost: 35000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 19 Votes, Ranking: 149
# - Install bike racks in front of all businesses and green spaces.: (Cost: 6000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 42 Votes, Ranking: 94
# - Twin Bridges Green Zone: sports facilities: (Cost: 150000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 59 Votes, Ranking: 66
# - Secure the crossing of the Cépière bridge for cyclists: (Cost: 200000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 64 Votes, Ranking: 61
# - Installation of composters in the city's schools: (Cost: 35000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 47 Votes, Ranking: 85
# - Brushstroke on the neighborhood's concrete: (Cost: 50000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 56 Votes, Ranking: 68
# - Art on the blind walls: (Cost: 100000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 27 Votes, Ranking: 126
# - Neighborhood map at metro exits: (Cost: 6000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 24 Votes, Ranking: 133
# - Develop the Rond-Point des Français Libres and the Demoiselles - Mistral - Frizac - Duméril - St Joseph intersection.: (Cost: 200000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 178 Votes, Ranking: 10
# - Tree planting and diversification of the plant palette: (Cost: 70000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 128 Votes, Ranking: 19
# - Greening of the Thibaud Business Area: (Cost: 60000.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 67 Votes, Ranking: 56
# - Motion sensor street lamps South canal bike path: (Cost: 50000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 50 Votes, Ranking: 76
# - Place trash cans at all bus stops: (Cost: 20000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 17 Votes, Ranking: 151
# - Fruit trees: (Cost: 40000.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 36 Votes, Ranking: 105
# - Public Toilets Bois de Limayrac: (Cost: 60000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 23 Votes, Ranking: 136
# - Speed control on Allée de Brienne: (Cost: 50000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 22 Votes, Ranking: 138
# - Making recycling bins glamorous: (Cost: 10000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 11 Votes, Ranking: 165
# - Noise and speed radars on the Barcelona Alley/Twin Bridges: (Cost: 30000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 50 Votes, Ranking: 77
# - Multi-Activity Terrain near the Touch: (Cost: 150000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 49 Votes, Ranking: 80
# - Speed bumps on Boulevard Déodat de Séverac for more safety and tranquility: (Cost: 15000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 2 Votes, Ranking: 198
# - Tiger mosquito traps: (Cost: 1200.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 91 Votes, Ranking: 39
# - Reduction of Light Pollution: (Cost: 50000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 113 Votes, Ranking: 25
# - Free the trees' feet on Avenue de Muret and Route d'Espagne: (Cost: 192000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 29 Votes, Ranking: 123
# - Installation of electric charging stations in the HLM/ZFU park: (Cost: 10500.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 2 Votes, Ranking: 196
# - Canal du Midi bank landscaping: (Cost: 170000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 103 Votes, Ranking: 30
# - Development for La Plaine: (Cost: 60000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 125 Votes, Ranking: 20
# - Make Rangueil Avenue one-way and a 30 km/h zone.: (Cost: 40000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 20 Votes, Ranking: 144
# - Negreneys Street: Transportation for all: continuous bike path, safety for pedestrians, and speed reduction.: (Cost: 150000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 47 Votes, Ranking: 87
# - Sports Circuit around the Garonne: (Cost: 35000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 32 Votes, Ranking: 115
# - Install chessboards at Claude Nougaro Garden: (Cost: 3000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 9 Votes, Ranking: 174
# - Pedestrian redevelopment, bicycle lanes, and greening of Charles de Fitte avenues: (Cost: 175000.0 €, District: 6 - Saint-Cyprien). 206 Votes, Ranking: 6
# - Public Toilets at the Jardin du Barry: (Cost: 60000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 27 Votes, Ranking: 127
# - Development of Fontaine Lestang Park (Les Biscottes): (Cost: 44000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 31 Votes, Ranking: 118
# - Correct the discontinuities between the bike lanes on Bd Déodat de Séverac, the Croix de Pierre tram stop, and the bridge.: (Cost: 70000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 51 Votes, Ranking: 74
# - Installing speed bumps on Avenue Albert Bedouce: (Cost: 30000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 21 Votes, Ranking: 141
# - Greening our neighborhoods (project studied around Place Émile Male and on the road to Saint-Simon): (Cost: 130000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 39 Votes, Ranking: 99
# - Clarify priorities upon exiting Rue Réclusane: (Cost: 40000.0 €, District: 6 - Saint-Cyprien). 9 Votes, Ranking: 173
# - Joséphine Baker Walkway Development: (Cost: 200000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 39 Votes, Ranking: 97
# - Art on the blind walls: (Cost: 100000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 10 Votes, Ranking: 170
# - Enhancement of the Gironis Tunnel: (Cost: 150000.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 39 Votes, Ranking: 98
# - Preserve trees, airy spaces, and soccer/basketball courts around the La Grave dome (planting of fruit trees near the playground): (Cost: 192000.0 €, District: 6 - Saint-Cyprien). 100 Votes, Ranking: 32
# - Massive greening of Roguet/St Cyprien square: (Cost: 110000.0 €, District: 6 - Saint-Cyprien). 161 Votes, Ranking: 13
# - Greening and conviviality of the Saint-Aubin neighborhood: (Cost: 30000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 94 Votes, Ranking: 36
# - Watch over illegal dumping sites: (Cost: 35000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 30 Votes, Ranking: 120
# - Deploy preventive equipment to mosquito-proof the neighborhood: (Cost: 5700.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 85 Votes, Ranking: 43
# - Friendliness area green space Rue de l'Isère / Rue de l'Invention: (Cost: 75000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 5 Votes, Ranking: 190
# - Nesting Boxes for Tits: (Cost: 6000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 44 Votes, Ranking: 91
# - Securing pedestrians: (Cost: 150000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 22 Votes, Ranking: 137
# - Bike inflation stations on the busiest routes: (Cost: 9000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 74 Votes, Ranking: 52
# - Guilhermy Neighborhood City Stadium: (Cost: 40000.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 26 Votes, Ranking: 128
# - Shade Greening on Rue Jean Mermoz: (Cost: 100000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 12 Votes, Ranking: 163
# - Installation of Urban Beehives: (Cost: 3000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 87 Votes, Ranking: 42
# - Sheer curtains of shadows over public outdoor playgrounds for children: (Cost: 10000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 31 Votes, Ranking: 119
# - A beehive in the city: (Cost: 3000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 33 Votes, Ranking: 114
# - Swift and bat nesting boxes + traps for tiger mosquito larvae or adults: (Cost: 60000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 111 Votes, Ranking: 27
# - Dry toilets in the green zone of La Plaine: (Cost: 60000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 21 Votes, Ranking: 140
# - Creation of shelters for wildlife: (Cost: 4000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 38 Votes, Ranking: 101
# - "OASIS" schoolyard redevelopment at Victor Hugo Elementary School: (Cost: 200000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 33 Votes, Ranking: 112
# - Greening of the Place du Capitole: (Cost: 200000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 358 Votes, Ranking: 3
# - Possible Improvements Belfort / Denfert Rochereau District: (Cost: 200000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 50 Votes, Ranking: 78
# - Greening Croix de Pierre (greening of Avenue de Muret): (Cost: 200000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 79 Votes, Ranking: 47
# - A city stadium for children under 11 years old: (Cost: 65000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 6 Votes, Ranking: 188
# - Basketball hoops for kids: (Cost: 15000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 4 Votes, Ranking: 192
# - Create an urban forest on the wastelands of the former Darty: (Cost: 15000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 47 Votes, Ranking: 86
# - Install a "swallow nest tower" in a green area in the heart of the Lafourguette district.: (Cost: 10000.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 13 Votes, Ranking: 162
# - Plant trees between the ring road and the greenway of the Hers: (Cost: 199500.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 94 Votes, Ranking: 37
# - Petit Bois Tavern: (Cost: 10000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 4 Votes, Ranking: 191
# - An orchard for the children of the asphalt (planting of fruit trees in the neighborhood): (Cost: 100000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 64 Votes, Ranking: 62
# - Increase the number of sources of freshness and CO2 capture in the neighborhood: (Cost: 50000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 115 Votes, Ranking: 23
# - Greening the Croix Daurade cemetery parking lot: (Cost: 200000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 21 Votes, Ranking: 142
# - Greening of the roundabout at Avenue de Lombez, Boulevard Gabriel Koenings, and surrounding areas: (Cost: 200000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 37 Votes, Ranking: 102
# - Planting vegetation to limit summer overheating and neighborhood comfort...: (Cost: 150000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 96 Votes, Ranking: 34
# - Reopening of the green spaces along the Garonne to the people of Toulouse: (Cost: 200000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 164 Votes, Ranking: 12
# - Development of the access road to Victor Hugo Nursery School: (Cost: 30000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 2 Votes, Ranking: 195
# - Installation of game tables at Place des Pradettes: (Cost: 12000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 14 Votes, Ranking: 160
# - A sports complex in an urban area: (Cost: 130000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 205 Votes, Ranking: 7
# - Let's restore color to the green spaces of Chemin de la Fronde: (Cost: 45000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 107 Votes, Ranking: 28
# - Missing section of the Lapujade cycle path: (Cost: 40000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 30 Votes, Ranking: 121
# - Plant trees and shared gardens wherever possible!: (Cost: 20000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 243 Votes, Ranking: 5
# - Developing Henri Russel Square: (Cost: 200000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 98 Votes, Ranking: 33
# - The WorksParc, an outdoor sports complex, at the intersection of several disciplines (Street Workout, Chase Tag, Parkour): (Cost: 200000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 21 Votes, Ranking: 143
# - Greening the surroundings of the Marengo-Périole schools: (Cost: 160000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 20 Votes, Ranking: 146
# - Shade veils over public outdoor playgrounds for children: (Cost: 10000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 34 Votes, Ranking: 110
# - Reynerie-Bellefontaine neighborhood nursery-garden: (Cost: 75000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 20 Votes, Ranking: 145
# - Penalize Noisy Bikers: (Cost: 30000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 174 Votes, Ranking: 11
# - Fighting against cigarette butt pollution: (Cost: 30000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 63 Votes, Ranking: 63
# - Reducing Noise Pollution: (Cost: 35000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 33 Votes, Ranking: 113
# - Installation of public toilets between Arènes station and Carrefour Lombez: (Cost: 14000.0 €, District: 6 - Saint-Cyprien). 19 Votes, Ranking: 147
# - Ashtrays at bus / metro / tram stops: (Cost: 16000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 11 Votes, Ranking: 167
# - Bike lane on Saint-Exupéry Avenue: (Cost: 200000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 492 Votes, Ranking: 1
# - Play Area Niki de St-Phalle Square: (Cost: 39000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 2 Votes, Ranking: 199
# - Greening of Agathoise Street: (Cost: 150000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 16 Votes, Ranking: 154
# - Creation of a bicycle lane on Avenue de la Marcaissonne: (Cost: 200000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 52 Votes, Ranking: 71
# - The ornamental fruit tree: (Cost: 1500.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 29 Votes, Ranking: 124
# - Shared Compost 'lalala'land: (Cost: 7000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 61 Votes, Ranking: 65
# - Eisenhower: Trees for Bike Paths: (Cost: 80000.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 81 Votes, Ranking: 45
# - Canigou Street Park Development: (Cost: 150000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 11 Votes, Ranking: 164
# - Greening of Place Saint Sernin, Rue Alsace, and the forecourt of the station: (Cost: 200000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 105 Votes, Ranking: 29
# - Improvement of cycle paths: (Cost: 100000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 88 Votes, Ranking: 41
# - Fruit tree in the parks: (Cost: 25000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 35 Votes, Ranking: 109
# - Mural depicting the history of Montaudran: (Cost: 60000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 15 Votes, Ranking: 156
# - Place trash cans at all bus stops: (Cost: 10700.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 15 Votes, Ranking: 157
# - "Green" Restructuring of Roger Arnaud Square: (Cost: 200000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 112 Votes, Ranking: 26
# - Mosquito Repellent - Distributing Bat Houses: (Cost: 60000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 115 Votes, Ranking: 24
# - Public electric charging stations: (Cost: 10500.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 7 Votes, Ranking: 185
# - Adding Trees to the Roman Arenas Neighborhood: (Cost: 70000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 19 Votes, Ranking: 148
# - Greening the bases of trees in the city: (Cost: 50000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 49 Votes, Ranking: 82
# - Long live solar energy on the rooftops of public buildings!: (Cost: 180000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 90 Votes, Ranking: 40
# - Place trash cans at all bus stops: (Cost: 10700.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 11 Votes, Ranking: 169
# - Replace parking spaces with trees: (Cost: 100000.0 €, District: 6 - Saint-Cyprien). 76 Votes, Ranking: 48
# - Person with disabilities: (Cost: 200000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 40 Votes, Ranking: 95
# - Development of the vacant lot behind the Pouvourville school: (Cost: 80000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 16 Votes, Ranking: 155
# - Terrifying bike lane on Matabiau Boulevard: (Cost: 200000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 83 Votes, Ranking: 44
# - Increase the Installation of the Algal Tree in Toulouse: (Cost: 80000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 21 Votes, Ranking: 139
# - Mosquito Control: (Cost: 7500.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 258 Votes, Ranking: 4
# - Uritrottoir in addition: (Cost: 14000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 36 Votes, Ranking: 106
# - Neighborhood Greening: (Cost: 55000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 68 Votes, Ranking: 54
# - Install a pollution filter at Place Job: (Cost: 80000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 24 Votes, Ranking: 134
# - Brunaud Alley roundabout, Roseraie district: (Cost: 8000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 8 Votes, Ranking: 181
# - Bike rack installation in Lardenne: (Cost: 15000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 8 Votes, Ranking: 179
# - Street Workout Area - Pierre Larousse Garden: (Cost: 20000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 6 Votes, Ranking: 186
# - Install bike racks in front of all businesses and green spaces.: (Cost: 6000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 75 Votes, Ranking: 50
# - Installation of mosquito traps in Croix Daurade: (Cost: 1200.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 49 Votes, Ranking: 81
# - Greening Matabiau Street: (Cost: 200000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 95 Votes, Ranking: 35
# - Land covered at the level of the boulodrome: (Cost: 200000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 189 Votes, Ranking: 8
# - Suggestions for Composting Sites: (Cost: 14000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 34 Votes, Ranking: 111
# - Honey in my neighborhood: let's produce sweetness!: (Cost: 10000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 43 Votes, Ranking: 92
# - Insects and Birds in the City: (Cost: 5320.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 48 Votes, Ranking: 84
# - Understanding and better preserving the animals of the Sept-Deniers neighborhood: (Cost: 5300.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 9 Votes, Ranking: 177
# - Build and install a communal bread oven in the 7 Deniers neighborhood.: (Cost: 72000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 7 Votes, Ranking: 182
# - Greening of Place des Tibaous: (Cost: 200000.0 €, District: 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur). 44 Votes, Ranking: 90
# - Motion sensor night lighting: (Cost: 200000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 189 Votes, Ranking: 9
# - Fighting mosquitoes with bats: (Cost: 1200.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 155 Votes, Ranking: 14
# - Soothing of Boulevard Riquet: (Cost: 75000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 64 Votes, Ranking: 60
# - Caillibens Cycle Path: (Cost: 50000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 9 Votes, Ranking: 172
# - Development of a hall at Bertier Square: (Cost: 170000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 25 Votes, Ranking: 132
# - Remove the asphalt from Lombez Avenue and Grande-Bretagne Avenue.: (Cost: 115000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 130 Votes, Ranking: 18
# - Military Battle at the 7 Deniers in 1814 (creation of a soldier statue): (Cost: 60000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 52 Votes, Ranking: 73
# - Replace the current traffic lights on Route de Blagnac with reward lights and add new lights at all pedestrian crossings.: (Cost: 55000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 9 Votes, Ranking: 176
# - Rehabilitate the Minimes Dead End: (Cost: 150000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 23 Votes, Ranking: 135
# - Create marked parking spaces on Avenue des Coteaux: (Cost: 115000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 11 Votes, Ranking: 168
# - Games for Adults (development of a playground with equipment not solely dedicated to children): (Cost: 100000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 7 Votes, Ranking: 184
# - Planting edible trees and plants: (Cost: 3000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 61 Votes, Ranking: 64
# - Bike lane and one-way street on rue de Périole: (Cost: 50000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 67 Votes, Ranking: 55
# - The development of car sharing: (Cost: 4500.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 35 Votes, Ranking: 108
# - A mural in the heart of the Bourrassol neighborhood that enhances nature in a significant living space for the residents.: (Cost: 25000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 75 Votes, Ranking: 51
# - Rehabilitation of the Bike and Mountain Bike Skills Course: (Cost: 40000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 2 Votes, Ranking: 197
# - Strolling down Raymond IV Street: (Cost: 200000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 65 Votes, Ranking: 59
# - Installation of a fitness trail in the Montaudran district near the Halle de la Machine.: (Cost: 150000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 76 Votes, Ranking: 49
# - Greening Avenues Biarritz & Casselardit: (Cost: 150000.0 €, District: 19 - Casselardit / Fontaine-Bayonne / Cartoucherie). 46 Votes, Ranking: 89
# - Fruit tree plantations in the Rangueil, Sauzelong, and Jules Julien neighborhoods: (Cost: 50000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 116 Votes, Ranking: 22
# - A bike path for better continuity on Rue Henri Desbals: (Cost: 45000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 66 Votes, Ranking: 58
# - No more benches in the streets: (Cost: 10000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 13 Votes, Ranking: 161
# - Speed bumps on Chemin du Touch: (Cost: 60000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 3 Votes, Ranking: 193
# - Intergenerational sports and recreational area around a pump track: (Cost: 150000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 26 Votes, Ranking: 130
# - Greenway to Pech David: (Cost: 200000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 93 Votes, Ranking: 38
# - Play area accessible to all at the Pays d'Oc garden: (Cost: 30000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 14 Votes, Ranking: 158
# - The convivial and sportive Gironde (development of the Couserans park): (Cost: 26000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 3 Votes, Ranking: 194
# - Create dedicated and well-defined bike and pedestrian paths: (Cost: 150000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 467 Votes, Ranking: 2
# - Continue along the Brienne alley bike path until you reach Paul-Séjourné Avenue.: (Cost: 200000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 71 Votes, Ranking: 53
# - Art on the blind walls: (Cost: 100000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 17 Votes, Ranking: 150
# - Develop the Parc des Sept-Deniers with an ecological fitness trail: (Cost: 25000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 25 Votes, Ranking: 131
# - Improvement of the playground at Mady de la Giraudière square: (Cost: 60000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 17 Votes, Ranking: 152
# - Creation of an Alley in the Soupetard Roseraie district - access - between Rue Louis Plana and the Guillaumet district: (Cost: 100000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 36 Votes, Ranking: 104
# - De-seal and vegetate the Ducuing/Salade Ponsan intersection: (Cost: 200000.0 €, District: 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville). 38 Votes, Ranking: 100
# - Street Workout Area - Boisseraie Park: (Cost: 20000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 31 Votes, Ranking: 117
# - Kiosk at Michelet Garden: (Cost: 10000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 46 Votes, Ranking: 88
# - A garden in motion along the railway and the rectorate: (Cost: 11000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 50 Votes, Ranking: 75
# - Community Composting/Participatory Garden - Croix de Pierre: (Cost: 7000.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 30 Votes, Ranking: 122
# - Bus shelter on Lanusse Road: (Cost: 10000.0 €, District: 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve). 0 Votes, Ranking: 200
# - Swift and bat nesting boxes + traps for tiger mosquito larvae or adults: (Cost: 11200.0 €, District: 15 - Croix de Pierre / Route d'Espagne). 125 Votes, Ranking: 21
# - Increase the Installation of the Algal Tree in Toulouse: (Cost: 80000.0 €, District: 17 - Mirail-Université / Reynerie / Bellefontaine). 5 Votes, Ranking: 189
# - Trees in the schoolyard of Soupetard: (Cost: 30000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 52 Votes, Ranking: 72
# - A Health Trail along the Touch: (Cost: 35000.0 €, District: 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan). 36 Votes, Ranking: 107
# - Make Place Amat Massot... a friendly ECO-CITIZEN square!: (Cost: 200000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 145 Votes, Ranking: 15
# - A two-way cycle path between the Airbus Saint-Eloi factory and the Canal du Midi (Chemin du Sang de Serp): (Cost: 60000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 43 Votes, Ranking: 93
# - Games of Ooo in the city: (Cost: 20000.0 €, District: 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée). 8 Votes, Ranking: 180
# - Plan secure bike paths to connect the Sept-Deniers district to Ginestous.: (Cost: 200000.0 €, District: 7 - Sept Deniers / Ginestous-Sesquières / Lalande). 36 Votes, Ranking: 103
#
#
# Your task is to analyze the following project, proposed for the upcoming participatory budgeting election.
#
# Project: Increase the number of bicycle parking spaces in the city center
# Cost: 12000.0 €
# District: 1 - Capitole / Arnaud Bernard / Carmes
# Description: Even though notable efforts have already been made, wanting to develop the modal share of bicycles in transportation requires a significant increase in bike parking options, especially in the city center. Parking spaces are very insufficient around Capitole Square, Wilson Square, St Pierre Square, Arnaud Bernard Square, around St Sernin, Carnot Boulevard, Strasbourg Boulevard, Arcole Boulevard, Alsace-Lorraine Street, Mirepoix Street, Pargaminières Street, Rémusat Street, Taur Street, Gambetta Street, etc. 🔎 WHAT THE SERVICES PLAN: As part of its urban development projects, the Community systematically integrates fixtures for bike parking. The deployment of urban furniture such as bike racks in the city center is carried out according to the needs reported by local residents and users (requests to the District Mayor or the AlloToulouse platform 05 61 222 222), subject to the opinion of the Architecte des Bâtiments de France and the availability of already very constrained public space. Within this framework, it is proposed to install, at a minimum, fifty bike racks per year in District 1.
#
# Based on:
#
# - Your knowledge of Toulouse, its urban context, and its social and environmental challenges.
# - The characteristics of the project (theme, cost, district, etc.)
# - Similarities with past projects that received votes.
# - Typical voting dynamics in participatory budgeting elections
#
# Please answer the following questions about this project:
#
# 1. What is a reasonable estimate of the number of votes this project could receive?
# 2. What would its expected position be in the final ranking?
#
# Please respond with a JSON dictionary using the following keys:
# ```json
# {
#   "estimated_votes": X,              // Estimated number of votes (integer)
#   "confidence_interval": [a, b],     // Realistic interval (min, max)
#   "expected_position": Y,            // Estimated position in the final ranking
#   "likely_in_top_5": 1 or 0,         // 1 if likely to be in the top 5, otherwise 0
#   "likely_in_top_10": 1 or 0         // 1 if likely to be in the top 10, otherwise 0
# }
# ```
# Before answering, think step by step and identify the key factors that affect the outcome. Then summarize your reasoning in 5 to 8 concise bullet points.
#
# **OUTPUT INSTRUCTIONS**
# 1. Present your reasoning in 5 to 8 concise key points.
# 2. At the end, provide only a valid JSON dictionary, with no additional text.

# %%
test['n_tokens'] = test['prompt'].apply(lambda p: tokens_counter(p))
test['cost_usd'] = test['n_tokens'].apply(lambda n_tokens: prompt_cost(n_tokens, 'gpt-4-turbo'))

print('mean tokens by prompt: {:.2f}'.format(test.n_tokens.mean()))
print('avg.cost of each prediction: ${:.2f}'.format(test.cost_usd.mean()))
print('experiment total cost: {:.2f}'.format(test.cost_usd.sum()))
# Out:
# mean tokens by prompt: 11775.94
# avg.cost of each prediction: $0.12
# experiment total cost: 21.55

# %%
#3. run experiment! :)
api_key=os.getenv('OPENAI_API_KEY')
from llm_client import call_openai_model 

test['out'] = test['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))
# Out:
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!

# %%
import json
import re

def get_json_from_llm_response(out):
    
    if isinstance(out, str):
        try:
            data = json.loads(out)
            if isinstance(data, dict):
                return data
        except json.JSONDecodeError:
            pass

    match = re.search(r"```json\s*({.*?})\s*```", out, re.DOTALL)
    if match:
        json_str = match.group(1)
        try:
            return json.loads(json_str)
        except json.JSONDecodeError:
            return None

    return None

def get_predicted_votes(df, out_json, city = 'Toulouse'):
    
    if city != 'Toulouse':
        raise ValueError(f"City '{city}' not supported")

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
    
    votes_2022 = df[df['year'] == 2022].votes.sum()
    votes_2024 = df[df['year'] == 2024].votes.sum()

    relative_estimation = out_json['estimated_votes'] / votes_2022
    adjusted_prediction = relative_estimation * votes_2024

    return adjusted_prediction

def get_predicted_rank(out_json):
    
    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['expected_position']


def get_if_is_top5(out_json):

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['likely_in_top_5']

def get_if_is_top10(out_json):

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['likely_in_top_10']

# %%
test['out_json'] = test['out'].apply(
    lambda o: get_json_from_llm_response(o))

# %%
test['out_json'].iloc[0]
# Out:
# {'estimated_votes': 75,
#  'confidence_interval': [50, 100],
#  'expected_position': 50,
#  'likely_in_top_5': 0,
#  'likely_in_top_10': 0}

# %%
test['predicted_votes'] = test['out_json'].apply(lambda x: get_predicted_votes(df, x))
test['predicted_rank'] = test['out_json'].apply(lambda x: get_predicted_rank(x))
test['is_top5'] = test['out_json'].apply(lambda x: get_if_is_top5(x))
test['is_top10'] = test['out_json'].apply(lambda x: get_if_is_top10(x))

# %%
#4. save results.
results = test.filter(['project_id', 
             'real_votes', 
             'real_rank',
             'prompt',
             'out',
             'out_json', 
             'predicted_votes', 
             'predicted_rank', 
             'is_top5', 
             'is_top10']
             )
results
# Out:
#      project_id  real_votes  real_rank  \
# 0           263         590          1
# 1           320         559          2
# 2           394         436          3
# 3           333         366          4
# 4           265         334          5
# ..          ...         ...        ...
# 178         372          20        179
# 179         356          19        180
# 180         230          19        181
# 181         370          18        182
# 182         374          17        183
#
#                                                 prompt  \
# 0    You are an expert model in analyzing participa...
# 1    You are an expert model in analyzing participa...
# 2    You are an expert model in analyzing participa...
# 3    You are an expert model in analyzing participa...
# 4    You are an expert model in analyzing participa...
# ..                                                 ...
# 178  You are an expert model in analyzing participa...
# 179  You are an expert model in analyzing participa...
# 180  You are an expert model in analyzing participa...
# 181  You are an expert model in analyzing participa...
# 182  You are an expert model in analyzing participa...
#
#                                                    out  \
# 0    **Reasoning Summary:**\n\n1. **District and Th...
# 1    **Key Points for Analysis:**\n\n1. **Project T...
# 2    **Key Points for Analysis:**\n\n1. **Theme Rel...
# 3    **Key Points for Analysis:**\n\n1. **Project T...
# 4    **Key Points for Analysis:**\n\n1. **District ...
# ..                                                 ...
# 178  **Reasoning Summary:**\n\n1. **Project Theme a...
# 179  **Key Points for Analysis:**\n\n1. **Project T...
# 180  **Key Points for Analysis:**\n\n1. **Project T...
# 181  **Key Points for Analysis:**\n\n1. **District ...
# 182  **Reasoning Summary:**\n\n1. **Project Cost an...
#
#                                               out_json  predicted_votes  \
# 0    {'estimated_votes': 75, 'confidence_interval':...       140.746166
# 1    {'estimated_votes': 180, 'confidence_interval'...       337.790798
# 2    {'estimated_votes': 120, 'confidence_interval'...       225.193865
# 3    {'estimated_votes': 120, 'confidence_interval'...       225.193865
# 4    {'estimated_votes': 350, 'confidence_interval'...       656.815440
# ..                                                 ...              ...
# 178  {'estimated_votes': 85, 'confidence_interval':...       159.512321
# 179  {'estimated_votes': 120, 'confidence_interval'...       225.193865
# 180  {'estimated_votes': 55, 'confidence_interval':...       103.213855
# 181  {'estimated_votes': 120, 'confidence_interval'...       225.193865
# 182  {'estimated_votes': 75, 'confidence_interval':...       140.746166
#
#      predicted_rank  is_top5  is_top10
# 0                50        0         0
# 1                15        0         0
# 2                22        0         0
# 3                22        0         0
# 4                15        0         0
# ..              ...      ...       ...
# 178              45        0         0
# 179              35        0         0
# 180              85        0         0
# 181              22        0         0
# 182              90        0         0
#
# [183 rows x 10 columns]

# %%
results.to_csv('output/predictions/tls_in_context_full_eng_1.csv', sep=";", index=False)
print('results ready!')
# Out:
# results ready!

# %% [markdown]
# ##### WRC 17

# %%
# 1. load data
import os
import pandas as pd
import src.utils as ut
import prompt_builder as pb

from dotenv import load_dotenv
from src.data_loader import load_and_prepare_projects, load_test_dataset
from prompt_utils import tokens_counter, prompt_cost


path_16 = 'data/wrc16_projects.csv'
path_17 = 'data/wrc17_projects.csv'

df, df16_shuffled = load_and_prepare_projects(path_16,path_17, city = 'Wroclaw')
test = load_test_dataset(df, rows = 50, city='Wroclaw')

load_dotenv()

conn_params = {
    "host": os.environ["PG_HOST"],
    "database": os.environ["PG_DATABASE"],
    "user": os.environ["PG_USER"],
    "password": os.environ['PG_PASSWORD']
}

test
# Out:
#     project_id                                       project_name  \
# 0           10  Toalety we Wrocławskich parkach i na terenach ...
# 1           50  Zielona rowerowo-piesza obwodnica Wrocławia; E...
# 2           18                              Rowerowy Wrocław 2017
# 3          675  Zieleń dla Wrocławia – parki kieszonkowe, nasa...
# 4          260                     Budki dla kotów wolno żyjących
# 5          550  Pieszo z Brochowa - uzupełnienie brakującego c...
# 6           12  Bulwar Fizyków - naukowy plac zabaw w przestrz...
# 7          159  Baza małych astronautów czyli kosmiczny plac z...
# 8          656     Toalety miejskie w parkach na miarę Wrocławia.
# 9          499  "Konikowo" - Budowa autorskiego placu zabaw na...
# 10         751                   Modernizacja ulicy DRZEWIECKIEGO
# 11         451                 Wrocławska Arena Sportu - strefa A
# 12         284  Zielona Obwodnica Wrocławia - drzewa i pnącza ...
# 13         345                                     Park Rędziński
# 14          41                Fontanna Neptuna na Placu Nowy Targ
# 15          16                Remont zabytkowego autobusu Fredruś
# 16         716  Park Grabiszyński - bezpieczne dojście! Remont...
# 17         590  Zagospodarowanie terenu kąpieliska na Oporowie...
# 18          43              Zielona Promenada przez Krzyki Etap I
# 19          46  Rondo Reagana na poziomie! Budowa peronów na R...
# 20         514  Pszczoły w mieście – hotele dla zapylaczy z pl...
# 21         553  Sieć parków we Wrocławiu - Psie Pole - Zawidaw...
# 22          68  Zielona trasa biegowo-pieszo-rowerowa z Ołtasz...
# 23         608                                 Sportowa Jantarowa
# 24         258                          Rewitalizacja ul. Ruskiej
# 25         555  Sieć parków we Wrocławiu – Psie Pole - Zawidaw...
# 26          83  Bezpieczne i przyjazne drogi we Wrocławiu - św...
# 27         680     Ścieżki pieszo-rowerowe przy ul. Opatowickiej.
# 28         372  Połączmy Psie Pole i Zakrzów – łącznik pieszo-...
# 29         688                          Miodowe łąki we Wrocławiu
# 30         668  "Park & ride" przy pętli Pilczyce/Stadion Wrocław
# 31         685                             Miejskie wyspy zieleni
# 32         694                Zielone przystanki w centrum miasta
# 33         371  Bezpieczniej na skrzyżowaniu al. Sobieskiego i...
# 34         508  Kępa Mieszczańska –park kieszonkowy z stacją s...
# 35         346          Odnowienie szpetnych wiaduktów kolejowych
# 36         358  Toskania we Wrocławiu: donice z kwiatami wokół...
# 37         594                Las sekwoi, drzewa i krzewy owocowe
# 38         332       Infrastruktura przystankowa na ul. Dworcowej
# 39         334          infrastruktura przystankowa na ul. Dawida
# 40          35  Wsiadanie na poziomie-budowa przystanków wiede...
# 41         620         Wrocławskie parki dostępne dla wszystkich.
# 42         203  Oczyszczenie z wojennego osmolenia i sadzy pia...
# 43         735  Rampa dla rowerów i wózków przy wyjściu z ulic...
# 44         464  Szachy plenerowe dużego gabarytu w centrum mia...
# 45         422          Akcja Plac - Gry uliczne "Oswajamy beton"
# 46         406  Budowa wrocławskiej wypożyczalni rowerów integ...
# 47         629  Wrocław na dotknięcie ręki – tylfograficzne ma...
# 48         720                                               1997
# 49         677  Polegiwacz - wędrujący mebel do odpoczynku i z...
#
#                                           description     cost      district  \
# 0   Uzasadnienie\nW parkach i na terenach zielonyc...   900000   Śródmieście
# 1   Uzasadnienie\nWalczymy o II ETAP. Ideą jest po...  1000000  Stare Miasto
# 2   Uzasadnienie\nProjekt przewiduje poprawę bezpi...  1000000  Stare Miasto
# 3   Uzasadnienie\nWe Wrocławiu nastąpiła deklaraty...  1000000     Psie Pole
# 4                                        Uzasadnienie    70000     Psie Pole
# 5   Uzasadnienie\nZ Brochowa nie sposób wydostać s...  1000000        Krzyki
# 6   Uzasadnienie\nProponujemy stworzenie instalacj...  1000000     Psie Pole
# 7   Uzasadnienie\nW ramach Budżetu Obywatelskiego ...  1000000        Krzyki
# 8   Uzasadnienie\nInicjatywa jest odpowiedzią na p...  1000000   Śródmieście
# 9   Uzasadnienie\nDrodzy Wrocławianie, Drodzy Sąsi...  1000000  Stare Miasto
# 10  Uzasadnienie\nPrzejścia dla pieszych oraz miej...  1000000        Krzyki
# 11  Uzasadnienie\nProjekt zakłada powstanie strefy...  1000000        Krzyki
# 12  Uzasadnienie\nProjekt zakłada nasadzenia drzew...   100000        Krzyki
# 13  Uzasadnienie\nKoncepcję Parku na Maślicach zap...  1000000        Krzyki
# 14  Uzasadnienie\nOdtworzenie historycznej rzeźby ...  1000000   Śródmieście
# 15  Uzasadnienie\nAutobus kabriolet Jelcz MEX - Fr...   430000        Krzyki
# 16  Uzasadnienie\nNiezbędny jest remont ogromnej w...  1000000  Stare Miasto
# 17  Uzasadnienie\nBudowa: boiska do siatkówki plaż...  1000000     Fabryczna
# 18  Uzasadnienie\nProjekt ma za zadanie przywrócen...  1000000        Krzyki
# 19  Uzasadnienie\nRondo Reagana to jeden z ważniej...  1000000     Psie Pole
# 20  Uzasadnienie\nObecnie wskazany zieleniec pomim...   250000        Krzyki
# 21  Uzasadnienie\nCelem projektu jest stworzenie d...  1000000     Fabryczna
# 22  Uzasadnienie\nProponuję kilka modyfikacji (głó...   750000        Krzyki
# 23  Uzasadnienie\nRealizując projekt budowy boiska...  1000000        Krzyki
# 24  Uzasadnienie\nCelem projektu jest remont ul. R...   750000     Psie Pole
# 25  Uzasadnienie\nCelem projektu jest stworzenie d...  1000000  Stare Miasto
# 26  Uzasadnienie\nProjekt zakłada zmianę trybu pra...   650000     Psie Pole
# 27  Uzasadnienie\nWzdłuż ul. Opatowickiej biegnie ...   500000        Krzyki
# 28  Uzasadnienie\nProjekt przewiduje budowę ciągu ...   350000  Stare Miasto
# 29  Uzasadnienie\nCelem projektu jest stworzenie a...   100000     Psie Pole
# 30  Uzasadnienie\n"Park & ride" to parkingi dla  p...   750000     Fabryczna
# 31  Uzasadnienie\nW tym roku smog dał się we znaki...   250000  Stare Miasto
# 32  Uzasadnienie\nProjekt zakłada utworzenie zielo...   320000     Fabryczna
# 33  Uzasadnienie\nProjekt ma na celu poprawę bezpi...  1000000        Krzyki
# 34  Uzasadnienie\nUporządkowanie i zagospodarowani...   750000     Psie Pole
# 35  Uzasadnienie\nCelem projektu jest ocieplenie z...   250000        Krzyki
# 36  Uzasadnienie\nCelem projektu jest upiększenie ...   350000        Krzyki
# 37  Uzasadnienie\n1. Mało kto wie, że kiedyś, potę...   150000  Stare Miasto
# 38  Uzasadnienie\nPętla przystankowa przy ul. Dwor...   420000  Stare Miasto
# 39  Uzasadnienie\nNa ul. Dawida (między ul. Dawida...   250000   Śródmieście
# 40  Uzasadnienie\nPrzystanki wiedeńskie ułatwiają ...   500000   Śródmieście
# 41  Uzasadnienie\nNieodłączną częścią tkanki miejs...   200000     Fabryczna
# 42  Uzasadnienie\nMedaliony z herbem Wrocławia są ...   150000        Krzyki
# 43  Uzasadnienie\nWały nad Odrą, a w szczególności...    50000     Fabryczna
# 44  Uzasadnienie\nBudowa szachów dużego gabarytu w...   250000  Stare Miasto
# 45  Uzasadnienie\nProjekt zakłada lokowanie w prze...   150000   Śródmieście
# 46  Uzasadnienie\nProjekt przeznaczony jest zarówn...   600000        Krzyki
# 47  Uzasadnienie\nRynek i wszystkie miejsca, takie...   130000  Stare Miasto
# 48  Uzasadnienie\nIdeą projektu "1997" było upamię...    50000        Krzyki
# 49  Uzasadnienie\nPolegiwacz jest przenośnym meble...   150000   Śródmieście
#
#     district_number  real_votes  real_rank  year
# 0               4.0       10857          1  2017
# 1               5.0       10796          2  2017
# 2               5.0        8640          3  2017
# 3               3.0        5398          4  2017
# 4               3.0        4998          5  2017
# 5               2.0        4468          6  2017
# 6               3.0        4149          7  2017
# 7               2.0        4098          8  2017
# 8               4.0        4008          9  2017
# 9               5.0        3949         10  2017
# 10              2.0        3788         11  2017
# 11              2.0        3368         12  2017
# 12              2.0        3362         13  2017
# 13              2.0        2484         14  2017
# 14              4.0        2123         15  2017
# 15              2.0        2113         16  2017
# 16              5.0        2098         17  2017
# 17              1.0        2001         18  2017
# 18              2.0        1973         19  2017
# 19              3.0        1839         20  2017
# 20              2.0        1737         21  2017
# 21              1.0        1724         22  2017
# 22              2.0        1705         23  2017
# 23              2.0        1613         24  2017
# 24              3.0        1566         25  2017
# 25              5.0        1512         26  2017
# 26              3.0        1455         27  2017
# 27              2.0        1358         28  2017
# 28              5.0        1331         29  2017
# 29              3.0        1092         30  2017
# 30              1.0        1060         31  2017
# 31              5.0         990         32  2017
# 32              1.0         943         33  2017
# 33              2.0         922         34  2017
# 34              3.0         882         35  2017
# 35              2.0         765         36  2017
# 36              2.0         619         37  2017
# 37              5.0         587         38  2017
# 38              5.0         544         39  2017
# 39              4.0         480         40  2017
# 40              4.0         433         41  2017
# 41              1.0         418         42  2017
# 42              2.0         415         43  2017
# 43              1.0         266         44  2017
# 44              5.0         263         45  2017
# 45              4.0         236         46  2017
# 46              2.0         178         47  2017
# 47              5.0         156         48  2017
# 48              2.0         118         49  2017
# 49              4.0          83         50  2017

# %%
#2. build prompt

last_projects_results = pb.get_all_projects_from_22_election(df16_shuffled)

test['prompt'] = test.apply(
    lambda x: pb.build_prompt(
        'prompts/prompt_in_context_pl.txt',
        {
            'last_projects_results': last_projects_results,
            'project_name': x['project_name'],
            'cost': x['cost'],
            'district': x['district'],
            'description': x['description']
        }
    ),
    axis=1
)

# %%
print(test['prompt'][0])
# Out:
# You are an expert model in analyzing participatory budgeting elections, specifically in the context of the city of Wroclaw, Poland.
#
# In Wroclaw, the municipality organizes participatory budgeting elections to fund citizen projects.
#
# Once the voting period is over, the projects are ranked based on the number of votes they received. Then, the winning projects are selected using a greedy algorithm: starting with the project that received the most votes, the next most voted projects are added in sequence as long as the remaining budget allows it.
# When the next project on the list exceeds the available budget, the algorithm skips to the next project that can be funded, and so on, until the total budget of 4500000 € is exhausted.
#
# Here is the list of the 52 initiatives proposed during the election, including their name, cost, and district:
# - Budowa wrocławskiej wypożyczalni rowerów integracyjnych typu handbike wraz z odpowiednim zapleczem socjalno-sanitarnym: (Coût: 550000 €, District: Psie Pole). 1912 Voix, Classement: 20
# - Remont ulicy Glinianej - odcinek Ślężna - Borowska: (Coût: 510000 €, District: Śródmieście). 522 Voix, Classement: 42
# - Zaułek na Stalowej. Chodniki i zieleń przy Stalowej (od Grabiszyńskiej do Mosięznej). Miejsca parkingowe. Renowacja Drogi.: (Coût: 250000 €, District: Fabryczna). 332 Voix, Classement: 48
# - Rozbudowa bazy sportowej na wrocławskich Osobowicach - strefa sportu przy Szkole Podstawowej nr 21: (Coût: 1000000 €, District: Psie Pole). 3008 Voix, Classement: 13
# - Frisbee Golf: (Coût: 85000 €, District: Krzyki). 477 Voix, Classement: 44
# - Posadzenie na terenie Wrocławia młodych drzew: (Coût: 100000 €, District: Fabryczna). 5287 Voix, Classement: 6
# - Bezpieczne i przyjazne drogi we Wrocławiu - światła spowalniające zamiast fotoradarów w całym mieście: (Coût: 650000 €, District: Psie Pole). 2070 Voix, Classement: 18
# - Stacja Roweru Miejskiego NEXTBIKE Dworzec Świebodzki: (Coût: 100000 €, District: Stare Miasto). 245 Voix, Classement: 51
# - Plac Zabaw dla Starszaków w parku Grabiszyńskim i coś ekstra dla maluchów: (Coût: 560000 €, District: Krzyki). 6663 Voix, Classement: 4
# - Ławeczki na przystankach: (Coût: 100000 €, District: Stare Miasto). 831 Voix, Classement: 33
# - Wydłużenie pasa lewoskrętu w kierunku ulicy Lotniczej na skrzyżowaniu ulic Na Ostatnim Groszu i Legnickiej: (Coût: 750000 €, District: Krzyki). 2901 Voix, Classement: 14
# - Fontanna Neptuna na Placu Nowy Targ: (Coût: 750000 €, District: Stare Miasto). 3632 Voix, Classement: 9
# - Stacje roweru miejskiego nextbike - Zakrzów - osiedle blokowe Wilanowska / Królewska: (Coût: 250000 €, District: Stare Miasto). 1506 Voix, Classement: 27
# - Rowerowy Wrocław 2016 – ulice przyjazne rowerzystom: (Coût: 1000000 €, District: Śródmieście). 4799 Voix, Classement: 7
# - Stacje roweru miejskiego NEXTBIKE Port Lotniczy Wrocław, CH Factory: (Coût: 150000 €, District: Krzyki). 718 Voix, Classement: 35
# - Parking przy "Dobrzyńskiej" - ułatwienie dojazdu wrocławian do największego w mieście centrum medycznego.: (Coût: 750000 €, District: Krzyki). 6383 Voix, Classement: 5
# - Ścianka bulderingowa.: (Coût: 150000 €, District: Krzyki). 648 Voix, Classement: 38
# - Bajkowy Plac dla Dorosłych i Dzieci w Parku Skowronim: (Coût: 500000 €, District: Psie Pole). 1619 Voix, Classement: 25
# - Poprawa nawierzchni ulicy Międzyleskiej: (Coût: 750000 €, District: Psie Pole). 474 Voix, Classement: 45
# - Remont ulicy Kamiennej - odcinek Tomaszowska - Borowska: (Coût: 1000000 €, District: Fabryczna). 781 Voix, Classement: 34
# - Remont sieci trakcyjnej na zajezdni Dąbie: (Coût: 500000 €, District: Krzyki). 278 Voix, Classement: 50
# - Poprawa infrastruktury sportowej dla dyscypliny Piłka Nożna: (Coût: 750000 €, District: Krzyki). 2093 Voix, Classement: 16
# - Budowa nadbrzeża ze slipem dla przyszłej miejskiej przystani łodziowej: (Coût: 1000000 €, District: Krzyki). 3243 Voix, Classement: 10
# - Psie Pole bez korków: (Coût: 1000000 €, District: Stare Miasto). 2081 Voix, Classement: 17
# - Poprawa nawierzchni ulicy Bogedaina: (Coût: 750000 €, District: Krzyki). 983 Voix, Classement: 31
# - Tablice rozkładowe na przystankach linii 2, 6, 7 i 17 oraz przystankach Uniwersytecka, Wita Stwosza, Dubois: (Coût: 600000 €, District: Fabryczna). 699 Voix, Classement: 37
# - Miejsca parkingowe (park & ride) przy pętli Pilczyce/Stadion Miejski: (Coût: 750000 €, District: Stare Miasto). 1608 Voix, Classement: 26
# - Park Jedności– miejska rekreacja: (Coût: 1000000 €, District: Fabryczna). 3026 Voix, Classement: 12
# - Drzewa dla Wrocławia - nasadzenia w całym mieście!: (Coût: 1000000 €, District: Fabryczna). 13938 Voix, Classement: 1
# - Stacje roweru miejskiego NEXTBIKE na pętli autobusowej Nowy Dwór.: (Coût: 250000 €, District: nan). 436 Voix, Classement: 47
# - Toaleta publiczna w Parku Wschodnim: (Coût: 250000 €, District: Psie Pole). 1441 Voix, Classement: 28
# - Błotniste pobocza ulic: (Coût: 200000 €, District: Krzyki). 889 Voix, Classement: 32
# - Remont ulicy Stawowej: (Coût: 700000 €, District: Psie Pole). 531 Voix, Classement: 40
# - Nowa Gwiaździsta: (Coût: 90000 €, District: Krzyki). 1025 Voix, Classement: 30
# - Zintegrowany system informacji pasażerskiej w obrębie pl. Grunwaldzkiego: (Coût: 200000 €, District: Psie Pole). 474 Voix, Classement: 46
# - Zielona rowerowo-piesza obwodnica Wrocławia; Etap I - fragment łącznika Gaj, Wojszyce, Ołtaszyn, Partynice, Jagodno, Tarnogaj Krzyki, Borek.: (Coût: 1000000 €, District: Krzyki). 12348 Voix, Classement: 2
# - Wyciszenie nawierzchni na ul. Złotnickiej: (Coût: 1000000 €, District: Fabryczna). 1717 Voix, Classement: 22
# - Oświetlenie Parku Grabiszyńskiego (Alei Romera oraz ścieżek do Cmentarza Grabiszyńskiego i ul. Racławickiej wzdłuż polan): (Coût: 1000000 €, District: Krzyki). 7291 Voix, Classement: 3
# - Podwórze pomiędzy ulicami Prusa, Wyszyńskiego, Sępa Sarzyńskiego i Sienkiewicza: (Coût: 750000 €, District: Śródmieście). 526 Voix, Classement: 41
# - Podniesienie powierzchni peronów na rondzie Reagana: (Coût: 1000000 €, District: Psie Pole). 705 Voix, Classement: 36
# - Niewykorzystany potencjał Parku Skowroniego - rewitalizacja: (Coût: 1000000 €, District: Śródmieście). 1644 Voix, Classement: 24
# - Cywilizacja na Wojszycach - Światło dla wszystkich - Zamontowanie miejskich latarni na ulicy Smardzowskiej w Europejskiej Stolicy Kultury: (Coût: 40000 €, District: Śródmieście). 281 Voix, Classement: 49
# - Rowerowe połączenie Dworca Głównego z pl. Społecznym: (Coût: 1000000 €, District: Psie Pole). 3099 Voix, Classement: 11
# - Uporządkowanie ruchu pojazdów na Ulicy Robotniczej w kierunku Placu Orląt Lwowskich: (Coût: 200000 €, District: Fabryczna). 1653 Voix, Classement: 23
# - Remont autobusu zabytkowego Fredruś: (Coût: 430000 €, District: Krzyki). 1924 Voix, Classement: 19
# - Budowa sygnalizacji świetlnej na skrzyżowaniu przy Skwerze Pionierów Wrocławskich: (Coût: 900000 €, District: Fabryczna). 120 Voix, Classement: 52
# - Bulwar Fizyków - etap 1: soczewki akustyczne, doświadczenie z falami dźwiękowymi w formie ogólnodostępnej instalacji: (Coût: 250000 €, District: Krzyki). 1825 Voix, Classement: 21
# - Stoły do ping – ponga i boiska do siatkówki w całym Wrocławiu.: (Coût: 1000000 €, District: Fabryczna). 3974 Voix, Classement: 8
# - Podniesienie peronów na Rondzie Reagana (Plac Grunwaldzki): (Coût: 1000000 €, District: Stare Miasto). 494 Voix, Classement: 43
# - Dokończenie trasy pieszo-rowerowej wokół Wielkiej Wyspy: (Coût: 1000000 €, District: Krzyki). 2260 Voix, Classement: 15
# - Kameralna scena na trawie w sercu Wyspy Słodowej: (Coût: 400000 €, District: Fabryczna). 1161 Voix, Classement: 29
# - Szachy plenerowe z figurami dużego gabarytu w centrum miasta: (Coût: 250000 €, District: Fabryczna). 619 Voix, Classement: 39
#
#
# Your task is to analyze the following project, proposed as part of a new participatory budgeting election.
#
# Project: Toalety we Wrocławskich parkach i na terenach rekreacyjnych.
# Cost: 900000 €
# District: Śródmieście
# Description: Uzasadnienie
# W parkach i na terenach zielonych we Wrocławiu brakuje toalet, co utrudnia korzystanie z nich w celach rekreacyjnych przez dłuższy czas.
# Proponujemy instalację toalet (technologia dowolna, prawdopodobnie najlepsze byłyby samoczyszczące i/lub odporne na wandalizm).
# Proponujemy następujące miejsca:
# 1) Park Szczytnicki
# 2) Park Wschodni
# 3) Park Południowy
# 4) Park Tysiąclecia
# 5) Park Zachodni
# 6) Karłowice (Park Kasprowicza lub Polana Karłowicka lub Brodzik)
# Szczegóły umiejscowienia zostaną ustalone z liderem projektu. W przypadku gdyby któryś z ww parków posiadał już toaletę w momencie wygranej projektu, wspólnie z UMW wybierzemy inną lokalizację.
#
# Based on:
# - Your knowledge of Wroclaw, its urban context, and its social and environmental issues
# - The characteristics of the project (theme, cost, district, etc.)
# - Similarities with previous projects that received votes
# - Typical voting dynamics in participatory budgeting elections
#
# In this new election, 50 alternative projects have been proposed
#
# Please answer the following questions regarding this project:
# - What is a reasonable estimate of the number of votes this project might receive?
# - What would be its expected ranking in the final list?
# - Is it likely that this project will be in the Top 5 by votes?
# - Is it likely that this project will be in the Top 10 by votes?
#
# Please answer in the form of a JSON dictionary with the following keys:
#
# ```json
# {
#   "estimated_votes": X,               // Estimated number of votes (integer)
#   "confidence_interval": [a, b],     // Realistic interval (min, max)
#   "expected_rank": Y,                // Expected rank in the final list
#   "in_top_5": 1 or 0,                // 1 if likely to be in the top 5, else 0
#   "in_top_10": 1 or 0                // 1 if likely to be in the top 10, else 0
# }
# ```
#
# Before giving an answer, take the time to reason thoroughly, but only explain the essential reasoning.
#
# **OUTPUT INSTRUCTIONS**
# 1. Present your reasoning in 5 to 8 key points, concisely.
# 2. At the end, provide a valid JSON dictionary only, with no additional text.

# %%
test['n_tokens'] = test['prompt'].apply(lambda p: tokens_counter(p))
test['cost_usd'] = test['n_tokens'].apply(lambda n_tokens: prompt_cost(n_tokens, 'gpt-4-turbo'))

print('mean tokens by prompt: {:.2f}'.format(test.n_tokens.mean()))
print('avg.cost of each prediction: ${:.2f}'.format(test.cost_usd.mean()))
print('experiment total cost: {:.2f}'.format(test.cost_usd.sum()))
# Out:
# mean tokens by prompt: 3759.80
# avg.cost of each prediction: $0.04
# experiment total cost: 1.88

# %%
#3. run experiment! :)
api_key=os.getenv('OPENAI_API_KEY')
from llm_client import call_openai_model 

test['out'] = test['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))

# %%
def get_json_from_llm_response(out):
    match = re.search(r"```json\s*({.*?})\s*```", out, re.DOTALL)
    if match:
        json_str = match.group(1)
        data = json.loads(json_str)
        return data
    else:
        return "No JSON in LLM answer..."
    
def get_predicted_votes(df, out_json):
    relative_estimation = (out_json['estimated_votes'] / df[df['year']==2016].votes.sum())
    return relative_estimation*df[df['year']==2017].votes.sum()
    
def get_predicted_rank(out_json):
    return out_json['expected_rank']

def get_if_is_top5(out_json):
    return out_json['in_top_5']

def get_if_is_top10(out_json):
    return out_json['in_top_10']

test['out_json'] = test['out'].apply(
    lambda o: ut.get_json_from_llm_response(o))

test['predicted_votes'] = test['out_json'].apply(lambda x: get_predicted_votes(df, x))
test['predicted_rank'] = test['out_json'].apply(lambda x: get_predicted_rank(x))
test['is_top5'] = test['out_json'].apply(lambda x: get_if_is_top5(x))
test['is_top10'] = test['out_json'].apply(lambda x: get_if_is_top10(x))

# %%
results = test.filter(['project_id', 
             'real_votes', 
             'real_rank',
             'prompt',
             'out',
             'out_json', 
             'predicted_votes', 
             'predicted_rank', 
             'is_top5', 
             'is_top10']
             )
results

# %%
results

# %%
results.to_csv('output/predictions/wrc_in_context_full_1.csv', sep=";", index=False)
print('results ready!')

# %%
#test['predicted_votes'] = test['out_json'].apply(lambda x: ut.get_predicted_votes(x))



#4. save results.
results = test.filter(['project_id', 
             'real_votes', 
             'real_rank',
             'prompt',
             'out',
             'out_json', 
             'predicted_votes', 
             'predicted_rank', 
             'is_top5', 
             'is_top10']
             )

results.to_csv('output/predictions/wrc_simple_prompt.csv', sep=";", index=False)
print('results ready!')

# %% [markdown]
# ### WRC 17 (English)

# %%
# 1. load data
import os
import pandas as pd
import src.utils as ut
import prompt_builder as pb

from dotenv import load_dotenv
from src.data_loader import load_and_prepare_projects, load_test_dataset
from prompt_utils import tokens_counter, prompt_cost


df = pd.read_csv("data/wrc_projects_eng.csv", sep=";")
df16_shuffled = df.sample(frac=1, random_state=42).reset_index(drop=True)
test = df[df['year'] == 2017].sample(frac=1, random_state=42).reset_index(drop=True)


load_dotenv()

conn_params = {
    "host": os.environ["PG_HOST"],
    "database": os.environ["PG_DATABASE"],
    "user": os.environ["PG_USER"],
    "password": os.environ['PG_PASSWORD']
}

# %%
#2. build prompt

last_projects_results = pb.get_all_projects_from_22_election(df16_shuffled)

test['prompt'] = test.apply(
    lambda x: pb.build_prompt(
        'prompts/prompt_in_context_pl.txt',
        {
            'last_projects_results': last_projects_results,
            'project_name': x['project_name'],
            'cost': x['cost'],
            'district': x['district'],
            'description': x['description']
        }
    ),
    axis=1
)

# %%
print(test['prompt'][0])
# Out:
# You are an expert model in analyzing participatory budgeting elections, specifically in the context of the city of Wroclaw, Poland.
#
# In Wroclaw, the municipality organizes participatory budgeting elections to fund citizen projects.
#
# Once the voting period is over, the projects are ranked based on the number of votes they received. Then, the winning projects are selected using a greedy algorithm: starting with the project that received the most votes, the next most voted projects are added in sequence as long as the remaining budget allows it.
# When the next project on the list exceeds the available budget, the algorithm skips to the next project that can be funded, and so on, until the total budget of 4500000 € is exhausted.
#
# Here is the list of the 52 initiatives proposed during the election, including their name, cost, and district:
# - Improvement of the Bogedaina Street surface: (Coût: 750000 €, District: Krzyki). 983 Voix, Classement: 31
# - Renovation of the Historic Fredruś Bus: (Coût: 430000 €, District: Krzyki). 2113 Voix, Classement: 16
# - Modernization of DRZEWIECKIEGO Street: (Coût: 1000000 €, District: Krzyki). 3788 Voix, Classement: 11
# - Alley on Stalowa. Sidewalks and greenery on Stalowa (from Grabiszyńska to Mosiężna). Parking spaces. Road renovation.: (Coût: 250000 €, District: Fabryczna). 332 Voix, Classement: 48
# - Raising the platforms at Reagan Roundabout (Grunwaldzki Square): (Coût: 1000000 €, District: Stare Miasto). 494 Voix, Classement: 43
# - The courtyard between Prusa, Wyszyńskiego, Sępa Sarzyńskiego, and Sienkiewicza streets: (Coût: 750000 €, District: Śródmieście). 526 Voix, Classement: 41
# - Bus stop infrastructure on Dworcowa Street: (Coût: 420000 €, District: Stare Miasto). 544 Voix, Classement: 39
# - Integrated passenger information system within Grunwaldzki Square: (Coût: 200000 €, District: Psie Pole). 474 Voix, Classement: 46
# - Bicycle connection between the Main Station and Social Square: (Coût: 1000000 €, District: Psie Pole). 3099 Voix, Classement: 11
# - Trees for Wrocław - plantings throughout the city!: (Coût: 1000000 €, District: Fabryczna). 13938 Voix, Classement: 1
# - Fredruś Vintage Bus Renovation: (Coût: 430000 €, District: Krzyki). 1924 Voix, Classement: 19
# - Muddy street verges: (Coût: 200000 €, District: Krzyki). 889 Voix, Classement: 32
# - Operation Square - Street Games "Taming the Concrete": (Coût: 150000 €, District: Śródmieście). 236 Voix, Classement: 46
# - Safer at the intersection of Sobieski Avenue and Wilanowska Street: (Coût: 1000000 €, District: Krzyki). 922 Voix, Classement: 34
# - Revitalization of Ruska Street: (Coût: 750000 €, District: Psie Pole). 1566 Voix, Classement: 25
# - Parking at "Dobrzyńska" - facilitating access for Wrocław residents to the city's largest medical center.: (Coût: 750000 €, District: Krzyki). 6383 Voix, Classement: 5
# - Pedestrian and bicycle paths along Opatowicka Street.: (Coût: 500000 €, District: Krzyki). 1358 Voix, Classement: 28
# - Renovation of Kamienna Street - section from Tomaszowska to Borowska: (Coût: 1000000 €, District: Fabryczna). 781 Voix, Classement: 34
# - Expansion of the sports base in Wrocław's Osobowice - sports zone at Primary School No. 21: (Coût: 1000000 €, District: Psie Pole). 3008 Voix, Classement: 13
# - Nextbike city bike stations - Zakrzów - Wilanowska / Królewska housing estate: (Coût: 250000 €, District: Stare Miasto). 1506 Voix, Classement: 27
# - I'm sorry, but you didn't provide any text to translate. Please provide the text you would like translated from Polish to English.: (Coût: 50000 €, District: Krzyki). 118 Voix, Classement: 49
# - Green cycling and walking ring road of Wrocław; STAGE II – sections: Tarnogaj – Gaj - Wojszyce – Jagodno - Krzyki – Borek – Grabiszyn – Grabiszynek – Gajowice – Muchobór Mały.: (Coût: 1000000 €, District: Stare Miasto). 10796 Voix, Classement: 2
# - Regulation of vehicle traffic on Robotnicza Street towards Plac Orląt Lwowskich: (Coût: 200000 €, District: Fabryczna). 1653 Voix, Classement: 23
# - Grabiszyński Park - safe access! Renovation of sidewalks on Odkrywców Street (from Hallera Avenue to Ślusarska Street) and sidewalks leading to the park.: (Coût: 1000000 €, District: Stare Miasto). 2098 Voix, Classement: 17
# - Improvement of the Międzyleska Street surface: (Coût: 750000 €, District: Psie Pole). 474 Voix, Classement: 45
# - Construction of the Wrocław handbike type integrative bicycle rental facility along with appropriate social and sanitary facilities.: (Coût: 600000 €, District: Krzyki). 178 Voix, Classement: 47
# - Improvement of sports infrastructure for the discipline of Football: (Coût: 750000 €, District: Krzyki). 2093 Voix, Classement: 16
# - Network of parks in Wrocław - Psie Pole - Zawidawie 1: (Coût: 1000000 €, District: Fabryczna). 1724 Voix, Classement: 22
# - Street Stawowa Renovation: (Coût: 700000 €, District: Psie Pole). 531 Voix, Classement: 40
# - Construction of a waterfront with a slip for the future city boat marina: (Coût: 1000000 €, District: Krzyki). 3243 Voix, Classement: 10
# - Green stops in the city center: (Coût: 320000 €, District: Fabryczna). 943 Voix, Classement: 33
# - Unity Park – urban recreation: (Coût: 1000000 €, District: Fabryczna). 3026 Voix, Classement: 12
# - Lounger - a wandering piece of furniture for rest and play: (Coût: 150000 €, District: Śródmieście). 83 Voix, Classement: 50
# - Greenery for Wrocław – pocket parks, plantings, green enclaves throughout the city!: (Coût: 1000000 €, District: Psie Pole). 5398 Voix, Classement: 4
# - Intimate stage on the grass in the heart of Słodowa Island: (Coût: 400000 €, District: Fabryczna). 1161 Voix, Classement: 29
# - Green Beltway of Wrocław - trees and vines in Wrocław's neighborhoods: (Coût: 100000 €, District: Krzyki). 3362 Voix, Classement: 13
# - Planting young trees in the area of Wrocław: (Coût: 100000 €, District: Fabryczna). 5287 Voix, Classement: 6
# - Safe and friendly roads in Wrocław - speed calming lights instead of speed cameras throughout the city: (Coût: 650000 €, District: Psie Pole). 1455 Voix, Classement: 27
# - Rędziński Park: (Coût: 1000000 €, District: Krzyki). 2484 Voix, Classement: 14
# - Raising the platform surfaces at Reagan Roundabout: (Coût: 1000000 €, District: Psie Pole). 705 Voix, Classement: 36
# - Dog Field without traffic jams: (Coût: 1000000 €, District: Stare Miasto). 2081 Voix, Classement: 17
# - bus stop infrastructure on Dawida Street: (Coût: 250000 €, District: Śródmieście). 480 Voix, Classement: 40
# - NEXTBIKE City Bike Stations Wrocław Airport, CH Factory: (Coût: 150000 €, District: Krzyki). 718 Voix, Classement: 35
# - Ping-pong tables and volleyball courts throughout Wrocław.: (Coût: 1000000 €, District: Fabryczna). 3974 Voix, Classement: 8
# - Frisbee Golf: (Coût: 85000 €, District: Krzyki). 477 Voix, Classement: 44
# - Bees in the city – pollinator hotels with a resting area between Hermanowska and Chociebuska streets: (Coût: 250000 €, District: Krzyki). 1737 Voix, Classement: 21
# - Public toilet in Eastern Park: (Coût: 250000 €, District: Psie Pole). 1441 Voix, Classement: 28
# - Construction of the Wrocław handbike type inclusive bike rental facility along with appropriate social and sanitary facilities: (Coût: 550000 €, District: Psie Pole). 1912 Voix, Classement: 20
# - Urban Green Islands: (Coût: 250000 €, District: Stare Miasto). 990 Voix, Classement: 32
# - Parking spaces (park & ride) at the Pilczyce/Municipal Stadium loop: (Coût: 750000 €, District: Stare Miasto). 1608 Voix, Classement: 26
# - Network of parks in Wrocław – Psie Pole - Zawidawie 2: (Coût: 1000000 €, District: Stare Miasto). 1512 Voix, Classement: 26
# - Overhaul of the traction network at the Dąbie depot: (Coût: 500000 €, District: Krzyki). 278 Voix, Classement: 50
# - Extension of the left-turn lane towards Lotnicza Street at the intersection of Na Ostatnim Groszu and Legnicka Streets.: (Coût: 750000 €, District: Krzyki). 2901 Voix, Classement: 14
# - Fairy Tale Square for Adults and Children in Skowroni Park: (Coût: 500000 €, District: Psie Pole). 1619 Voix, Classement: 25
# - Playground for Older Children in Grabiszyński Park and Something Extra for Toddlers: (Coût: 560000 €, District: Krzyki). 6663 Voix, Classement: 4
# - Safe and friendly roads in Wrocław - speed calming lights instead of speed cameras throughout the city: (Coût: 650000 €, District: Psie Pole). 2070 Voix, Classement: 18
# - Outdoor chess with large-scale pieces in the city center: (Coût: 250000 €, District: Fabryczna). 619 Voix, Classement: 39
# - Neptune's Fountain at Nowy Targ Square: (Coût: 750000 €, District: Stare Miasto). 3632 Voix, Classement: 9
# - Let's connect Psie Pole and Zakrzów – a pedestrian and bicycle link: (Coût: 350000 €, District: Stare Miasto). 1331 Voix, Classement: 29
# - Bike-friendly Wrocław 2016 – streets welcoming to cyclists: (Coût: 1000000 €, District: Śródmieście). 4799 Voix, Classement: 7
# - Neptune's Fountain at Nowy Targ Square: (Coût: 1000000 €, District: Śródmieście). 2123 Voix, Classement: 15
# - Timetables at the stops for lines 2, 6, 7, and 17, as well as at the Uniwersytecka, Wita Stwosza, Dubois stops.: (Coût: 600000 €, District: Fabryczna). 699 Voix, Classement: 37
# - Sequoia forest, fruit trees and shrubs: (Coût: 150000 €, District: Stare Miasto). 587 Voix, Classement: 38
# - Shelters for free-living cats: (Coût: 70000 €, District: Psie Pole). 4998 Voix, Classement: 5
# - Bike and stroller ramp at the exit from Sopocka Street to the Odra River Embankments: (Coût: 50000 €, District: Fabryczna). 266 Voix, Classement: 44
# - Bike Wrocław 2017: (Coût: 1000000 €, District: Stare Miasto). 8640 Voix, Classement: 3
# - NEXTBIKE City Bike Station Świebodzki Station: (Coût: 100000 €, District: Stare Miasto). 245 Voix, Classement: 51
# - Development of the bathing area in Oporów, in order to make it available as an open recreation area.: (Coût: 1000000 €, District: Fabryczna). 2001 Voix, Classement: 18
# - NEXTBIKE city bike stations at the Nowy Dwór bus loop.: (Coût: 250000 €, District: nan). 436 Voix, Classement: 47
# - Green Promenade through Krzyki Stage I: (Coût: 1000000 €, District: Krzyki). 1973 Voix, Classement: 19
# - "Konikowo" - Construction of an original playground at the Wrocław Racecourse - Partynice: (Coût: 1000000 €, District: Stare Miasto). 3949 Voix, Classement: 10
# - Wrocław at your fingertips – tactile maps of selected areas of Wrocław.: (Coût: 130000 €, District: Stare Miasto). 156 Voix, Classement: 48
# - Honey Meadows in Wrocław: (Coût: 100000 €, District: Psie Pole). 1092 Voix, Classement: 30
# - Renovation of Gliniana Street - Ślężna to Borowska section: (Coût: 510000 €, District: Śródmieście). 522 Voix, Classement: 42
# - Physicists' Boulevard - a scientific playground in the urban space (city-wide): (Coût: 1000000 €, District: Psie Pole). 4149 Voix, Classement: 7
# - Civilization in Wojszyce - Light for All - Installation of city lanterns on Smardzowska Street in the European Capital of Culture: (Coût: 40000 €, District: Śródmieście). 281 Voix, Classement: 49
# - Tuscany in Wrocław: flower pots around the Wrocław Market Square.: (Coût: 350000 €, District: Krzyki). 619 Voix, Classement: 37
# - On foot from Brochów - completion of the missing sidewalk on I. Mościckiego, Gazowa, and Karwińska Streets (mainly concerns the viaduct over the tracks connecting these three streets): (Coût: 1000000 €, District: Krzyki). 4468 Voix, Classement: 6
# - Sporty Amber: (Coût: 1000000 €, District: Krzyki). 1613 Voix, Classement: 24
# - Benches at the Stops: (Coût: 100000 €, District: Stare Miasto). 831 Voix, Classement: 33
# - Large outdoor chess in the center of Wrocław: (Coût: 250000 €, District: Stare Miasto). 263 Voix, Classement: 45
# - The base of little astronauts, or the cosmic playground in Mini Park on F. Hynka Street.: (Coût: 1000000 €, District: Krzyki). 4098 Voix, Classement: 8
# - Wrocław Sports Arena - Zone A: (Coût: 1000000 €, District: Krzyki). 3368 Voix, Classement: 12
# - Cleaning of the sandstone medallions with the coat of arms of Wrocław from war-time grime and soot on old school buildings, hospitals, and other public buildings.: (Coût: 150000 €, District: Krzyki). 415 Voix, Classement: 43
# - Bouldering wall.: (Coût: 150000 €, District: Krzyki). 648 Voix, Classement: 38
# - New Starry: (Coût: 90000 €, District: Krzyki). 1025 Voix, Classement: 30
# - Green cycling and walking ring road of Wrocław; Stage I - section connecting Gaj, Wojszyce, Ołtaszyn, Partynice, Jagodno, Tarnogaj Krzyki, Borek.: (Coût: 1000000 €, District: Krzyki). 12348 Voix, Classement: 2
# - Toilets in Wrocław parks and recreational areas.: (Coût: 900000 €, District: Śródmieście). 10857 Voix, Classement: 1
# - Surface calming on Złotnicka Street: (Coût: 1000000 €, District: Fabryczna). 1717 Voix, Classement: 22
# - Lighting of Grabiszyński Park (Romera Avenue and paths to Grabiszyński Cemetery and Racławicka Street along the clearings): (Coût: 1000000 €, District: Krzyki). 7291 Voix, Classement: 3
# - The Untapped Potential of Skowroni Park - Revitalization: (Coût: 1000000 €, District: Śródmieście). 1644 Voix, Classement: 24
# - Renovation of unsightly railway viaducts: (Coût: 250000 €, District: Krzyki). 765 Voix, Classement: 36
# - Wrocław parks available to everyone.: (Coût: 200000 €, District: Fabryczna). 418 Voix, Classement: 42
# - Green running-walking-cycling trail from Ołtaszyn to the center (with modifications): (Coût: 750000 €, District: Krzyki). 1705 Voix, Classement: 23
# - Kępa Mieszczańska – a pocket park with a street workout station near Dmowski Bridge in Wrocław.: (Coût: 750000 €, District: Psie Pole). 882 Voix, Classement: 35
# - "Park & ride" at the Pilczyce/Wrocław Stadium loop: (Coût: 750000 €, District: Fabryczna). 1060 Voix, Classement: 31
# - Physicists' Boulevard - Stage 1: Acoustic Lenses, an experiment with sound waves in the form of a publicly accessible installation: (Coût: 250000 €, District: Krzyki). 1825 Voix, Classement: 21
# - City toilets in parks befitting Wrocław.: (Coût: 1000000 €, District: Śródmieście). 4008 Voix, Classement: 9
# - Reagan Roundabout up to standard! Construction of platforms at Reagan Roundabout.: (Coût: 1000000 €, District: Psie Pole). 1839 Voix, Classement: 20
# - Completion of the pedestrian and bicycle route around Wielka Wyspa: (Coût: 1000000 €, District: Krzyki). 2260 Voix, Classement: 15
# - Boarding at level - construction of Górnicki's Viennese stops: (Coût: 500000 €, District: Śródmieście). 433 Voix, Classement: 41
# - Construction of traffic lights at the intersection near Skwer Pionierów Wrocławskich: (Coût: 900000 €, District: Fabryczna). 120 Voix, Classement: 52
#
#
# Your task is to analyze the following project, proposed as part of a new participatory budgeting election.
#
# Project: Rędziński Park
# Cost: 1000000 €
# District: Krzyki
# Description: Justification
# The concept of the Park in Maślice was designed based on a survey conducted among its current users. It takes into account two main target groups: families with children and young, active sports enthusiasts. Currently, this area is perceived by residents as a green space—unfortunately, neglected. Given the development of the estate and the need to create new meeting places for residents, as well as Wrocław's efforts to earn the title of European Green Capital, this area should gain a new look.
#
# The park development project includes paths, prepared based on the state of tree cover and potential costs of clearing the trails to a minimum width of 2.5 m—cycling, running, and walking paths—leveled and prepared for stroller access. Additionally, the project includes health trail routes connected by crossings made of wooden bridges, culverts, and balance beams. The paths will be connected to sandy squares where wooden play equipment and willow wigwams will be located. The park's hill will also be utilized—it will be planted with a spiral hedge, and plastic slides will be built into its sides. At the top, there will be a viewing point with a circular gazebo and swing benches.
#
# The park paths will be equipped with a series of educational and sensory boards. Existing blackberry hedges will be densified with raspberry bushes in various varieties and fruiting seasons. The concept also includes the development of two water reservoirs. Two crossings over them in the form of wooden bridges are planned. Near one of the ponds, there will be a spot for exercises with a shock-absorbing surface and a place for outdoor gym equipment. The area will also feature two fire pits, gazebos, benches, and wooden loungers made from tree trunks.
#
# Based on:
# - Your knowledge of Wroclaw, its urban context, and its social and environmental issues
# - The characteristics of the project (theme, cost, district, etc.)
# - Similarities with previous projects that received votes
# - Typical voting dynamics in participatory budgeting elections
#
# In this new election, 50 alternative projects have been proposed
#
# Please answer the following questions regarding this project:
# - What is a reasonable estimate of the number of votes this project might receive?
# - What would be its expected ranking in the final list?
# - Is it likely that this project will be in the Top 5 by votes?
# - Is it likely that this project will be in the Top 10 by votes?
#
# Please answer in the form of a JSON dictionary with the following keys:
#
# ```json
# {
#   "estimated_votes": X,               // Estimated number of votes (integer)
#   "confidence_interval": [a, b],     // Realistic interval (min, max)
#   "expected_rank": Y,                // Expected rank in the final list
#   "in_top_5": 1 or 0,                // 1 if likely to be in the top 5, else 0
#   "in_top_10": 1 or 0                // 1 if likely to be in the top 10, else 0
# }
# ```
#
# Before giving an answer, take the time to reason thoroughly, but only explain the essential reasoning.
#
# **OUTPUT INSTRUCTIONS**
# 1. Present your reasoning in 5 to 8 key points, concisely.
# 2. At the end, provide a valid JSON dictionary only, with no additional text.

# %%
test['n_tokens'] = test['prompt'].apply(lambda p: tokens_counter(p))
test['cost_usd'] = test['n_tokens'].apply(lambda n_tokens: prompt_cost(n_tokens, 'gpt-4-turbo'))

print('mean tokens by prompt: {:.2f}'.format(test.n_tokens.mean()))
print('avg.cost of each prediction: ${:.2f}'.format(test.cost_usd.mean()))
print('experiment total cost: {:.2f}'.format(test.cost_usd.sum()))
# Out:
# mean tokens by prompt: 5435.10
# avg.cost of each prediction: $0.05
# experiment total cost: 2.72

# %%
#3. run experiment! :)
api_key=os.getenv('OPENAI_API_KEY')
from llm_client import call_openai_model 

test['out'] = test['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))

# %%
def get_json_from_llm_response(out):
    match = re.search(r"```json\s*({.*?})\s*```", out, re.DOTALL)
    if match:
        json_str = match.group(1)
        data = json.loads(json_str)
        return data
    else:
        return "No JSON in LLM answer..."
    
def get_predicted_votes(df, out_json):
    relative_estimation = (out_json['estimated_votes'] / df[df['year']==2016].votes.sum())
    return relative_estimation*df[df['year']==2017].votes.sum()
    
def get_predicted_rank(out_json):
    return out_json['expected_rank']

def get_if_is_top5(out_json):
    return out_json['in_top_5']

def get_if_is_top10(out_json):
    return out_json['in_top_10']

test['out_json'] = test['out'].apply(
    lambda o: ut.get_json_from_llm_response(o))

# %%
test['predicted_votes'] = test['out_json'].apply(lambda x: get_predicted_votes(df, x))
test['predicted_rank'] = test['out_json'].apply(lambda x: get_predicted_rank(x))
test['is_top5'] = test['out_json'].apply(lambda x: get_if_is_top5(x))
test['is_top10'] = test['out_json'].apply(lambda x: get_if_is_top10(x))

# %%
results = test.filter(['project_id', 
             'votes', 
             'real_rank',
             'prompt',
             'out',
             'out_json', 
             'predicted_votes', 
             'predicted_rank', 
             'is_top5', 
             'is_top10']
             )
results

# %%
results.to_csv('output/predictions/wrc_in_context_full_eng_1.csv', sep=";", index=False)
print('results ready!')
