# %%
# 1. load data
import sys
import os
from dotenv import load_dotenv
sys.path.append(os.path.abspath("../src"))

from data_loader import load_and_prepare_projects, load_prediction_set

path_22 = '../data/projects2022.csv'
path_24 = '../data/projects2024.csv'

df, df22_shuffled = load_and_prepare_projects(path_22,path_24)

ids_to_predict_path = '../data/projects_to_predict_2024.csv'
test = load_prediction_set(df, ids_to_predict_path)

# %%
df
# Out:
#      project_id                                       project_name  \
# 0           136                Piste cyclable avenue Saint-Exupéry
# 1             7  Faire des voies vélos et piétons dédiées et bi...
# 2             5             Végétalisation de la place du Capitole
# 3           132                              Lutte anti-moustiques
# 4            71  Planter des arbres et jardins partagés partout...
# ..          ...                                                ...
# 378         372  Installation d'un portique pour réparer les vé...
# 379         356  Débitumiser les places de stationnement rue Be...
# 380         230  Installation de poubelles à déjection aux Sept...
# 381         370  Installer des tables et des chaises au Parc Ma...
# 382         374  Améliorer la propreté de l'aire de jeux Jean G...
#
#                                            description  \
# 0    Lorsque l'on habite vers la place de l'ormeau,...
# 1    Pour favoriser la cohabitation piétons/cyclist...
# 2    Pour donner encore plus de majesté à ce lieu e...
# 3    Mise en place de pièges à moustiques dans le q...
# 4    Une voisine exploite un bout du terrain du sup...
# ..                                                 ...
# 378  Fleury : Place André Abbal (Reynerie): Il sera...
# 379  Je propose d’enlever le bitume sur les places ...
# 380  Installer sur le quartier des sept deniers, de...
# 381  Il n’y a pas assez de tables et de chaises pou...
# 382  Nécessité de rénover l'aire de jeux de Jean Gi...
#
#                             category      cost  \
# 0                       Éco-mobilité  200000.0
# 1                       Éco-mobilité  150000.0
# 2                    Nature en ville  200000.0
# 3                    Nature en ville    7500.0
# 4                    Nature en ville   20000.0
# ..                               ...       ...
# 378       Éco-mobilité et transports    5000.0
# 379  Nature en ville et biodiversité  240000.0
# 380                     Cadre de vie    6000.0
# 381                     Cadre de vie   85000.0
# 382                     Cadre de vie    3000.0
#
#                                               district  votes district_number  \
# 0    12 - Pont des Demoiselles / Ormeau / Montaudra...    492              12
# 1               1 - Capitole / Arnaud Bernard / Carmes    467               1
# 2               1 - Capitole / Arnaud Bernard / Carmes    358               1
# 3    12 - Pont des Demoiselles / Ormeau / Montaudra...    258              12
# 4    8 - Minimes / Barrière de Paris / Ponts-Jumeau...    243               8
# ..                                                 ...    ...             ...
# 378  17 - Mirail-Université / Reynerie / Bellefontaine     20              17
# 379             15 - Croix de Pierre / Route d'Espagne     19              15
# 380  7 - Sept Deniers / Ginestous-Sesquières / Lalande     19               7
# 381  17 - Mirail-Université / Reynerie / Bellefontaine     18              17
# 382  17 - Mirail-Université / Reynerie / Bellefontaine     17              17
#
#      rank  year
# 0       1  2022
# 1       2  2022
# 2       3  2022
# 3       4  2022
# 4       5  2022
# ..    ...   ...
# 378   179  2024
# 379   180  2024
# 380   181  2024
# 381   182  2024
# 382   183  2024
#
# [383 rows x 10 columns]

# %% [markdown]
# #### Prompt 1: Cost Estimation GPT-4-Turbo

# %%
from prompt_utils import tokens_counter, prompt_cost
from prompt_builder import build_prompt, get_all_projects_from_22_election

last_projects_results = get_all_projects_from_22_election(df22_shuffled)

test['prompt'] = test.apply(
    lambda x: build_prompt(
        '../prompts/prompt_template1.txt',
        {
            'last_projects_results': last_projects_results,
            'project_name': x['project_name'],
            'cost': x['cost'],
            'district': x['district'],
            'description': x['description']
        }
    ),
    axis=1
)

test['n_tokens'] = test['prompt'].apply(lambda p: tokens_counter(p))
test['cost_usd'] = test['n_tokens'].apply(lambda n_tokens: prompt_cost(n_tokens, 'gpt-4-turbo'))

print('mean tokens by prompt: {:.2f}'.format(test.n_tokens.mean()))
print('experiment total cost: {:.2f}'.format(test.cost_usd.sum()))
# Out:
# mean tokens by prompt: 13454.16
# experiment total cost: 4.98

# %% [markdown]
# #### Prompt 2 (CoT): Cost Estimation GPT-4-Turbo

# %%
from prompt_utils import tokens_counter, prompt_cost
from prompt_builder import build_prompt, get_all_projects_from_22_election

last_projects_results = get_all_projects_from_22_election(df22_shuffled)

test['prompt'] = test.apply(
    lambda x: build_prompt(
        '../prompts/prompt_template3_CoT.txt',
        {
            'last_projects_results': last_projects_results,
            'project_name': x['project_name'],
            'cost': x['cost'],
            'district': x['district'],
            'description': x['description']
        }
    ),
    axis=1
)

test['n_tokens'] = test['prompt'].apply(lambda p: tokens_counter(p))
test['cost_usd'] = test['n_tokens'].apply(lambda n_tokens: prompt_cost(n_tokens, 'gpt-4-turbo'))

print('mean tokens by prompt: {:.2f}'.format(test.n_tokens.mean()))
print('avg.cost of each prediction: ${:.2f}'.format(test.cost_usd.mean()))
print('experiment total cost: {:.2f}'.format(test.cost_usd.sum()))
# Out:
# mean tokens by prompt: 13547.16
# avg.cost of each prediction: $0.14
# experiment total cost: 5.01

# %% [markdown]
# #### Prompt 4: (RAG + CoT): Cost Estimation GPT-4-Turbo

# %%
import prompt_builder as pb

conn_params = {
    "host": os.environ["PG_HOST"],
    "database": os.environ["PG_DATABASE"],
    "user": os.environ["PG_USER"],
    "password": os.environ['PG_PASSWORD']
}


print(pb.get_top_k_similar_projects_in_22_by_district(df,136,conn_params, k=5))
# Out:
# - Restructuration "verte" de la place Roger Arnaud: (Coût: 200000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 112 Voix, Classement: 26
# - Installation d’un parcours de santé au quartier Montaudran vers la Halle de la Machine: (Coût: 150000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 76 Voix, Classement: 49
# - Création d une piste cyclable avenue de la Marcaissonne: (Coût: 200000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 52 Voix, Classement: 71
# - Le développement de l'auto partage: (Coût: 4500.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 35 Voix, Classement: 108
# - Aménagement parc rue du Canigou: (Coût: 150000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 11 Voix, Classement: 164

# %%
df
# Out:
#      project_id                                       project_name  \
# 0           136                Piste cyclable avenue Saint-Exupéry
# 1             7  Faire des voies vélos et piétons dédiées et bi...
# 2             5             Végétalisation de la place du Capitole
# 3           132                              Lutte anti-moustiques
# 4            71  Planter des arbres et jardins partagés partout...
# ..          ...                                                ...
# 378         372  Installation d'un portique pour réparer les vé...
# 379         356  Débitumiser les places de stationnement rue Be...
# 380         230  Installation de poubelles à déjection aux Sept...
# 381         370  Installer des tables et des chaises au Parc Ma...
# 382         374  Améliorer la propreté de l'aire de jeux Jean G...
#
#                                            description  \
# 0    Lorsque l'on habite vers la place de l'ormeau,...
# 1    Pour favoriser la cohabitation piétons/cyclist...
# 2    Pour donner encore plus de majesté à ce lieu e...
# 3    Mise en place de pièges à moustiques dans le q...
# 4    Une voisine exploite un bout du terrain du sup...
# ..                                                 ...
# 378  Fleury : Place André Abbal (Reynerie): Il sera...
# 379  Je propose d’enlever le bitume sur les places ...
# 380  Installer sur le quartier des sept deniers, de...
# 381  Il n’y a pas assez de tables et de chaises pou...
# 382  Nécessité de rénover l'aire de jeux de Jean Gi...
#
#                             category      cost  \
# 0                       Éco-mobilité  200000.0
# 1                       Éco-mobilité  150000.0
# 2                    Nature en ville  200000.0
# 3                    Nature en ville    7500.0
# 4                    Nature en ville   20000.0
# ..                               ...       ...
# 378       Éco-mobilité et transports    5000.0
# 379  Nature en ville et biodiversité  240000.0
# 380                     Cadre de vie    6000.0
# 381                     Cadre de vie   85000.0
# 382                     Cadre de vie    3000.0
#
#                                               district  votes district_number  \
# 0    12 - Pont des Demoiselles / Ormeau / Montaudra...    492              12
# 1               1 - Capitole / Arnaud Bernard / Carmes    467               1
# 2               1 - Capitole / Arnaud Bernard / Carmes    358               1
# 3    12 - Pont des Demoiselles / Ormeau / Montaudra...    258              12
# 4    8 - Minimes / Barrière de Paris / Ponts-Jumeau...    243               8
# ..                                                 ...    ...             ...
# 378  17 - Mirail-Université / Reynerie / Bellefontaine     20              17
# 379             15 - Croix de Pierre / Route d'Espagne     19              15
# 380  7 - Sept Deniers / Ginestous-Sesquières / Lalande     19               7
# 381  17 - Mirail-Université / Reynerie / Bellefontaine     18              17
# 382  17 - Mirail-Université / Reynerie / Bellefontaine     17              17
#
#      rank  year
# 0       1  2022
# 1       2  2022
# 2       3  2022
# 3       4  2022
# 4       5  2022
# ..    ...   ...
# 378   179  2024
# 379   180  2024
# 380   181  2024
# 381   182  2024
# 382   183  2024
#
# [383 rows x 10 columns]

# %%
import prompt_builder as pb
from prompt_utils import tokens_counter, prompt_cost

load_dotenv()

conn_params = {
    "host": os.environ["PG_HOST"],
    "database": os.environ["PG_DATABASE"],
    "user": os.environ["PG_USER"],
    "password": os.environ['PG_PASSWORD']
}

top_k_voted_22 = pb.get_top_k_projects_from_22_election(df, k=10)
proj_count_avg_by_district= pb.get_project_count_and_avg_votes_by_district(df)
proj_count_avg_by_categories = pb.get_project_count_and_avg_votes_by_categories(df)

test['prompt'] = test.apply(
    lambda x: pb.build_prompt(
        '../prompts/prompt_rag2_CoT.txt',
        {
            'top_k_voted_22': top_k_voted_22,
            'project_count_and_avg_votes_by_district': proj_count_avg_by_district,
            'project_count_and_avg_votes_by_categories': proj_count_avg_by_categories,
            'project_name': x['project_name'],
            'cost': x['cost'],
            'district': x['district'],
            'description': x['description'],
            'top_k_similar_projects_in_22': pb.get_top_k_similar_projects_in_22(df,x['project_id'],conn_params, k=10),
            'count_of_projects22_in_quartier': pb.get_count_of_projects_in_quartier(df,x['district']),
            'top_k_voted_in_district': pb.get_top_k_voted_in_district(df, x['district'], k=5),
            'count_of_projects24_in_quartier': pb.get_count_of_projects_in_quartier(df,x['district'], year=2024),
            'top_k_similar_projects_in_district': pb.get_top_k_similar_projects_in_22_by_district(df, x['project_id'], conn_params,k=5)
        }
    ),
    axis=1
)

test['n_tokens'] = test['prompt'].apply(lambda p: tokens_counter(p))
test['cost_usd'] = test['n_tokens'].apply(lambda n_tokens: prompt_cost(n_tokens, 'gpt-4-turbo'))

print('mean tokens by prompt: {:.2f}'.format(test.n_tokens.mean()))
print('avg.cost of each prediction: ${:.2f}'.format(test.cost_usd.mean()))
print('experiment total cost: {:.2f}'.format(test.cost_usd.sum()))
# Out:
# mean tokens by prompt: 3949.70
# avg.cost of each prediction: $0.04
# experiment total cost: 1.46

# %%
print(test['prompt'][0])
# Out:
# Vous êtes un modèle expert dans l’analyse des élections de budgets participatifs, spécifiquement dans le contexte de la ville de Toulouse, en France.
#
# À Toulouse, la municipalité organise des élections de budget participatif pour financer des projets citoyens. Chaque habitant peut voter pour entre 1 et 3 initiatives sur le site web officiel. Les votes sont anonymes.
#
# Voici comment les projets sont sélectionnés :
# - Tous les projets sont classés selon le nombre de voix obtenues.
# - Un algorithme « greedy » est utilisé : on finance les projets dans l’ordre décroissant des voix, tant que le budget total n’est pas dépassé.
# - Si un projet est trop coûteux pour le budget restant, on passe au suivant.
#
# ---
#
# Lors de l’élection de 2022 :
# - Il y a eu **4532 votants**, chaque personne pouvant voter pour jusqu'à 3 projets.
# - Au total, environ **11918 voix** ont été exprimées sur **200 projets**.
# - Le nombre de voix par projet variait de *2* à 492, avec une moyenne autour de **58** voix et un écart-type estimé de **68**.
# - La majorité des projets ont reçu entre **18 et 75 voix**.
# - Le budget total disponible était de **8000000 €**.
#
# Dans cette édition, les 10 projets les plus votés étaient les suivants :
#
# - Piste cyclable avenue Saint-Exupéry: (Coût: 200000.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 492 Voix, Classement: 1
# - Faire des voies vélos et piétons dédiées et bien délimitées: (Coût: 150000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 467 Voix, Classement: 2
# - Végétalisation de la place du Capitole: (Coût: 200000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 358 Voix, Classement: 3
# - Lutte anti-moustiques: (Coût: 7500.0 €, District: 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère). 258 Voix, Classement: 4
# - Planter des arbres et jardins partagés partout où c'est possible!: (Coût: 20000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 243 Voix, Classement: 5
# - Réaménagement piéton, vélos et végétalisation allées Charles de Fitte: (Coût: 175000.0 €, District: 6 - Saint-Cyprien). 206 Voix, Classement: 6
# - Un complexe sportif en zone urbaine: (Coût: 130000.0 €, District: 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux). 205 Voix, Classement: 7
# - Terrain couvert au niveau du boulodrome: (Coût: 200000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 189 Voix, Classement: 8
# - Éclairage nocturne à détecteur de mouvements : (Coût: 200000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 189 Voix, Classement: 9
# - Aménager le Rond-Point des Français Libres et le carrefour Demoiselles - Mistral - Frizac - Duméril - St Joseph: (Coût: 200000.0 €, District: 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir). 178 Voix, Classement: 10
#
#
# Voici, pour chaque quartier, le nombre de projets proposés et le nombre moyen de voix reçues lors de l’élection de 2022 :
# 1 - Capitole / Arnaud Bernard / Carmes : 10 projets, moyenne de voix 136.9.
# 10 - Jolimont / Soupetard / Roseraie / Gloire / Gramont / Amouroux : 10 projets, moyenne de voix 71.4.
# 11 - Bonhoure / Guilheméry / Château de l'Hers / Limayrac / Côte Pavée : 10 projets, moyenne de voix 43.6.
# 12 - Pont des Demoiselles / Ormeau / Montaudran / La Terrasse / Malepère : 10 projets, moyenne de voix 116.9.
# 13 - Rangueil / Sauzelong / Jules-Julien / Pech-David / Pouvourville : 10 projets, moyenne de voix 55.7.
# 14 - Saint-Simon / Lafourguette / Oncopole-Campus Santé du Futur : 10 projets, moyenne de voix 40.4.
# 15 - Croix de Pierre / Route d'Espagne : 10 projets, moyenne de voix 45.1.
# 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette : 10 projets, moyenne de voix 39.2.
# 17 - Mirail-Université / Reynerie / Bellefontaine : 10 projets, moyenne de voix 10.5.
# 18 - Lardenne / Pradettes / Basso-Cambo : 10 projets, moyenne de voix 62.2.
# 19 - Casselardit / Fontaine-Bayonne / Cartoucherie : 10 projets, moyenne de voix 49.8.
# 2 - Amidonniers / Compans-Caffarelli / Brouardel : 10 projets, moyenne de voix 58.2.
# 20 - Arènes Romaines / Ancely / Saint-Martin du Touch / Purpan : 10 projets, moyenne de voix 43.8.
# 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy : 10 projets, moyenne de voix 52.4.
# 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne : 10 projets, moyenne de voix 41.0.
# 5 - Saint-Michel / Saint-Agne / Empalot / Le Busca / Ile du Ramier / Monplaisir : 10 projets, moyenne de voix 76.8.
# 6 - Saint-Cyprien : 10 projets, moyenne de voix 77.8.
# 7 - Sept Deniers / Ginestous-Sesquières / Lalande : 10 projets, moyenne de voix 30.8.
# 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre : 10 projets, moyenne de voix 75.2.
# 9 - Trois Cocus / Borderouge / Croix-Daurade / Paléficat / Grand Selve : 10 projets, moyenne de voix 32.9.
#
#
# Le nombre de projets proposés par catégorie et le nombre moyen de voix par catégorie lors de l’élection de 2022 étaient les suivants :
# Cadre de vie : 73 projets, moyenne de voix: 31.25
# Consommation responsable : 2 projets, moyenne de voix: 30.50
# Déchets et Recyclage : 5 projets, moyenne de voix: 47.00
# Nature en ville : 78 projets, moyenne de voix: 76.10
# Éco-mobilité : 35 projets, moyenne de voix: 73.20
# Énergie : 7 projets, moyenne de voix: 75.86
#
#
# ---
#
# Votre tâche est maintenant d’évaluer un nouveau projet soumis à l’élection suivante, dans laquelle **183 projets ont été proposés** et un plus grand nombre de participants est attendu.
#
# **Projet à analyser :**
# - Nom : Piétons, vélos et bus sur le boulevard Riquet
# - Coût : 250000.0 €
# - Quartier : 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy
# - Description : Apaisement du Boulevard Riquet en séparant les usages par la création de (1) une voie de bus dédiée ; (2) une piste cyclable (voie isolée à la place d'une voie voitures sur la chaussée, en urbanisme tactique si besoin), donc séparée des piétons (qui marcheront plus tranquillement en bord de Canal), comme le long du Boulevard Monplaisir. Aménagement à créer depuis la passerelle Saint-Aubin (ou avant depuis la caserne Genes Lougnon) jusqu'aux Allées Jean-Jaurès.🔎 CE QUE PRÉVOIENT LES SERVICES : Dans le cadre de cet appel à idées, au regard des délais et budget associés, il ne peut être réalisé un aménagement sur la totalité du linéaire allant de la Caserne Gènes Lougnon aux allées Jean-Jaurès. Néanmoins, dans l'attente de la mise en œuvre du projet Grand Parc Canal, qui aura pour objectif de réorganiser et sécuriser les déplacements le long des canaux (piétons, cyclistes, transports en commun, voitures), et afin de pouvoir d'ores et déjà améliorer les conflits d'usage en bord de canal et ainsi les déplacements des piétons, des interventions ponctuelles peuvent être envisagées, aux endroits les plus sensibles qui auront été définis au préalable. Egalement, entre le Pont Constantine et le Pont Riquet, l'aménagement d'une piste cyclable monodirectionnelle pourra être étudiée : à noter qu'un tel aménagement supprimerait environ 45 places de stationnement.
#
# En vous basant sur :
# - Les dynamiques de vote observées en 2022.
# - Le coût, le quartier et la thématique du projet.
# - Votre compréhension du contexte social, écologique et politique de Toulouse.
#
# ---
#
# En complément, voici une sélection de projets similaires dans toute la ville, présentés lors de l’élection de 2022 et présentant une forte similarité sémantique avec le projet à analyser.
# Chaque projet inclut :
# - le nom du projet,
# - le quartier concerné,
# - le coût estimé,
# - le nombre de voix obtenues,
# - et leur position dans le classement final.
#
# - Faire des voies vélos et piétons dédiées et bien délimitées: (Coût: 150000.0 €, District: 1 - Capitole / Arnaud Bernard / Carmes). 467 Voix, Classement: 2
# - Réaménagement piéton, vélos et végétalisation allées Charles de Fitte: (Coût: 175000.0 €, District: 6 - Saint-Cyprien). 206 Voix, Classement: 6
# - Piste vélos terrifique sur le boulevard Matabiau: (Coût: 200000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 83 Voix, Classement: 44
# - Piste cyclable et sens unique rue de Périole : (Coût: 50000.0 €, District: 4 - Lapujade / Bonnefoy / Périole / Marengo / La Colonne). 67 Voix, Classement: 55
# - Une piste cyclable pour une meilleure continuité rue Henri Desbals: (Coût: 45000.0 €, District: 16 - Fontaine-Lestang / Arènes / Bagatelle / Papus / Tabar / Bordelongue / Mermoz / La Faourette). 66 Voix, Classement: 58
# - Apaisement du Boulevard Riquet: (Coût: 75000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 64 Voix, Classement: 60
# - Sécuriser le passage du pont de la Cépière pour les cyclistes: (Coût: 200000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 64 Voix, Classement: 61
# - Rue Negreneys : Un transport pour tous :  piste cyclable continue, sécurité pour les piétons et réduction de la vitesse : (Coût: 150000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 47 Voix, Classement: 87
# - Un double sens cyclable entre l'usine Airbus Saint-Eloi et le Canal du midi  (Chemin du Sang de Serp): (Coût: 60000.0 €, District: 8 - Minimes / Barrière de Paris / Ponts-Jumeaux / La Vache / Raisins / Fondeyre). 43 Voix, Classement: 93
# - Sécuriser les piétons: (Coût: 150000.0 €, District: 2 - Amidonniers / Compans-Caffarelli / Brouardel). 22 Voix, Classement: 137
# - Ralentisseurs chemin du Touch: (Coût: 60000.0 €, District: 18 - Lardenne / Pradettes / Basso-Cambo). 3 Voix, Classement: 193
#
#
# ---
#
# Dans le quartier 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy, 10 projets ont été proposés, et les projets les plus votés étaient :
#
# - Végétaliser la rue Matabiau: (Coût: 200000.0 €). 95 Voix, Classement: 35
# - Végétalisation et convivialité du quartier Saint-Aubin: (Coût: 30000.0 €). 94 Voix, Classement: 36
# - Piste vélos terrifique sur le boulevard Matabiau: (Coût: 200000.0 €). 83 Voix, Classement: 44
# - Arborer la rue Raymond IV: (Coût: 200000.0 €). 65 Voix, Classement: 59
# - Apaisement du Boulevard Riquet: (Coût: 75000.0 €). 64 Voix, Classement: 60
#
#
# Cette année, 10 projets ont été proposés dans le quartier.
#
# Voici une sélection de projets similaires issus de l’élection précédente et situés dans le même quartier :
#
# - Végétaliser la rue Matabiau: (Coût: 200000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 95 Voix, Classement: 35
# - Végétalisation et convivialité du quartier Saint-Aubin: (Coût: 30000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 94 Voix, Classement: 36
# - Piste vélos terrifique sur le boulevard Matabiau: (Coût: 200000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 83 Voix, Classement: 44
# - Apaisement du Boulevard Riquet: (Coût: 75000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 64 Voix, Classement: 60
# - Améliorations possibles Quartier Belfort / Denfert Rochereau: (Coût: 200000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 50 Voix, Classement: 78
# - Végétalisation de la rue Agathoise: (Coût: 150000.0 €, District: 3 - Les Chalets / Bayard / Belfort / Saint Aubin / Dupuy). 16 Voix, Classement: 154
#
#
# ---
#
# Veuillez répondre sous la forme d’un dictionnaire JSON avec les clés suivantes :
#
# ```json
# {
#   "voix_estimées": X,                // Nombre estimé de voix (entier)
#   "intervalle_confiance": [a, b],   // Intervalle réaliste (min, max)
#   "position_attendue": Y,           // Rang estimé dans le classement
#   "dans_top_5": 1 ou 0,             // 1 si probable d'être dans le top 5, sinon 0
#   "dans_top_10": 1 ou 0             // 1 si probable d'être dans le top 10, sinon 0
# }
# Avant de donner une réponse, prenez le temps de raisonner en profondeur, mais expliquez seulement le raisonnement essentiel.
#
# **INSTRUCTIONS DE SORTIE**
# 1. Exposez votre raisonnement en 5 à 8 points clés maximum, de façon concise.
# 2. À la fin, fournissez uniquement un dictionnaire JSON valide, sans autre texte.

# %% [markdown]
# #### Calulo en Llama 3.1 70b

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("meta-llama/Meta-Llama-3.1-8B-Instruct")
prompt = "Tu texto aquí"
n_tokens = len(tokenizer.encode(prompt))
print("Tokens:", n_tokens)
