# %% [markdown]
# #### TLS 24

# %%
# 1. load data
import os
import pandas as pd
import src.utils as ut
import prompt_builder as pb

from dotenv import load_dotenv
from src.data_loader import load_and_prepare_projects, load_test_dataset
from prompt_utils import tokens_counter, prompt_cost


path_22 = 'data/tls22_projects.csv'
path_24 = 'data/tls24_projects.csv'

df, df22_shuffled = load_and_prepare_projects(path_22,path_24, city = "Toulouse")
test = load_test_dataset(df, rows = len(df[df['year'] == 2024]), city = 'Toulouse')

load_dotenv()

conn_params = {
    "host": os.environ["PG_HOST"],
    "database": os.environ["PG_DATABASE"],
    "user": os.environ["PG_USER"],
    "password": os.environ['PG_PASSWORD']
}

# %%
#2. build prompt
test['prompt'] = test.apply(
    lambda x: pb.build_prompt(
        'prompts/prompt_simple_fr.txt',
        {
            'project_name': x['project_name'],
            'cost': x['cost'],
            'district': x['district'],
            'description': x['description']
        }
    ),
    axis=1
)

# %%
print(test['prompt'].iloc[0])
# Out:
# Vous êtes un modèle expert dans l’analyse des élections de budgets participatifs, spécifiquement dans le contexte de la ville de Toulouse, en France.
#
# À Toulouse, la municipalité organise des élections de budget participatif pour financer des projets citoyens. Chaque habitant peut voter pour entre 1 et 3 initiatives sur le site web officiel.
#
# Une fois la période de vote terminée, les projets sont classés selon le nombre de voix obtenues et se voient attribuer un rang. Ensuite, les projets gagnants sont sélectionnés à l’aide d’un algorithme greedy : on commence par le projet ayant obtenu le plus de voix, puis on ajoute successivement les projets suivants les plus votés, tant que le budget disponible le permet.
# Lorsque le budget restant ne permet plus de financer le projet suivant dans la liste, on passe au suivant qui peut l’être, et ainsi de suite, jusqu’à épuisement du budget total de 8000000 euros.
#
#
# Votre tâche consiste à analyser le projet suivant, proposé dans le cadre d'une nouvelle élection de budget participatif.
#
# Projet : Multiplier les places de stationnement pour les vélos en hypercentre
# Coût : 12000.0 €
# Quartier : 1 - Capitole / Arnaud Bernard / Carmes
# Description : Même si des efforts notables ont déjà été effectués, vouloir développer la part modale du vélo dans les déplacements exige d'accroître très sensiblement les possibilités d'accroche des vélos, notamment dans l'hyper centre. Les places de stationnement sont très insuffisantes autour de la place du Capitole, place Wilson, Place St Pierre, Place Arnaud Bernard, autour de St Sernin, Boulevards Carnot, Strasbourg, Arcole, rues Alsace-Lorraine, Mirepoix, Pargaminières, Rémusat, Taur, Gambetta, etc.🔎 CE QUE PRÉVOIENT LES SERVICES : Dans le cadre de ses projets d'aménagement urbain, la Collectivité intègre systématiquement du mobilier de type accroche pour les vélos.Le déploiement de mobilier urbain de type racks à vélos dans l'hyper centre s'effectue selon les besoins signalés par les riverains et usagers (sollicitation auprès du Maire de Quartier ou de la plateforme AlloToulouse 05 61 222 222) sous réserve de l'avis de l'Architecte des Bâtiments de France et de la disponibilité sur l'espace public déjà très contraint.Dans le cadre de ce dispositif, il est proposé d'installer, a minima, une cinquantaine de racks vélos par an sur le quartier 1.
#
# En vous basant sur :
#
# - Votre connaissance de Toulouse, de son contexte urbain, ainsi que de ses problématiques sociales et environnementales
# - Les caractéristiques du projet (thème, coût, quartier, etc.)
# - Les dynamiques typiques de vote dans les élections participatives
#
# Veuillez répondre aux questions suivantes concernant ce projet :
#
# 1. Quelle estimation raisonnable du nombre de voix ce projet pourrait-il obtenir ?
# 2. Quelle serait sa position attendue dans le classement final ?
#
# Veuillez répondre sous la forme d’un dictionnaire JSON avec les clés suivantes :
#
# ```json
# {
#   "voix_estimées": X,                // Nombre estimé de voix (entier)
#   "intervalle_confiance": [a, b],   // Intervalle réaliste (min, max)
#   "position_attendue": Y,           // Rang estimé dans le classement
# }
# Avant de donner une réponse, prenez le temps de raisonner en profondeur, mais expliquez seulement le raisonnement essentiel.
#
# **INSTRUCTIONS DE SORTIE**
# 1. Exposez votre raisonnement en 5 à 8 points clés maximum, de façon concise.
# 2. À la fin, fournissez uniquement un dictionnaire JSON valide, sans autre texte.

# %%
test['n_tokens'] = test['prompt'].apply(lambda p: tokens_counter(p))
test['cost_usd'] = test['n_tokens'].apply(lambda n_tokens: prompt_cost(n_tokens, 'gpt-4-turbo'))

print('mean tokens by prompt: {:.2f}'.format(test.n_tokens.mean()))
print('avg.cost of each prediction: ${:.2f}'.format(test.cost_usd.mean()))
print('experiment total cost: {:.2f}'.format(test.cost_usd.sum()))
# Out:
# mean tokens by prompt: 818.34
# avg.cost of each prediction: $0.01
# experiment total cost: 1.50

# %%
#3. run experiment! :)
api_key=os.getenv('OPENAI_API_KEY')
from llm_client import call_openai_model 

test['out'] = test['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))
# Out:
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!

# %%
import json
import re

def get_json_from_llm_response(out):
    # 1. Primer intento: el string completo es un JSON válido
    if isinstance(out, str):
        try:
            data = json.loads(out)
            if isinstance(data, dict):
                return data
        except json.JSONDecodeError:
            pass  # No es un JSON plano válido, continuamos

    # 2. Segundo intento: buscar bloque ```json {...} ```
    match = re.search(r"```json\s*({.*?})\s*```", out, re.DOTALL)
    if match:
        json_str = match.group(1)
        try:
            return json.loads(json_str)
        except json.JSONDecodeError:
            return None

    # 3. No se pudo encontrar JSON válido
    return None

def get_predicted_votes(df, out_json, city = 'Toulouse'):
    
    if city != 'Toulouse':
        raise ValueError(f"City '{city}' not supported")

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
    
    votes_2022 = df[df['year'] == 2022].votes.sum()
    votes_2024 = df[df['year'] == 2024].votes.sum()

    relative_estimation = out_json['voix_estimées'] / votes_2022
    adjusted_prediction = relative_estimation * votes_2024

    return adjusted_prediction

def get_predicted_rank(out_json):
    
    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['position_attendue']


def get_if_is_top5(out_json):

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['dans_top_5']

def get_if_is_top10(out_json):

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['dans_top_10']

# %%
test['out_json'].iloc[0]
# Out:
# {'voix_estimées': 1500,
#  'intervalle_confiance': [1200, 1800],
#  'position_attendue': 25}

# %%
test['out_json'] = test['out'].apply(
    lambda o: get_json_from_llm_response(o))

test['predicted_votes'] = test['out_json'].apply(lambda x: get_predicted_votes(df, x))
test['predicted_rank'] = test['out_json'].apply(lambda x: get_predicted_rank(x))

# %%
results = test.filter(['project_id', 
             'real_votes', 
             'real_rank',
             'prompt',
             'out',
             'out_json', 
             'predicted_votes', 
             'predicted_rank']
             )
results

# %%
results.to_csv('output/predictions/tls_simple_prompt_full_1.csv', sep=";", index=False)
print('results ready!')
# Out:
# results ready!

# %% [markdown]
# #### WRC 17

# %%
# 1. load data
import os
import pandas as pd
import src.utils as ut
import prompt_builder as pb

from dotenv import load_dotenv
from src.data_loader import load_and_prepare_projects, load_test_dataset
from prompt_utils import tokens_counter, prompt_cost


path_16 = 'data/wrc16_projects.csv'
path_17 = 'data/wrc17_projects.csv'

df, df16_shuffled = load_and_prepare_projects(path_16,path_17, city = 'Wroclaw')
test = load_test_dataset(df, rows = 50, city='Wroclaw')

load_dotenv()

conn_params = {
    "host": os.environ["PG_HOST"],
    "database": os.environ["PG_DATABASE"],
    "user": os.environ["PG_USER"],
    "password": os.environ['PG_PASSWORD']
}
# Out:
#     project_id                                       project_name  \
# 0           10  Toalety we Wrocławskich parkach i na terenach ...
# 1           50  Zielona rowerowo-piesza obwodnica Wrocławia; E...
# 2           18                              Rowerowy Wrocław 2017
# 3          675  Zieleń dla Wrocławia – parki kieszonkowe, nasa...
# 4          260                     Budki dla kotów wolno żyjących
# 5          550  Pieszo z Brochowa - uzupełnienie brakującego c...
# 6           12  Bulwar Fizyków - naukowy plac zabaw w przestrz...
# 7          159  Baza małych astronautów czyli kosmiczny plac z...
# 8          656     Toalety miejskie w parkach na miarę Wrocławia.
# 9          499  "Konikowo" - Budowa autorskiego placu zabaw na...
# 10         751                   Modernizacja ulicy DRZEWIECKIEGO
# 11         451                 Wrocławska Arena Sportu - strefa A
# 12         284  Zielona Obwodnica Wrocławia - drzewa i pnącza ...
# 13         345                                     Park Rędziński
# 14          41                Fontanna Neptuna na Placu Nowy Targ
# 15          16                Remont zabytkowego autobusu Fredruś
# 16         716  Park Grabiszyński - bezpieczne dojście! Remont...
# 17         590  Zagospodarowanie terenu kąpieliska na Oporowie...
# 18          43              Zielona Promenada przez Krzyki Etap I
# 19          46  Rondo Reagana na poziomie! Budowa peronów na R...
# 20         514  Pszczoły w mieście – hotele dla zapylaczy z pl...
# 21         553  Sieć parków we Wrocławiu - Psie Pole - Zawidaw...
# 22          68  Zielona trasa biegowo-pieszo-rowerowa z Ołtasz...
# 23         608                                 Sportowa Jantarowa
# 24         258                          Rewitalizacja ul. Ruskiej
# 25         555  Sieć parków we Wrocławiu – Psie Pole - Zawidaw...
# 26          83  Bezpieczne i przyjazne drogi we Wrocławiu - św...
# 27         680     Ścieżki pieszo-rowerowe przy ul. Opatowickiej.
# 28         372  Połączmy Psie Pole i Zakrzów – łącznik pieszo-...
# 29         688                          Miodowe łąki we Wrocławiu
# 30         668  "Park & ride" przy pętli Pilczyce/Stadion Wrocław
# 31         685                             Miejskie wyspy zieleni
# 32         694                Zielone przystanki w centrum miasta
# 33         371  Bezpieczniej na skrzyżowaniu al. Sobieskiego i...
# 34         508  Kępa Mieszczańska –park kieszonkowy z stacją s...
# 35         346          Odnowienie szpetnych wiaduktów kolejowych
# 36         358  Toskania we Wrocławiu: donice z kwiatami wokół...
# 37         594                Las sekwoi, drzewa i krzewy owocowe
# 38         332       Infrastruktura przystankowa na ul. Dworcowej
# 39         334          infrastruktura przystankowa na ul. Dawida
# 40          35  Wsiadanie na poziomie-budowa przystanków wiede...
# 41         620         Wrocławskie parki dostępne dla wszystkich.
# 42         203  Oczyszczenie z wojennego osmolenia i sadzy pia...
# 43         735  Rampa dla rowerów i wózków przy wyjściu z ulic...
# 44         464  Szachy plenerowe dużego gabarytu w centrum mia...
# 45         422          Akcja Plac - Gry uliczne "Oswajamy beton"
# 46         406  Budowa wrocławskiej wypożyczalni rowerów integ...
# 47         629  Wrocław na dotknięcie ręki – tylfograficzne ma...
# 48         720                                               1997
# 49         677  Polegiwacz - wędrujący mebel do odpoczynku i z...
#
#                                           description     cost      district  \
# 0   Uzasadnienie\nW parkach i na terenach zielonyc...   900000   Śródmieście
# 1   Uzasadnienie\nWalczymy o II ETAP. Ideą jest po...  1000000  Stare Miasto
# 2   Uzasadnienie\nProjekt przewiduje poprawę bezpi...  1000000  Stare Miasto
# 3   Uzasadnienie\nWe Wrocławiu nastąpiła deklaraty...  1000000     Psie Pole
# 4                                        Uzasadnienie    70000     Psie Pole
# 5   Uzasadnienie\nZ Brochowa nie sposób wydostać s...  1000000        Krzyki
# 6   Uzasadnienie\nProponujemy stworzenie instalacj...  1000000     Psie Pole
# 7   Uzasadnienie\nW ramach Budżetu Obywatelskiego ...  1000000        Krzyki
# 8   Uzasadnienie\nInicjatywa jest odpowiedzią na p...  1000000   Śródmieście
# 9   Uzasadnienie\nDrodzy Wrocławianie, Drodzy Sąsi...  1000000  Stare Miasto
# 10  Uzasadnienie\nPrzejścia dla pieszych oraz miej...  1000000        Krzyki
# 11  Uzasadnienie\nProjekt zakłada powstanie strefy...  1000000        Krzyki
# 12  Uzasadnienie\nProjekt zakłada nasadzenia drzew...   100000        Krzyki
# 13  Uzasadnienie\nKoncepcję Parku na Maślicach zap...  1000000        Krzyki
# 14  Uzasadnienie\nOdtworzenie historycznej rzeźby ...  1000000   Śródmieście
# 15  Uzasadnienie\nAutobus kabriolet Jelcz MEX - Fr...   430000        Krzyki
# 16  Uzasadnienie\nNiezbędny jest remont ogromnej w...  1000000  Stare Miasto
# 17  Uzasadnienie\nBudowa: boiska do siatkówki plaż...  1000000     Fabryczna
# 18  Uzasadnienie\nProjekt ma za zadanie przywrócen...  1000000        Krzyki
# 19  Uzasadnienie\nRondo Reagana to jeden z ważniej...  1000000     Psie Pole
# 20  Uzasadnienie\nObecnie wskazany zieleniec pomim...   250000        Krzyki
# 21  Uzasadnienie\nCelem projektu jest stworzenie d...  1000000     Fabryczna
# 22  Uzasadnienie\nProponuję kilka modyfikacji (głó...   750000        Krzyki
# 23  Uzasadnienie\nRealizując projekt budowy boiska...  1000000        Krzyki
# 24  Uzasadnienie\nCelem projektu jest remont ul. R...   750000     Psie Pole
# 25  Uzasadnienie\nCelem projektu jest stworzenie d...  1000000  Stare Miasto
# 26  Uzasadnienie\nProjekt zakłada zmianę trybu pra...   650000     Psie Pole
# 27  Uzasadnienie\nWzdłuż ul. Opatowickiej biegnie ...   500000        Krzyki
# 28  Uzasadnienie\nProjekt przewiduje budowę ciągu ...   350000  Stare Miasto
# 29  Uzasadnienie\nCelem projektu jest stworzenie a...   100000     Psie Pole
# 30  Uzasadnienie\n"Park & ride" to parkingi dla  p...   750000     Fabryczna
# 31  Uzasadnienie\nW tym roku smog dał się we znaki...   250000  Stare Miasto
# 32  Uzasadnienie\nProjekt zakłada utworzenie zielo...   320000     Fabryczna
# 33  Uzasadnienie\nProjekt ma na celu poprawę bezpi...  1000000        Krzyki
# 34  Uzasadnienie\nUporządkowanie i zagospodarowani...   750000     Psie Pole
# 35  Uzasadnienie\nCelem projektu jest ocieplenie z...   250000        Krzyki
# 36  Uzasadnienie\nCelem projektu jest upiększenie ...   350000        Krzyki
# 37  Uzasadnienie\n1. Mało kto wie, że kiedyś, potę...   150000  Stare Miasto
# 38  Uzasadnienie\nPętla przystankowa przy ul. Dwor...   420000  Stare Miasto
# 39  Uzasadnienie\nNa ul. Dawida (między ul. Dawida...   250000   Śródmieście
# 40  Uzasadnienie\nPrzystanki wiedeńskie ułatwiają ...   500000   Śródmieście
# 41  Uzasadnienie\nNieodłączną częścią tkanki miejs...   200000     Fabryczna
# 42  Uzasadnienie\nMedaliony z herbem Wrocławia są ...   150000        Krzyki
# 43  Uzasadnienie\nWały nad Odrą, a w szczególności...    50000     Fabryczna
# 44  Uzasadnienie\nBudowa szachów dużego gabarytu w...   250000  Stare Miasto
# 45  Uzasadnienie\nProjekt zakłada lokowanie w prze...   150000   Śródmieście
# 46  Uzasadnienie\nProjekt przeznaczony jest zarówn...   600000        Krzyki
# 47  Uzasadnienie\nRynek i wszystkie miejsca, takie...   130000  Stare Miasto
# 48  Uzasadnienie\nIdeą projektu "1997" było upamię...    50000        Krzyki
# 49  Uzasadnienie\nPolegiwacz jest przenośnym meble...   150000   Śródmieście
#
#     district_number  real_votes  real_rank  year
# 0               4.0       10857          1  2017
# 1               5.0       10796          2  2017
# 2               5.0        8640          3  2017
# 3               3.0        5398          4  2017
# 4               3.0        4998          5  2017
# 5               2.0        4468          6  2017
# 6               3.0        4149          7  2017
# 7               2.0        4098          8  2017
# 8               4.0        4008          9  2017
# 9               5.0        3949         10  2017
# 10              2.0        3788         11  2017
# 11              2.0        3368         12  2017
# 12              2.0        3362         13  2017
# 13              2.0        2484         14  2017
# 14              4.0        2123         15  2017
# 15              2.0        2113         16  2017
# 16              5.0        2098         17  2017
# 17              1.0        2001         18  2017
# 18              2.0        1973         19  2017
# 19              3.0        1839         20  2017
# 20              2.0        1737         21  2017
# 21              1.0        1724         22  2017
# 22              2.0        1705         23  2017
# 23              2.0        1613         24  2017
# 24              3.0        1566         25  2017
# 25              5.0        1512         26  2017
# 26              3.0        1455         27  2017
# 27              2.0        1358         28  2017
# 28              5.0        1331         29  2017
# 29              3.0        1092         30  2017
# 30              1.0        1060         31  2017
# 31              5.0         990         32  2017
# 32              1.0         943         33  2017
# 33              2.0         922         34  2017
# 34              3.0         882         35  2017
# 35              2.0         765         36  2017
# 36              2.0         619         37  2017
# 37              5.0         587         38  2017
# 38              5.0         544         39  2017
# 39              4.0         480         40  2017
# 40              4.0         433         41  2017
# 41              1.0         418         42  2017
# 42              2.0         415         43  2017
# 43              1.0         266         44  2017
# 44              5.0         263         45  2017
# 45              4.0         236         46  2017
# 46              2.0         178         47  2017
# 47              5.0         156         48  2017
# 48              2.0         118         49  2017
# 49              4.0          83         50  2017

# %%
#2. build prompt
test['prompt'] = test.apply(
    lambda x: pb.build_prompt(
        'prompts/prompt_simple_pl.txt',
        {
            'project_name': x['project_name'],
            'cost': x['cost'],
            'district': x['district'],
            'description': x['description']
        }
    ),
    axis=1
)

# %%
print(test['prompt'].iloc[0])
# Out:
# You are an expert model in the analysis of participatory budgeting elections, specifically in the context of the city of Wroclaw, Poland.
# In Wroclaw, the municipality organizes participatory budgeting elections to fund citizen-led projects. Each resident can vote for between 1 and 3 initiatives on the official website.
#
# Once the voting period ends, the projects are ranked according to the number of votes received. Then, the winning projects are selected using a greedy algorithm: starting with the project that received the most votes, projects are added one by one in decreasing order of votes, as long as the available budget allows. If the next project in the list exceeds the remaining budget, it is skipped in favor of the next affordable one, and so on, until the total budget of €8,000,000 is exhausted.
# Your task is to analyze the following project, proposed as part of a new participatory budgeting election:
#
# Project: Toalety we Wrocławskich parkach i na terenach rekreacyjnych.
# Cost: 900000 €
# District: Śródmieście
# Description: Uzasadnienie
# W parkach i na terenach zielonych we Wrocławiu brakuje toalet, co utrudnia korzystanie z nich w celach rekreacyjnych przez dłuższy czas.
# Proponujemy instalację toalet (technologia dowolna, prawdopodobnie najlepsze byłyby samoczyszczące i/lub odporne na wandalizm).
# Proponujemy następujące miejsca:
# 1) Park Szczytnicki
# 2) Park Wschodni
# 3) Park Południowy
# 4) Park Tysiąclecia
# 5) Park Zachodni
# 6) Karłowice (Park Kasprowicza lub Polana Karłowicka lub Brodzik)
# Szczegóły umiejscowienia zostaną ustalone z liderem projektu. W przypadku gdyby któryś z ww parków posiadał już toaletę w momencie wygranej projektu, wspólnie z UMW wybierzemy inną lokalizację.
#
# Based on:
# - Your knowledge of Wroclaw, its urban context, and its social and environmental challenges
# - The characteristics of the project (theme, cost, district, etc.)
# - The typical voting dynamics in participatory budgeting elections
#
# Please answer the following questions regarding this project:
# 1. What is a reasonable estimate of the number of votes this project might receive?
# 2. What would be its expected position in the final ranking?
#
# Please answer in the form of a valid JSON dictionary with the following keys:
#
# ```json
# {
#   "estimated_votes": X,              // Estimated number of votes (integer)
#   "confidence_interval": [a, b],     // Realistic interval (min, max)
#   "expected_rank": Y                 // Estimated rank in the final list
# }
# Before giving an answer, take the time to reason thoroughly, but explain only the essential reasoning.
#
# **OUTPUT INSTRUCTIONS**
# 1. Briefly explain your reasoning in 5 to 8 key points, maximum.
# 2. At the end, provide only a valid JSON dictionary, with no additional text.

# %%
test['n_tokens'] = test['prompt'].apply(lambda p: tokens_counter(p))
test['cost_usd'] = test['n_tokens'].apply(lambda n_tokens: prompt_cost(n_tokens, 'gpt-4-turbo'))

print('mean tokens by prompt: {:.2f}'.format(test.n_tokens.mean()))
print('avg.cost of each prediction: ${:.2f}'.format(test.cost_usd.mean()))
print('experiment total cost: {:.2f}'.format(test.cost_usd.sum()))
# Out:
# mean tokens by prompt: 876.80
# avg.cost of each prediction: $0.01
# experiment total cost: 0.44

# %%
#3. run experiment! :)
api_key=os.getenv('OPENAI_API_KEY')
from llm_client import call_openai_model 

test['out'] = test['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))
# Out:
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!

# %%
import json
import re

def get_json_from_llm_response(out):
    # 1. Primer intento: el string completo es un JSON válido
    if isinstance(out, str):
        try:
            data = json.loads(out)
            if isinstance(data, dict):
                return data
        except json.JSONDecodeError:
            pass  # No es un JSON plano válido, continuamos

    # 2. Segundo intento: buscar bloque ```json {...} ```
    match = re.search(r"```json\s*({.*?})\s*```", out, re.DOTALL)
    if match:
        json_str = match.group(1)
        try:
            return json.loads(json_str)
        except json.JSONDecodeError:
            return None

    # 3. No se pudo encontrar JSON válido
    return None

def get_predicted_votes(df, out_json, city = 'Wroclaw'):
    
    if city != 'Wroclaw':
        raise ValueError(f"City '{city}' not supported")

    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
    
    votes_2016 = df[df['year'] == 2016].votes.sum()
    votes_2017 = df[df['year'] == 2017].votes.sum()

    relative_estimation = out_json['estimated_votes'] / votes_2016
    adjusted_prediction = relative_estimation * votes_2017

    return adjusted_prediction

def get_predicted_rank(out_json):
    
    if isinstance(out_json, str):
        try:
            out_json = json.loads(out_json)
        except json.JSONDecodeError:
            return None
        
    return out_json['expected_rank']

# %%
test['out_json'].iloc[0]
# Out:
# {'estimated_votes': 3500,
#  'confidence_interval': [3000, 4000],
#  'expected_rank': 5}

# %%
test['out_json'] = test['out'].apply(
    lambda o: get_json_from_llm_response(o))

# %%
test['predicted_votes'] = test['out_json'].apply(lambda x: get_predicted_votes(df, x))
test['predicted_rank'] = test['out_json'].apply(lambda x: get_predicted_rank(x))

# %%
# Out:
#     project_id                                       project_name  \
# 0           10  Toalety we Wrocławskich parkach i na terenach ...
# 1           50  Zielona rowerowo-piesza obwodnica Wrocławia; E...
# 2           18                              Rowerowy Wrocław 2017
# 3          675  Zieleń dla Wrocławia – parki kieszonkowe, nasa...
# 4          260                     Budki dla kotów wolno żyjących
# 5          550  Pieszo z Brochowa - uzupełnienie brakującego c...
# 6           12  Bulwar Fizyków - naukowy plac zabaw w przestrz...
# 7          159  Baza małych astronautów czyli kosmiczny plac z...
# 8          656     Toalety miejskie w parkach na miarę Wrocławia.
# 9          499  "Konikowo" - Budowa autorskiego placu zabaw na...
# 10         751                   Modernizacja ulicy DRZEWIECKIEGO
# 11         451                 Wrocławska Arena Sportu - strefa A
# 12         284  Zielona Obwodnica Wrocławia - drzewa i pnącza ...
# 13         345                                     Park Rędziński
# 14          41                Fontanna Neptuna na Placu Nowy Targ
# 15          16                Remont zabytkowego autobusu Fredruś
# 16         716  Park Grabiszyński - bezpieczne dojście! Remont...
# 17         590  Zagospodarowanie terenu kąpieliska na Oporowie...
# 18          43              Zielona Promenada przez Krzyki Etap I
# 19          46  Rondo Reagana na poziomie! Budowa peronów na R...
# 20         514  Pszczoły w mieście – hotele dla zapylaczy z pl...
# 21         553  Sieć parków we Wrocławiu - Psie Pole - Zawidaw...
# 22          68  Zielona trasa biegowo-pieszo-rowerowa z Ołtasz...
# 23         608                                 Sportowa Jantarowa
# 24         258                          Rewitalizacja ul. Ruskiej
# 25         555  Sieć parków we Wrocławiu – Psie Pole - Zawidaw...
# 26          83  Bezpieczne i przyjazne drogi we Wrocławiu - św...
# 27         680     Ścieżki pieszo-rowerowe przy ul. Opatowickiej.
# 28         372  Połączmy Psie Pole i Zakrzów – łącznik pieszo-...
# 29         688                          Miodowe łąki we Wrocławiu
# 30         668  "Park & ride" przy pętli Pilczyce/Stadion Wrocław
# 31         685                             Miejskie wyspy zieleni
# 32         694                Zielone przystanki w centrum miasta
# 33         371  Bezpieczniej na skrzyżowaniu al. Sobieskiego i...
# 34         508  Kępa Mieszczańska –park kieszonkowy z stacją s...
# 35         346          Odnowienie szpetnych wiaduktów kolejowych
# 36         358  Toskania we Wrocławiu: donice z kwiatami wokół...
# 37         594                Las sekwoi, drzewa i krzewy owocowe
# 38         332       Infrastruktura przystankowa na ul. Dworcowej
# 39         334          infrastruktura przystankowa na ul. Dawida
# 40          35  Wsiadanie na poziomie-budowa przystanków wiede...
# 41         620         Wrocławskie parki dostępne dla wszystkich.
# 42         203  Oczyszczenie z wojennego osmolenia i sadzy pia...
# 43         735  Rampa dla rowerów i wózków przy wyjściu z ulic...
# 44         464  Szachy plenerowe dużego gabarytu w centrum mia...
# 45         422          Akcja Plac - Gry uliczne "Oswajamy beton"
# 46         406  Budowa wrocławskiej wypożyczalni rowerów integ...
# 47         629  Wrocław na dotknięcie ręki – tylfograficzne ma...
# 48         720                                               1997
# 49         677  Polegiwacz - wędrujący mebel do odpoczynku i z...
#
#                                           description     cost      district  \
# 0   Uzasadnienie\nW parkach i na terenach zielonyc...   900000   Śródmieście
# 1   Uzasadnienie\nWalczymy o II ETAP. Ideą jest po...  1000000  Stare Miasto
# 2   Uzasadnienie\nProjekt przewiduje poprawę bezpi...  1000000  Stare Miasto
# 3   Uzasadnienie\nWe Wrocławiu nastąpiła deklaraty...  1000000     Psie Pole
# 4                                        Uzasadnienie    70000     Psie Pole
# 5   Uzasadnienie\nZ Brochowa nie sposób wydostać s...  1000000        Krzyki
# 6   Uzasadnienie\nProponujemy stworzenie instalacj...  1000000     Psie Pole
# 7   Uzasadnienie\nW ramach Budżetu Obywatelskiego ...  1000000        Krzyki
# 8   Uzasadnienie\nInicjatywa jest odpowiedzią na p...  1000000   Śródmieście
# 9   Uzasadnienie\nDrodzy Wrocławianie, Drodzy Sąsi...  1000000  Stare Miasto
# 10  Uzasadnienie\nPrzejścia dla pieszych oraz miej...  1000000        Krzyki
# 11  Uzasadnienie\nProjekt zakłada powstanie strefy...  1000000        Krzyki
# 12  Uzasadnienie\nProjekt zakłada nasadzenia drzew...   100000        Krzyki
# 13  Uzasadnienie\nKoncepcję Parku na Maślicach zap...  1000000        Krzyki
# 14  Uzasadnienie\nOdtworzenie historycznej rzeźby ...  1000000   Śródmieście
# 15  Uzasadnienie\nAutobus kabriolet Jelcz MEX - Fr...   430000        Krzyki
# 16  Uzasadnienie\nNiezbędny jest remont ogromnej w...  1000000  Stare Miasto
# 17  Uzasadnienie\nBudowa: boiska do siatkówki plaż...  1000000     Fabryczna
# 18  Uzasadnienie\nProjekt ma za zadanie przywrócen...  1000000        Krzyki
# 19  Uzasadnienie\nRondo Reagana to jeden z ważniej...  1000000     Psie Pole
# 20  Uzasadnienie\nObecnie wskazany zieleniec pomim...   250000        Krzyki
# 21  Uzasadnienie\nCelem projektu jest stworzenie d...  1000000     Fabryczna
# 22  Uzasadnienie\nProponuję kilka modyfikacji (głó...   750000        Krzyki
# 23  Uzasadnienie\nRealizując projekt budowy boiska...  1000000        Krzyki
# 24  Uzasadnienie\nCelem projektu jest remont ul. R...   750000     Psie Pole
# 25  Uzasadnienie\nCelem projektu jest stworzenie d...  1000000  Stare Miasto
# 26  Uzasadnienie\nProjekt zakłada zmianę trybu pra...   650000     Psie Pole
# 27  Uzasadnienie\nWzdłuż ul. Opatowickiej biegnie ...   500000        Krzyki
# 28  Uzasadnienie\nProjekt przewiduje budowę ciągu ...   350000  Stare Miasto
# 29  Uzasadnienie\nCelem projektu jest stworzenie a...   100000     Psie Pole
# 30  Uzasadnienie\n"Park & ride" to parkingi dla  p...   750000     Fabryczna
# 31  Uzasadnienie\nW tym roku smog dał się we znaki...   250000  Stare Miasto
# 32  Uzasadnienie\nProjekt zakłada utworzenie zielo...   320000     Fabryczna
# 33  Uzasadnienie\nProjekt ma na celu poprawę bezpi...  1000000        Krzyki
# 34  Uzasadnienie\nUporządkowanie i zagospodarowani...   750000     Psie Pole
# 35  Uzasadnienie\nCelem projektu jest ocieplenie z...   250000        Krzyki
# 36  Uzasadnienie\nCelem projektu jest upiększenie ...   350000        Krzyki
# 37  Uzasadnienie\n1. Mało kto wie, że kiedyś, potę...   150000  Stare Miasto
# 38  Uzasadnienie\nPętla przystankowa przy ul. Dwor...   420000  Stare Miasto
# 39  Uzasadnienie\nNa ul. Dawida (między ul. Dawida...   250000   Śródmieście
# 40  Uzasadnienie\nPrzystanki wiedeńskie ułatwiają ...   500000   Śródmieście
# 41  Uzasadnienie\nNieodłączną częścią tkanki miejs...   200000     Fabryczna
# 42  Uzasadnienie\nMedaliony z herbem Wrocławia są ...   150000        Krzyki
# 43  Uzasadnienie\nWały nad Odrą, a w szczególności...    50000     Fabryczna
# 44  Uzasadnienie\nBudowa szachów dużego gabarytu w...   250000  Stare Miasto
# 45  Uzasadnienie\nProjekt zakłada lokowanie w prze...   150000   Śródmieście
# 46  Uzasadnienie\nProjekt przeznaczony jest zarówn...   600000        Krzyki
# 47  Uzasadnienie\nRynek i wszystkie miejsca, takie...   130000  Stare Miasto
# 48  Uzasadnienie\nIdeą projektu "1997" było upamię...    50000        Krzyki
# 49  Uzasadnienie\nPolegiwacz jest przenośnym meble...   150000   Śródmieście
#
#     district_number  real_votes  real_rank  year  \
# 0               4.0       10857          1  2017
# 1               5.0       10796          2  2017
# 2               5.0        8640          3  2017
# 3               3.0        5398          4  2017
# 4               3.0        4998          5  2017
# 5               2.0        4468          6  2017
# 6               3.0        4149          7  2017
# 7               2.0        4098          8  2017
# 8               4.0        4008          9  2017
# 9               5.0        3949         10  2017
# 10              2.0        3788         11  2017
# 11              2.0        3368         12  2017
# 12              2.0        3362         13  2017
# 13              2.0        2484         14  2017
# 14              4.0        2123         15  2017
# 15              2.0        2113         16  2017
# 16              5.0        2098         17  2017
# 17              1.0        2001         18  2017
# 18              2.0        1973         19  2017
# 19              3.0        1839         20  2017
# 20              2.0        1737         21  2017
# 21              1.0        1724         22  2017
# 22              2.0        1705         23  2017
# 23              2.0        1613         24  2017
# 24              3.0        1566         25  2017
# 25              5.0        1512         26  2017
# 26              3.0        1455         27  2017
# 27              2.0        1358         28  2017
# 28              5.0        1331         29  2017
# 29              3.0        1092         30  2017
# 30              1.0        1060         31  2017
# 31              5.0         990         32  2017
# 32              1.0         943         33  2017
# 33              2.0         922         34  2017
# 34              3.0         882         35  2017
# 35              2.0         765         36  2017
# 36              2.0         619         37  2017
# 37              5.0         587         38  2017
# 38              5.0         544         39  2017
# 39              4.0         480         40  2017
# 40              4.0         433         41  2017
# 41              1.0         418         42  2017
# 42              2.0         415         43  2017
# 43              1.0         266         44  2017
# 44              5.0         263         45  2017
# 45              4.0         236         46  2017
# 46              2.0         178         47  2017
# 47              5.0         156         48  2017
# 48              2.0         118         49  2017
# 49              4.0          83         50  2017
#
#                                                prompt  n_tokens  cost_usd  \
# 0   You are an expert model in the analysis of par...       699   0.00699
# 1   You are an expert model in the analysis of par...       814   0.00814
# 2   You are an expert model in the analysis of par...       850   0.00850
# 3   You are an expert model in the analysis of par...       994   0.00994
# 4   You are an expert model in the analysis of par...       445   0.00445
# 5   You are an expert model in the analysis of par...       930   0.00930
# 6   You are an expert model in the analysis of par...       853   0.00853
# 7   You are an expert model in the analysis of par...       963   0.00963
# 8   You are an expert model in the analysis of par...      1043   0.01043
# 9   You are an expert model in the analysis of par...      1082   0.01082
# 10  You are an expert model in the analysis of par...       495   0.00495
# 11  You are an expert model in the analysis of par...      1064   0.01064
# 12  You are an expert model in the analysis of par...       932   0.00932
# 13  You are an expert model in the analysis of par...      1108   0.01108
# 14  You are an expert model in the analysis of par...       683   0.00683
# 15  You are an expert model in the analysis of par...       765   0.00765
# 16  You are an expert model in the analysis of par...       655   0.00655
# 17  You are an expert model in the analysis of par...       709   0.00709
# 18  You are an expert model in the analysis of par...       898   0.00898
# 19  You are an expert model in the analysis of par...       732   0.00732
# 20  You are an expert model in the analysis of par...       805   0.00805
# 21  You are an expert model in the analysis of par...      1105   0.01105
# 22  You are an expert model in the analysis of par...       915   0.00915
# 23  You are an expert model in the analysis of par...       991   0.00991
# 24  You are an expert model in the analysis of par...       808   0.00808
# 25  You are an expert model in the analysis of par...      1098   0.01098
# 26  You are an expert model in the analysis of par...      1118   0.01118
# 27  You are an expert model in the analysis of par...       764   0.00764
# 28  You are an expert model in the analysis of par...      1133   0.01133
# 29  You are an expert model in the analysis of par...       913   0.00913
# 30  You are an expert model in the analysis of par...       929   0.00929
# 31  You are an expert model in the analysis of par...      1054   0.01054
# 32  You are an expert model in the analysis of par...       841   0.00841
# 33  You are an expert model in the analysis of par...      1112   0.01112
# 34  You are an expert model in the analysis of par...       732   0.00732
# 35  You are an expert model in the analysis of par...       573   0.00573
# 36  You are an expert model in the analysis of par...       660   0.00660
# 37  You are an expert model in the analysis of par...      1084   0.01084
# 38  You are an expert model in the analysis of par...       883   0.00883
# 39  You are an expert model in the analysis of par...       862   0.00862
# 40  You are an expert model in the analysis of par...       681   0.00681
# 41  You are an expert model in the analysis of par...      1128   0.01128
# 42  You are an expert model in the analysis of par...       862   0.00862
# 43  You are an expert model in the analysis of par...       820   0.00820
# 44  You are an expert model in the analysis of par...       499   0.00499
# 45  You are an expert model in the analysis of par...       870   0.00870
# 46  You are an expert model in the analysis of par...      1105   0.01105
# 47  You are an expert model in the analysis of par...      1073   0.01073
# 48  You are an expert model in the analysis of par...       818   0.00818
# 49  You are an expert model in the analysis of par...       890   0.00890
#
#                                                   out  \
# 0   1. **Relevance and Demand**: The project addre...
# 1   1. **Project Appeal and Relevance**: The proje...
# 2   1. **Project Relevance**: The project "Rowerow...
# 3   1. **Relevance of the Project**: The project "...
# 4   1. **Project Theme and Appeal**: The project "...
# 5   1. **Project Relevance**: The project addresse...
# 6   1. **Project Appeal and Relevance**: The proje...
# 7   1. **Project Appeal**: The project, aimed at c...
# 8   1. **Relevance and Demand**: The project addre...
# 9   1. The project is located in a popular and acc...
# 10  1. **District Analysis**: Krzyki is one of the...
# 11  1. **District and Demographics**: Krzyki is on...
# 12  1. **Relevance and Impact**: The project addre...
# 13  1. **District and Demographics**: Krzyki is on...
# 14  1. **Historical Context and Appeal**: The proj...
# 15  1. **Historical Interest and Cultural Signific...
# 16  1. **Project Relevance**: The project focuses ...
# 17  1. **District and Population**: Fabryczna is o...
# 18  1. **Project Appeal and Relevance**: The proje...
# 19  1. **Previous Voting Patterns**: The project i...
# 20  1. **Project Theme and Appeal**: The project "...
# 21  1. **Project Appeal and Relevance**: The proje...
# 22  1. **Project Appeal and Relevance**: The proje...
# 23  1. **District and Demographics**: Krzyki is on...
# 24  1. **Project Appeal and Relevance**: The proje...
# 25  1. **Project Appeal**: The project aims to cre...
# 26  1. **Project Relevance**: The project addresse...
# 27  1. **Project Relevance**: The project addresse...
# 28  1. **Project Relevance**: The project addresse...
# 29  1. **Project Appeal and Relevance**: The proje...
# 30  1. **Relevance and Impact**: The project addre...
# 31  1. **Relevance and Urgency**: The project addr...
# 32  1. **Project Appeal and Relevance**: The proje...
# 33  1. **Project Relevance**: The project addresse...
# 34  1. **Project Appeal and Relevance**: The proje...
# 35  1. **Project Appeal**: The project aims to bea...
# 36  1. **Project Appeal**: The project "Toskania w...
# 37  1. **Project Appeal and Relevance**: The proje...
# 38  1. **Project Relevance**: The project addresse...
# 39  1. **Project Relevance**: The project addresse...
# 40  1. **Project Relevance**: The project addresse...
# 41  1. **Relevance and Impact**: The project "Wroc...
# 42  1. **Cultural and Historical Significance**: T...
# 43  1. **Project Relevance**: The project addresse...
# 44  1. **Project Appeal and Location**: The projec...
# 45  1. **Project Appeal**: The project "Akcja Plac...
# 46  1. **Project Relevance**: The project targets ...
# 47  1. **Relevance and Impact**: The project addre...
# 48  1. **Historical Context and Emotional Appeal**...
# 49  1. **Project Appeal**: The project "Polegiwacz...
#
#                                              out_json  predicted_votes  \
# 0   {'estimated_votes': 3500, 'confidence_interval...      3287.610954
# 1   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 2   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 3   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 4   {'estimated_votes': 1500, 'confidence_interval...      1408.976123
# 5   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 6   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 7   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 8   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 9   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 10  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 11  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 12  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 13  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 14  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 15  {'estimated_votes': 3500, 'confidence_interval...      3287.610954
# 16  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 17  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 18  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 19  {'estimated_votes': 1300, 'confidence_interval...      1221.112640
# 20  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 21  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 22  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 23  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 24  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 25  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 26  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 27  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 28  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 29  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 30  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 31  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 32  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 33  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 34  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 35  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 36  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 37  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 38  {'estimated_votes': 3500, 'confidence_interval...      3287.610954
# 39  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 40  {'estimated_votes': 3500, 'confidence_interval...      3287.610954
# 41  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 42  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 43  {'estimated_votes': 1200, 'confidence_interval...      1127.180898
# 44  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 45  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 46  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 47  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 48  {'estimated_votes': 1200, 'confidence_interval...      1127.180898
# 49  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
#
#     predicted_rank
# 0                5
# 1               15
# 2                5
# 3                5
# 4               25
# 5                5
# 6                5
# 7               10
# 8                5
# 9                5
# 10              15
# 11               5
# 12              15
# 13               5
# 14              15
# 15              15
# 16               5
# 17              10
# 18               5
# 19               5
# 20              15
# 21               5
# 22              15
# 23              10
# 24              10
# 25               5
# 26              15
# 27              15
# 28              15
# 29              15
# 30              10
# 31              10
# 32              10
# 33              15
# 34              15
# 35              15
# 36              15
# 37              15
# 38              15
# 39              15
# 40               5
# 41              15
# 42              15
# 43              15
# 44              15
# 45              15
# 46              15
# 47              15
# 48              15
# 49               5

# %%
results = test.filter(['project_id', 
             'real_votes', 
             'real_rank',
             'prompt',
             'out',
             'out_json', 
             'predicted_votes', 
             'predicted_rank']
             )
results
# Out:
#     project_id  real_votes  real_rank  \
# 0           10       10857          1
# 1           50       10796          2
# 2           18        8640          3
# 3          675        5398          4
# 4          260        4998          5
# 5          550        4468          6
# 6           12        4149          7
# 7          159        4098          8
# 8          656        4008          9
# 9          499        3949         10
# 10         751        3788         11
# 11         451        3368         12
# 12         284        3362         13
# 13         345        2484         14
# 14          41        2123         15
# 15          16        2113         16
# 16         716        2098         17
# 17         590        2001         18
# 18          43        1973         19
# 19          46        1839         20
# 20         514        1737         21
# 21         553        1724         22
# 22          68        1705         23
# 23         608        1613         24
# 24         258        1566         25
# 25         555        1512         26
# 26          83        1455         27
# 27         680        1358         28
# 28         372        1331         29
# 29         688        1092         30
# 30         668        1060         31
# 31         685         990         32
# 32         694         943         33
# 33         371         922         34
# 34         508         882         35
# 35         346         765         36
# 36         358         619         37
# 37         594         587         38
# 38         332         544         39
# 39         334         480         40
# 40          35         433         41
# 41         620         418         42
# 42         203         415         43
# 43         735         266         44
# 44         464         263         45
# 45         422         236         46
# 46         406         178         47
# 47         629         156         48
# 48         720         118         49
# 49         677          83         50
#
#                                                prompt  \
# 0   You are an expert model in the analysis of par...
# 1   You are an expert model in the analysis of par...
# 2   You are an expert model in the analysis of par...
# 3   You are an expert model in the analysis of par...
# 4   You are an expert model in the analysis of par...
# 5   You are an expert model in the analysis of par...
# 6   You are an expert model in the analysis of par...
# 7   You are an expert model in the analysis of par...
# 8   You are an expert model in the analysis of par...
# 9   You are an expert model in the analysis of par...
# 10  You are an expert model in the analysis of par...
# 11  You are an expert model in the analysis of par...
# 12  You are an expert model in the analysis of par...
# 13  You are an expert model in the analysis of par...
# 14  You are an expert model in the analysis of par...
# 15  You are an expert model in the analysis of par...
# 16  You are an expert model in the analysis of par...
# 17  You are an expert model in the analysis of par...
# 18  You are an expert model in the analysis of par...
# 19  You are an expert model in the analysis of par...
# 20  You are an expert model in the analysis of par...
# 21  You are an expert model in the analysis of par...
# 22  You are an expert model in the analysis of par...
# 23  You are an expert model in the analysis of par...
# 24  You are an expert model in the analysis of par...
# 25  You are an expert model in the analysis of par...
# 26  You are an expert model in the analysis of par...
# 27  You are an expert model in the analysis of par...
# 28  You are an expert model in the analysis of par...
# 29  You are an expert model in the analysis of par...
# 30  You are an expert model in the analysis of par...
# 31  You are an expert model in the analysis of par...
# 32  You are an expert model in the analysis of par...
# 33  You are an expert model in the analysis of par...
# 34  You are an expert model in the analysis of par...
# 35  You are an expert model in the analysis of par...
# 36  You are an expert model in the analysis of par...
# 37  You are an expert model in the analysis of par...
# 38  You are an expert model in the analysis of par...
# 39  You are an expert model in the analysis of par...
# 40  You are an expert model in the analysis of par...
# 41  You are an expert model in the analysis of par...
# 42  You are an expert model in the analysis of par...
# 43  You are an expert model in the analysis of par...
# 44  You are an expert model in the analysis of par...
# 45  You are an expert model in the analysis of par...
# 46  You are an expert model in the analysis of par...
# 47  You are an expert model in the analysis of par...
# 48  You are an expert model in the analysis of par...
# 49  You are an expert model in the analysis of par...
#
#                                                   out  \
# 0   1. **Relevance and Demand**: The project addre...
# 1   1. **Project Appeal and Relevance**: The proje...
# 2   1. **Project Relevance**: The project "Rowerow...
# 3   1. **Relevance of the Project**: The project "...
# 4   1. **Project Theme and Appeal**: The project "...
# 5   1. **Project Relevance**: The project addresse...
# 6   1. **Project Appeal and Relevance**: The proje...
# 7   1. **Project Appeal**: The project, aimed at c...
# 8   1. **Relevance and Demand**: The project addre...
# 9   1. The project is located in a popular and acc...
# 10  1. **District Analysis**: Krzyki is one of the...
# 11  1. **District and Demographics**: Krzyki is on...
# 12  1. **Relevance and Impact**: The project addre...
# 13  1. **District and Demographics**: Krzyki is on...
# 14  1. **Historical Context and Appeal**: The proj...
# 15  1. **Historical Interest and Cultural Signific...
# 16  1. **Project Relevance**: The project focuses ...
# 17  1. **District and Population**: Fabryczna is o...
# 18  1. **Project Appeal and Relevance**: The proje...
# 19  1. **Previous Voting Patterns**: The project i...
# 20  1. **Project Theme and Appeal**: The project "...
# 21  1. **Project Appeal and Relevance**: The proje...
# 22  1. **Project Appeal and Relevance**: The proje...
# 23  1. **District and Demographics**: Krzyki is on...
# 24  1. **Project Appeal and Relevance**: The proje...
# 25  1. **Project Appeal**: The project aims to cre...
# 26  1. **Project Relevance**: The project addresse...
# 27  1. **Project Relevance**: The project addresse...
# 28  1. **Project Relevance**: The project addresse...
# 29  1. **Project Appeal and Relevance**: The proje...
# 30  1. **Relevance and Impact**: The project addre...
# 31  1. **Relevance and Urgency**: The project addr...
# 32  1. **Project Appeal and Relevance**: The proje...
# 33  1. **Project Relevance**: The project addresse...
# 34  1. **Project Appeal and Relevance**: The proje...
# 35  1. **Project Appeal**: The project aims to bea...
# 36  1. **Project Appeal**: The project "Toskania w...
# 37  1. **Project Appeal and Relevance**: The proje...
# 38  1. **Project Relevance**: The project addresse...
# 39  1. **Project Relevance**: The project addresse...
# 40  1. **Project Relevance**: The project addresse...
# 41  1. **Relevance and Impact**: The project "Wroc...
# 42  1. **Cultural and Historical Significance**: T...
# 43  1. **Project Relevance**: The project addresse...
# 44  1. **Project Appeal and Location**: The projec...
# 45  1. **Project Appeal**: The project "Akcja Plac...
# 46  1. **Project Relevance**: The project targets ...
# 47  1. **Relevance and Impact**: The project addre...
# 48  1. **Historical Context and Emotional Appeal**...
# 49  1. **Project Appeal**: The project "Polegiwacz...
#
#                                              out_json  predicted_votes  \
# 0   {'estimated_votes': 3500, 'confidence_interval...      3287.610954
# 1   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 2   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 3   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 4   {'estimated_votes': 1500, 'confidence_interval...      1408.976123
# 5   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 6   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 7   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 8   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 9   {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 10  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 11  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 12  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 13  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 14  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 15  {'estimated_votes': 3500, 'confidence_interval...      3287.610954
# 16  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 17  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 18  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 19  {'estimated_votes': 1300, 'confidence_interval...      1221.112640
# 20  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 21  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 22  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 23  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 24  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 25  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 26  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 27  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 28  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 29  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 30  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 31  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 32  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 33  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 34  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 35  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 36  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 37  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 38  {'estimated_votes': 3500, 'confidence_interval...      3287.610954
# 39  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 40  {'estimated_votes': 3500, 'confidence_interval...      3287.610954
# 41  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 42  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 43  {'estimated_votes': 1200, 'confidence_interval...      1127.180898
# 44  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 45  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
# 46  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 47  {'estimated_votes': 4500, 'confidence_interval...      4226.928369
# 48  {'estimated_votes': 1200, 'confidence_interval...      1127.180898
# 49  {'estimated_votes': 3200, 'confidence_interval...      3005.815729
#
#     predicted_rank
# 0                5
# 1               15
# 2                5
# 3                5
# 4               25
# 5                5
# 6                5
# 7               10
# 8                5
# 9                5
# 10              15
# 11               5
# 12              15
# 13               5
# 14              15
# 15              15
# 16               5
# 17              10
# 18               5
# 19               5
# 20              15
# 21               5
# 22              15
# 23              10
# 24              10
# 25               5
# 26              15
# 27              15
# 28              15
# 29              15
# 30              10
# 31              10
# 32              10
# 33              15
# 34              15
# 35              15
# 36              15
# 37              15
# 38              15
# 39              15
# 40               5
# 41              15
# 42              15
# 43              15
# 44              15
# 45              15
# 46              15
# 47              15
# 48              15
# 49               5

# %%
results.to_csv('output/predictions/wrc_simple_prompt_full_1.csv', sep=";", index=False)
print('results ready!')
# Out:
# results ready!
