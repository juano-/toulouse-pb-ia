# %% [markdown]
# ### Data Validation
#
# Methodology:
# I choose 10  random projects from 2024 election in Toulouse. For each one:
#
# 1. Project Name
# 2. Description
# 3. Cost
# 4. District
# 5. Votes
#
# Ask (Guided / Non-guided)
#
# #### Without searching in exteranal sources
#
# 1.  Complete the description.
# 2.  In which Neighborhood was proposed and in which category..
#
# - ROUGE-L (Lexic Similarity)
# - BLEURT (Semantic similarity)
#
#
# -> Methodology proposed here: https://arxiv.org/abs/2308.08493#

# %% [markdown]
# #### Toulouse 2024 Dataset

# %%
# 1. load data
from src.data_loader import load_and_prepare_projects, load_prediction_set

path_22 = 'data/tls22_projects.csv'
path_24 = 'data/tls24_projects.csv'

df, df22_shuffled = load_and_prepare_projects(path_22,path_24)

ids_to_predict_path = 'data/tls24_projects_to_predict.csv'
test = load_prediction_set(df, ids_to_predict_path)
df
# Out:
#      project_id                                       project_name  \
# 0           136                Piste cyclable avenue Saint-Exupéry
# 1             7  Faire des voies vélos et piétons dédiées et bi...
# 2             5             Végétalisation de la place du Capitole
# 3           132                              Lutte anti-moustiques
# 4            71  Planter des arbres et jardins partagés partout...
# ..          ...                                                ...
# 378         372  Installation d'un portique pour réparer les vé...
# 379         356  Débitumiser les places de stationnement rue Be...
# 380         230  Installation de poubelles à déjection aux Sept...
# 381         370  Installer des tables et des chaises au Parc Ma...
# 382         374  Améliorer la propreté de l'aire de jeux Jean G...
#
#                                            description  \
# 0    Lorsque l'on habite vers la place de l'ormeau,...
# 1    Pour favoriser la cohabitation piétons/cyclist...
# 2    Pour donner encore plus de majesté à ce lieu e...
# 3    Mise en place de pièges à moustiques dans le q...
# 4    Une voisine exploite un bout du terrain du sup...
# ..                                                 ...
# 378  Fleury : Place André Abbal (Reynerie): Il sera...
# 379  Je propose d’enlever le bitume sur les places ...
# 380  Installer sur le quartier des sept deniers, de...
# 381  Il n’y a pas assez de tables et de chaises pou...
# 382  Nécessité de rénover l'aire de jeux de Jean Gi...
#
#                             category      cost  \
# 0                       Éco-mobilité  200000.0
# 1                       Éco-mobilité  150000.0
# 2                    Nature en ville  200000.0
# 3                    Nature en ville    7500.0
# 4                    Nature en ville   20000.0
# ..                               ...       ...
# 378       Éco-mobilité et transports    5000.0
# 379  Nature en ville et biodiversité  240000.0
# 380                     Cadre de vie    6000.0
# 381                     Cadre de vie   85000.0
# 382                     Cadre de vie    3000.0
#
#                                               district  votes district_number  \
# 0    12 - Pont des Demoiselles / Ormeau / Montaudra...    492              12
# 1               1 - Capitole / Arnaud Bernard / Carmes    467               1
# 2               1 - Capitole / Arnaud Bernard / Carmes    358               1
# 3    12 - Pont des Demoiselles / Ormeau / Montaudra...    258              12
# 4    8 - Minimes / Barrière de Paris / Ponts-Jumeau...    243               8
# ..                                                 ...    ...             ...
# 378  17 - Mirail-Université / Reynerie / Bellefontaine     20              17
# 379             15 - Croix de Pierre / Route d'Espagne     19              15
# 380  7 - Sept Deniers / Ginestous-Sesquières / Lalande     19               7
# 381  17 - Mirail-Université / Reynerie / Bellefontaine     18              17
# 382  17 - Mirail-Université / Reynerie / Bellefontaine     17              17
#
#      rank  year
# 0       1  2022
# 1       2  2022
# 2       3  2022
# 3       4  2022
# 4       5  2022
# ..    ...   ...
# 378   179  2024
# 379   180  2024
# 380   181  2024
# 381   182  2024
# 382   183  2024
#
# [383 rows x 10 columns]

# %%
sample24 = df[df['year'] == 2024].sample(n=10, random_state=42).filter(['project_id', 
                                                                        'project_name', 
                                                                        'description', 
                                                                        'cost', 
                                                                        'district',
                                                                        'votes'])

sample24

# %%
### This option: validates if model memorized the dataset 
def build_guided_validation_prompt_1(project_name):
    prompt =f"""This project is part of the 2024 participatory budget of the city of Toulouse.\n
    Its name is: {project_name}.\n
    Please provide the exact original description as it was proposed during the election
    """
    return prompt

### This option: validates if LLM can reconstruct original description, using its training dataset.
def build_guided_validation_prompt_2(project_name, description):
    prompt =f"""This project is part of the 2024 participatory budget of the city of Toulouse.\n
    Its name is: {project_name}.
    Complete the description of the project exactly as it was proposed during.\n
    Description: {description[0:30]} ...
    """
    return prompt
### Algunos modelos pueden recordar solo los nombres + barrios + costos desde CSV, Bases de datos, pdfs etc.
def build_validation_prompt_cost_district(project_name):
    prompt = f"""This project is part of the 2024 participatory budget of the city of Toulouse.\n
    Its name is: {project_name}.
    Can you tell me:
    1. In which district of the city this project was proposed?
    2. What was the cost proposed for this project?
    """
    return prompt

# %%
# prompt 1
sample24['prompt'] = sample24.apply(lambda x: build_guided_validation_prompt_1(x['project_name']), axis=1)
print(sample24['prompt'].iloc[0])

# %%
import os 
from llm_client import call_openai_model


api_key=os.getenv('OPENAI_API_KEY')
 
sample24['out'] = sample24['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))

# %%
sample24.filter(['project_id','prompt','out']).to_csv("output/validation/guided_validation_description.csv", sep=";", index=False)

# %%
# prompt 2
sample24['prompt'] = sample24.apply(lambda x: build_guided_validation_prompt_2(x['project_name'], x['description']), axis=1)
print(sample24['prompt'].iloc[0])

# %%
import os 
from llm_client import call_openai_model


api_key=os.getenv('OPENAI_API_KEY')
 
sample24['out'] = sample24['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))

# %%
sample24.filter(['project_id','prompt','out']).to_csv("output/validation/tls24_guided_validation_description_2.csv", sep=";", index=False)

# %%
# prompt 3
sample24['prompt'] = sample24.apply(lambda x: build_validation_prompt_cost_district(x['project_name']), axis=1)
print(sample24['prompt'].iloc[0])

# %%
import os 
from llm_client import call_openai_model


api_key=os.getenv('OPENAI_API_KEY')
 
sample24['out'] = sample24['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))

# %%
sample24.filter(['project_id','prompt','out']).to_csv("output/validation/tls24_guided_validation_district_cost.csv", sep=";", index=False)

# %% [markdown]
# #### Warzclaw 2017 Dataset

# %%
# 1. load data
from src.data_loader import load_and_prepare_projects, load_prediction_set

path_16 = 'data/wrc16_projects.csv'
path_17 = 'data/wrc17_projects.csv'

df, df16_shuffled = load_and_prepare_projects(path_16,path_17, city='Wroclaw')

df
ids_to_predict_path = 'data/wrc17_projects_to_predict.csv'
test = load_prediction_set(df, ids_to_predict_path, city='Wroclaw')
df
# Out:
#      project_id                                       project_name  \
# 0           710  Drzewa dla Wrocławia - nasadzenia w całym mieś...
# 1            15  Zielona rowerowo-piesza obwodnica Wrocławia; E...
# 2           764  Oświetlenie Parku Grabiszyńskiego (Alei Romera...
# 3           685  Plac Zabaw dla Starszaków w parku Grabiszyński...
# 4           379  Parking przy "Dobrzyńskiej" - ułatwienie dojaz...
# ..          ...                                                ...
# 97          422          Akcja Plac - Gry uliczne "Oswajamy beton"
# 98          406  Budowa wrocławskiej wypożyczalni rowerów integ...
# 99          629  Wrocław na dotknięcie ręki – tylfograficzne ma...
# 100         720                                               1997
# 101         677  Polegiwacz - wędrujący mebel do odpoczynku i z...
#
#                                            description  \
# 0    Uzasadnienie\nZnikające drzewa z krajobrazu mi...
# 1                                         Uzasadnienie
# 2    Uzasadnienie\nTaki mamy klimat... że przez pół...
# 3    Uzasadnienie\nPlac Zabaw dla Starszaków w park...
# 4    Uzasadnienie\nProjekt polega na utworzeniu w c...
# ..                                                 ...
# 97   Uzasadnienie\nProjekt zakłada lokowanie w prze...
# 98   Uzasadnienie\nProjekt przeznaczony jest zarówn...
# 99   Uzasadnienie\nRynek i wszystkie miejsca, takie...
# 100  Uzasadnienie\nIdeą projektu "1997" było upamię...
# 101  Uzasadnienie\nPolegiwacz jest przenośnym meble...
#
#                            category     cost  \
# 0               greenery/recreation  1000000
# 1    walking/cycling infrastructure  1000000
# 2                             other  1000000
# 3                       playgrounds   560000
# 4                             roads   750000
# ..                              ...      ...
# 97              greenery/recreation   150000
# 98   walking/cycling infrastructure   600000
# 99                            other   130000
# 100                           other    50000
# 101             greenery/recreation   150000
#
#                                               district  votes  rank  year
# 0    Kuźniki, Nowy Dwór, Muchobór Mały,Grabiszyn-Gr...  13938     1  2016
# 1    Grabiszyn-Grabiszynek, Krzyki-Partynice, Oporó...  12348     2  2016
# 2    Grabiszyn-Grabiszynek, Krzyki-Partynice, Oporó...   7291     3  2016
# 3    Huby, Gaj, Tarnogaj,Nadodrze, Ołbin, Stare Mia...   6663     4  2016
# 4                 Gajowice, Powstańców Śląskich, Borek   6383     5  2016
# ..                                                 ...    ...   ...   ...
# 97                                               Ołbin    236    46  2017
# 98                                            Tarnogaj    178    47  2017
# 99   Stare Miasto, Przedmieście Świdnickie,Przedmie...    156    48  2017
# 100                                           Ołtaszyn    118    49  2017
# 101                                       Ołbin,Oporów     83    50  2017
#
# [102 rows x 9 columns]

# %%
df
# Out:
#      project_id                                       project_name  \
# 0           710  Drzewa dla Wrocławia - nasadzenia w całym mieś...
# 1            15  Zielona rowerowo-piesza obwodnica Wrocławia; E...
# 2           764  Oświetlenie Parku Grabiszyńskiego (Alei Romera...
# 3           685  Plac Zabaw dla Starszaków w parku Grabiszyński...
# 4           379  Parking przy "Dobrzyńskiej" - ułatwienie dojaz...
# ..          ...                                                ...
# 97          422          Akcja Plac - Gry uliczne "Oswajamy beton"
# 98          406  Budowa wrocławskiej wypożyczalni rowerów integ...
# 99          629  Wrocław na dotknięcie ręki – tylfograficzne ma...
# 100         720                                               1997
# 101         677  Polegiwacz - wędrujący mebel do odpoczynku i z...
#
#                                            description  \
# 0    Uzasadnienie\nZnikające drzewa z krajobrazu mi...
# 1                                         Uzasadnienie
# 2    Uzasadnienie\nTaki mamy klimat... że przez pół...
# 3    Uzasadnienie\nPlac Zabaw dla Starszaków w park...
# 4    Uzasadnienie\nProjekt polega na utworzeniu w c...
# ..                                                 ...
# 97   Uzasadnienie\nProjekt zakłada lokowanie w prze...
# 98   Uzasadnienie\nProjekt przeznaczony jest zarówn...
# 99   Uzasadnienie\nRynek i wszystkie miejsca, takie...
# 100  Uzasadnienie\nIdeą projektu "1997" było upamię...
# 101  Uzasadnienie\nPolegiwacz jest przenośnym meble...
#
#                            category     cost  \
# 0               greenery/recreation  1000000
# 1    walking/cycling infrastructure  1000000
# 2                             other  1000000
# 3                       playgrounds   560000
# 4                             roads   750000
# ..                              ...      ...
# 97              greenery/recreation   150000
# 98   walking/cycling infrastructure   600000
# 99                            other   130000
# 100                           other    50000
# 101             greenery/recreation   150000
#
#                                               district  votes  rank  year
# 0    Kuźniki, Nowy Dwór, Muchobór Mały,Grabiszyn-Gr...  13938     1  2016
# 1    Grabiszyn-Grabiszynek, Krzyki-Partynice, Oporó...  12348     2  2016
# 2    Grabiszyn-Grabiszynek, Krzyki-Partynice, Oporó...   7291     3  2016
# 3    Huby, Gaj, Tarnogaj,Nadodrze, Ołbin, Stare Mia...   6663     4  2016
# 4                 Gajowice, Powstańców Śląskich, Borek   6383     5  2016
# ..                                                 ...    ...   ...   ...
# 97                                               Ołbin    236    46  2017
# 98                                            Tarnogaj    178    47  2017
# 99   Stare Miasto, Przedmieście Świdnickie,Przedmie...    156    48  2017
# 100                                           Ołtaszyn    118    49  2017
# 101                                       Ołbin,Oporów     83    50  2017
#
# [102 rows x 9 columns]

# %%
sample17 = df[df['year'] == 2017].sample(n=10, random_state=42).filter(['project_id', 
                                                                        'project_name', 
                                                                        'description', 
                                                                        'cost', 
                                                                        'district',
                                                                        'votes'])

sample17
# Out:
#      project_id                                       project_name  \
# 65          345                                     Park Rędziński
# 91          334          infrastruktura przystankowa na ul. Dawida
# 82          668  "Park & ride" przy pętli Pilczyce/Stadion Wrocław
# 97          422          Akcja Plac - Gry uliczne "Oswajamy beton"
# 69          590  Zagospodarowanie terenu kąpieliska na Oporowie...
# 100         720                                               1997
# 78           83  Bezpieczne i przyjazne drogi we Wrocławiu - św...
# 77          555  Sieć parków we Wrocławiu – Psie Pole - Zawidaw...
# 84          694                Zielone przystanki w centrum miasta
# 71           46  Rondo Reagana na poziomie! Budowa peronów na R...
#
#                                            description     cost  \
# 65   Uzasadnienie\nKoncepcję Parku na Maślicach zap...  1000000
# 91   Uzasadnienie\nNa ul. Dawida (między ul. Dawida...   250000
# 82   Uzasadnienie\n"Park & ride" to parkingi dla  p...   750000
# 97   Uzasadnienie\nProjekt zakłada lokowanie w prze...   150000
# 69   Uzasadnienie\nBudowa: boiska do siatkówki plaż...  1000000
# 100  Uzasadnienie\nIdeą projektu "1997" było upamię...    50000
# 78   Uzasadnienie\nProjekt zakłada zmianę trybu pra...   650000
# 77   Uzasadnienie\nCelem projektu jest stworzenie d...  1000000
# 84   Uzasadnienie\nProjekt zakłada utworzenie zielo...   320000
# 71   Uzasadnienie\nRondo Reagana to jeden z ważniej...  1000000
#
#                                     district  votes
# 65                                   Brochów   2484
# 91                                     Ołbin    480
# 82                                   Leśnica   1060
# 97                                     Ołbin    236
# 69                           Leśnica,Maślice   2001
# 100                                 Ołtaszyn    118
# 78                    Karłowice-Różanka,Huby   1455
# 77                     Przedmieście Oławskie   1512
# 84   Pilczyce-Kozanów-Popowice Płn.,Szczepin    943
# 71                         Karłowice-Różanka   1839

# %%
### This option: validates if model memorized the dataset 
def build_guided_validation_prompt_1(project_name, lang = 'eng'):
    if lang == 'eng':
        prompt =f"""This project is part of the 2017 participatory budget election on the city of Wroclaw in Poland.\n
        Its name is: {project_name}.\n
        Please provide the exact original justification of the project as it was proposed during the election
        """
        return prompt
    
    else:
        prompt =f"""Ten projekt jest częścią budżetu obywatelskiego z 2017 roku w mieście Wrocław w Polsce..\n
        Jego nazwa to: {project_name}.\n
        Proszę podać dokładne oryginalne uzasadnienie projektu, takie jak zostało przedstawione podczas głosowania.
        """
        return prompt

### This option: validates if LLM can reconstruct original description, using its training dataset.
def build_guided_validation_prompt_2(project_name, description):
    prompt =f"""This project is part of the 2017 participatory budget election on the city of Wroclaw in Poland.\n
    Its name is: {project_name}.
    Complete the justification of the project exactly as it was proposed during the election.\n
    Description: {description[0:50]} ...
    """
    return prompt

### Algunos modelos pueden recordar solo los nombres + barrios + costos desde CSV, Bases de datos, pdfs etc.
def build_validation_prompt_cost_district(project_name):
    prompt = f"""This project is part of the 2017 participatory budget election on the city of Wroclaw in Poland.\n
    Its name is: {project_name}.
    Can you tell me:
    1. In which district of the city this project was proposed?
    2. What was the cost proposed for this project?
    """
    return prompt

# %%
# prompt 1
sample17['prompt'] = sample17.apply(lambda x: build_guided_validation_prompt_1(x['project_name'], lang='pl'), axis=1)
print(sample17['prompt'].iloc[0])

# %%
import os 
from llm_client import call_openai_model


api_key=os.getenv('OPENAI_API_KEY')
 
sample17['out'] = sample17['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))

# %%
sample17.filter(['project_id','prompt','out']).to_csv("output/validation/wrc_guided_validation_description_pl.csv", sep=";", index=False)

# %%
# prompt 2
sample17['prompt'] = sample17.apply(lambda x: build_guided_validation_prompt_2(x['project_name'], x['description']), axis=1)
print(sample17['prompt'].iloc[0])
# Out:
# This project is part of the 2017 participatory budget election on the city of Wroclaw in Poland.
#
#     Its name is: Park Rędziński.
#     Complete the justification of the project exactly as it was proposed during the election.
#
#     Description: Uzasadnienie
# Koncepcję Parku na Maślicach zaprojek ...

# %%
import os 
from llm_client import call_openai_model


api_key=os.getenv('OPENAI_API_KEY')
 
sample17['out'] = sample17['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))
# Out:
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!

# %%
sample17.filter(['project_id','prompt','out']).to_csv("output/validation/wrc17_guided_validation_description_2.csv", sep=";", index=False)

# %%
# prompt 3
sample17['prompt'] = sample17.apply(lambda x: build_validation_prompt_cost_district(x['project_name']), axis=1)
print(sample17['prompt'].iloc[0])
# Out:
# This project is part of the 2017 participatory budget election on the city of Wroclaw in Poland.
#
#     Its name is: Park Rędziński.
#     Can you tell me:
#     1. In which district of the city this project was proposed?
#     2. What was the cost proposed for this project?

# %%
import os 
from llm_client import call_openai_model


api_key=os.getenv('OPENAI_API_KEY')
 
sample17['out'] = sample17['prompt'].apply(lambda prompt: 
                     call_openai_model(prompt=prompt, api_key=api_key))
# Out:
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!
# LLM response receive!

# %%
sample17.filter(['project_id','prompt','out']).to_csv("output/validation/wrc17_guided_validation_district_cost.csv", sep=";", index=False)
